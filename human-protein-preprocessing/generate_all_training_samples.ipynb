# %%
import pandas as pd
import os
import random

# %%
def create_training_sample(individual_pathway, all_nodes, union_ppi, ind_pathway_name):
    """
    create the training samples from a processed single pathway
    """
    sample_size = max(1, len(all_nodes) // 4)  # TODO: change this to multiplication
    # randomly sample nodes
    random_sample = random.sample(all_nodes, sample_size)
    
    # Filter the edges that contain the sampled nodes
    mask = individual_pathway[0].isin(random_sample) & individual_pathway[2].isin(random_sample)
    matching_rows = individual_pathway[mask]
    
    # Generate the training sample
    training_sample = union_ppi.copy()
    training_sample["label"] = training_sample[[0, 1]].apply(tuple, axis=1).isin(matching_rows.apply(tuple, axis=1)).astype(int)
    
    if 1 in training_sample['label'].tolist():
        print("True labels in PPI - found")
    else:
        print("No True Label found in PPI")
        
    # save the training sample
    filename = ind_pathway_name + str(random.randint(1000, 9999)) + '.csv'
    training_sample.to_csv(f'training-samples/{filename}', index=False, sep='\t')

# %%
def process_individual_pathway(file_path, union_ppi, id_map):
    """
    Process a single pathway file and generate training samples
    
    Parameters:
    file_path (str): Path to the pathway file
    union_ppi (pd.DataFrame): The union PPI dataset
    id_map (pd.DataFrame): Mapping between gene names and entry names
    """
    # extract filename without extension for naming training samples
    path_name = os.path.splitext(os.path.basename(file_path))[0]
    path_name = path_name.replace(' ', '_').lower() + '_train_'
    
    # read + preprocess the pathway file
    individual_pathway = pd.read_csv(file_path, sep='\t', header=None)
    # remove the reaction column
    individual_pathway.drop(columns=[1], inplace=True)
    
    # create mapping dictionary from id map
    mapping_dict = dict(zip(id_map["gene_name"], id_map["entry_name"]))
    # replace gene names w entry names
    individual_pathway[0] = individual_pathway[0].replace(mapping_dict)
    individual_pathway[2] = individual_pathway[2].replace(mapping_dict)
    
    # get all unique nodes in the individual pathway
    all_nodes = list(set(individual_pathway[0].tolist() + individual_pathway[2].tolist()))
    
    print(f"\nProcessing pathway: {path_name}")
    print(f"Total nodes in pathway: {len(all_nodes)}")
    
    # Generate 10 training samples for each pathway
    for i in range(10):
        create_training_sample(individual_pathway, all_nodes, union_ppi, path_name)

# %%
def process_all_pathways(folder_path, union_ppi, id_map):
    """
    Process all pathway files in the specified folder
    
    Parameters:
    folder_path (str): Path to the folder containing pathway files
    union_ppi (pd.DataFrame): The union PPI dataset
    id_map (pd.DataFrame): Mapping between gene names and entry names
    """

    os.makedirs('training-samples', exist_ok=True)
    # get all .txt files in the folder
    pathway_files = [f for f in os.listdir(folder_path) if f.endswith('.txt')]
    print(f"Found {len(pathway_files)} pathway files to process")
    
    # Process each pathway file
    for file_name in pathway_files:
        file_path = os.path.join(folder_path, file_name)
        try:
            process_individual_pathway(file_path, union_ppi, id_map)
        except Exception as e:
            print(f"Error processing {file_name}: {str(e)}")
            continue

# %%
union_ppi = pd.read_csv('processed-data/union_ppi.txt', sep='\t', header=None)
union_ppi.head()
# Out:
#              0            1         2  3
# 0  TACC1_HUMAN   RUXG_HUMAN  0.736771  U
# 1  TACC1_HUMAN  KAT2A_HUMAN  0.292198  U
# 2  TACC1_HUMAN  CKAP5_HUMAN  0.724783  U
# 3  TACC1_HUMAN  YETS4_HUMAN  0.542597  U
# 4  TACC1_HUMAN   LSM7_HUMAN  0.714823  U

# %%
id_map = pd.read_csv('processed-data/mapped_ids_reviewed.csv', sep='\t')
id_map.head()
# Out:
#   gene_name   entry_name
# 0   PLA2G10  PA2GX_HUMAN
# 1     FDFT1   FDFT_HUMAN
# 2      UGCG   CEGT_HUMAN
# 3    CYP1A2  CP1A2_HUMAN
# 4     RARS2   SYRM_HUMAN

# %%
folder_path = 'pathwaycommons-individual'
process_all_pathways(folder_path, union_ppi, id_map)
# Out:
# Found 82 pathway files to process
#
# Processing pathway: vitamin_b6_metabolis_train_
# Total nodes in pathway: 12
# True labels in PPI - found
# True labels in PPI - found
# No True Label found in PPI
# True labels in PPI - found
# True labels in PPI - found
# No True Label found in PPI
# No True Label found in PPI
# True labels in PPI - found
# True labels in PPI - found
# No True Label found in PPI
#
# Processing pathway: valine,_leucine_and__train_
# Total nodes in pathway: 22
# True labels in PPI - found
# True labels in PPI - found
# True labels in PPI - found
# True labels in PPI - found
# True labels in PPI - found
# No True Label found in PPI
# True labels in PPI - found
# True labels in PPI - found
# True labels in PPI - found
# True labels in PPI - found
#
# Processing pathway: valine,_leucine_and__(1)_train_
# Total nodes in pathway: 77
# True labels in PPI - found
# True labels in PPI - found
# True labels in PPI - found
# True labels in PPI - found
# True labels in PPI - found
# True labels in PPI - found
# True labels in PPI - found
# True labels in PPI - found
# True labels in PPI - found
# True labels in PPI - found
#
# Processing pathway: ubiquinone_and_other_train_
# Total nodes in pathway: 46
# True labels in PPI - found
# True labels in PPI - found
# True labels in PPI - found
# True labels in PPI - found
# True labels in PPI - found
# True labels in PPI - found
# True labels in PPI - found
# True labels in PPI - found
# True labels in PPI - found
# True labels in PPI - found
#
# Processing pathway: tyrosine_metabolism_train_
# Total nodes in pathway: 73
# True labels in PPI - found
# True labels in PPI - found
# True labels in PPI - found
# True labels in PPI - found
# True labels in PPI - found
# True labels in PPI - found
# True labels in PPI - found
# True labels in PPI - found
# True labels in PPI - found
# True labels in PPI - found
#
# Processing pathway: thiamine_metabolism_train_
# Total nodes in pathway: 13
# No True Label found in PPI
# No True Label found in PPI
# No True Label found in PPI
# No True Label found in PPI
# No True Label found in PPI
# No True Label found in PPI
# True labels in PPI - found
# True labels in PPI - found
# True labels in PPI - found
# No True Label found in PPI
#
# Processing pathway: taurine_and_hypotaur_train_
# Total nodes in pathway: 16
# No True Label found in PPI
# No True Label found in PPI
# True labels in PPI - found
# True labels in PPI - found
# True labels in PPI - found
# True labels in PPI - found
# No True Label found in PPI
# True labels in PPI - found
# True labels in PPI - found
# True labels in PPI - found
#
# Processing pathway: sulfur_metabolism_train_
# Total nodes in pathway: 21
# True labels in PPI - found
# True labels in PPI - found
# True labels in PPI - found
# True labels in PPI - found
# True labels in PPI - found
# No True Label found in PPI
# True labels in PPI - found
# No True Label found in PPI
# True labels in PPI - found
# True labels in PPI - found
#
# Processing pathway: steroid_biosynthesis_train_
# Total nodes in pathway: 58
# True labels in PPI - found
# True labels in PPI - found
# True labels in PPI - found
# True labels in PPI - found
# True labels in PPI - found
# True labels in PPI - found
# True labels in PPI - found
# True labels in PPI - found
# True labels in PPI - found
# True labels in PPI - found
#
# Processing pathway: sphingolipid_metabol_train_
# Total nodes in pathway: 75
# True labels in PPI - found
# True labels in PPI - found
# True labels in PPI - found
# True labels in PPI - found
# True labels in PPI - found
# True labels in PPI - found
# True labels in PPI - found
# True labels in PPI - found
# True labels in PPI - found
# True labels in PPI - found
#
# Processing pathway: synthesis_and_degrad_train_
# Total nodes in pathway: 7
# No True Label found in PPI
# No True Label found in PPI
# No True Label found in PPI
# No True Label found in PPI
# No True Label found in PPI
# No True Label found in PPI
# No True Label found in PPI
# No True Label found in PPI
# No True Label found in PPI
# No True Label found in PPI
#
# Processing pathway: terpenoid_backbone_b_train_
# Total nodes in pathway: 17
# True labels in PPI - found
# True labels in PPI - found
# No True Label found in PPI
# True labels in PPI - found
# True labels in PPI - found
# No True Label found in PPI
# True labels in PPI - found
# True labels in PPI - found
# No True Label found in PPI
# True labels in PPI - found
#
# Processing pathway: tryptophan_metabolis_train_
# Total nodes in pathway: 80
# True labels in PPI - found
# True labels in PPI - found
# True labels in PPI - found
# True labels in PPI - found
# True labels in PPI - found
# True labels in PPI - found
# True labels in PPI - found
# True labels in PPI - found
# True labels in PPI - found
# True labels in PPI - found
#
# Processing pathway: steroid_hormone_bios_train_
# Total nodes in pathway: 132
# True labels in PPI - found
# True labels in PPI - found
# True labels in PPI - found
# True labels in PPI - found
# True labels in PPI - found
# True labels in PPI - found
# True labels in PPI - found
# True labels in PPI - found
# True labels in PPI - found
# True labels in PPI - found
#
# Processing pathway: starch_and_sucrose_m_train_
# Total nodes in pathway: 80
# True labels in PPI - found
# True labels in PPI - found
# True labels in PPI - found
# True labels in PPI - found
# True labels in PPI - found
# True labels in PPI - found
# True labels in PPI - found
# True labels in PPI - found
# True labels in PPI - found
# True labels in PPI - found
#
# Processing pathway: selenocompound_metab_train_
# Total nodes in pathway: 49
# True labels in PPI - found
# True labels in PPI - found
# True labels in PPI - found
# True labels in PPI - found
# True labels in PPI - found
# True labels in PPI - found
# True labels in PPI - found
# True labels in PPI - found
# True labels in PPI - found
# True labels in PPI - found
#
# Processing pathway: riboflavin_metabolis_train_
# Total nodes in pathway: 12
# True labels in PPI - found
# True labels in PPI - found
# No True Label found in PPI
# No True Label found in PPI
# True labels in PPI - found
# No True Label found in PPI
# True labels in PPI - found
# True labels in PPI - found
# No True Label found in PPI
# True labels in PPI - found
#
# Processing pathway: retinol_metabolism_train_
# Total nodes in pathway: 72
# True labels in PPI - found
# True labels in PPI - found
# True labels in PPI - found
# True labels in PPI - found
# True labels in PPI - found
# True labels in PPI - found
# True labels in PPI - found
# True labels in PPI - found
# True labels in PPI - found
# True labels in PPI - found
#
# Processing pathway: pyruvate_metabolism_train_
# Total nodes in pathway: 71
# True labels in PPI - found
# True labels in PPI - found
# True labels in PPI - found
# True labels in PPI - found
# True labels in PPI - found
# True labels in PPI - found
# True labels in PPI - found
# True labels in PPI - found
# True labels in PPI - found
# True labels in PPI - found
#
# Processing pathway: pyrimidine_metabolis_train_
# Total nodes in pathway: 104
# True labels in PPI - found
# True labels in PPI - found
# True labels in PPI - found
# True labels in PPI - found
# True labels in PPI - found
# True labels in PPI - found
# True labels in PPI - found
# True labels in PPI - found
# True labels in PPI - found
# True labels in PPI - found
#
# Processing pathway: purine_metabolism_train_
# Total nodes in pathway: 180
# True labels in PPI - found
# True labels in PPI - found
# True labels in PPI - found
# True labels in PPI - found
# True labels in PPI - found
# True labels in PPI - found
# True labels in PPI - found
# True labels in PPI - found
# True labels in PPI - found
# True labels in PPI - found
#
# Processing pathway: propanoate_metabolis_train_
# Total nodes in pathway: 35
# True labels in PPI - found
# True labels in PPI - found
# True labels in PPI - found
# True labels in PPI - found
# True labels in PPI - found
# True labels in PPI - found
# True labels in PPI - found
# True labels in PPI - found
# True labels in PPI - found
# True labels in PPI - found
#
# Processing pathway: primary_bile_acid_bi_train_
# Total nodes in pathway: 68
# True labels in PPI - found
# True labels in PPI - found
# True labels in PPI - found
# True labels in PPI - found
# True labels in PPI - found
# True labels in PPI - found
# True labels in PPI - found
# True labels in PPI - found
# True labels in PPI - found
# True labels in PPI - found
#
# Processing pathway: porphyrin_and_chloro_train_
# Total nodes in pathway: 86
# True labels in PPI - found
# True labels in PPI - found
# True labels in PPI - found
# True labels in PPI - found
# True labels in PPI - found
# True labels in PPI - found
# True labels in PPI - found
# True labels in PPI - found
# True labels in PPI - found
# True labels in PPI - found
#
# Processing pathway: phenylalanine_metabo_train_
# Total nodes in pathway: 25
# True labels in PPI - found
# True labels in PPI - found
# True labels in PPI - found
# True labels in PPI - found
# True labels in PPI - found
# True labels in PPI - found
# True labels in PPI - found
# True labels in PPI - found
# No True Label found in PPI
# True labels in PPI - found
#
# Processing pathway: phenylalanine,_tyros_train_
# Total nodes in pathway: 15
# No True Label found in PPI
# No True Label found in PPI
# True labels in PPI - found
# True labels in PPI - found
# No True Label found in PPI
# True labels in PPI - found
# True labels in PPI - found
# True labels in PPI - found
# True labels in PPI - found
# True labels in PPI - found
#
# Processing pathway: pentose_phosphate_pa_train_
# Total nodes in pathway: 36
# True labels in PPI - found
# True labels in PPI - found
# True labels in PPI - found
# True labels in PPI - found
# True labels in PPI - found
# True labels in PPI - found
# True labels in PPI - found
# True labels in PPI - found
# True labels in PPI - found
# True labels in PPI - found
#
# Processing pathway: pentose_and_glucuron_train_
# Total nodes in pathway: 47
# True labels in PPI - found
# True labels in PPI - found
# True labels in PPI - found
# True labels in PPI - found
# No True Label found in PPI
# True labels in PPI - found
# True labels in PPI - found
# True labels in PPI - found
# True labels in PPI - found
# True labels in PPI - found
#
# Processing pathway: pantothenate_and_coa_train_
# Total nodes in pathway: 39
# True labels in PPI - found
# True labels in PPI - found
# True labels in PPI - found
# True labels in PPI - found
# True labels in PPI - found
# True labels in PPI - found
# True labels in PPI - found
# True labels in PPI - found
# True labels in PPI - found
# True labels in PPI - found
#
# Processing pathway: other_types_of_o-gly_train_
# Total nodes in pathway: 34
# True labels in PPI - found
# True labels in PPI - found
# True labels in PPI - found
# True labels in PPI - found
# True labels in PPI - found
# True labels in PPI - found
# No True Label found in PPI
# True labels in PPI - found
# True labels in PPI - found
# True labels in PPI - found
#
# Processing pathway: one_carbon_pool_by_f_train_
# Total nodes in pathway: 44
# True labels in PPI - found
# True labels in PPI - found
# True labels in PPI - found
# True labels in PPI - found
# True labels in PPI - found
# True labels in PPI - found
# True labels in PPI - found
# True labels in PPI - found
# True labels in PPI - found
# True labels in PPI - found
#
# Processing pathway: nitrogen_metabolism_train_
# Total nodes in pathway: 31
# True labels in PPI - found
# True labels in PPI - found
# True labels in PPI - found
# True labels in PPI - found
# True labels in PPI - found
# No True Label found in PPI
# True labels in PPI - found
# True labels in PPI - found
# True labels in PPI - found
# True labels in PPI - found
#
# Processing pathway: alanine,_aspartate_a_train_
# Total nodes in pathway: 52
# True labels in PPI - found
# True labels in PPI - found
# True labels in PPI - found
# True labels in PPI - found
# True labels in PPI - found
# True labels in PPI - found
# True labels in PPI - found
# True labels in PPI - found
# True labels in PPI - found
# True labels in PPI - found
#
# Processing pathway: alpha-linolenic_acid_train_
# Total nodes in pathway: 34
# True labels in PPI - found
# True labels in PPI - found
# No True Label found in PPI
# True labels in PPI - found
# True labels in PPI - found
# True labels in PPI - found
# True labels in PPI - found
# True labels in PPI - found
# True labels in PPI - found
# True labels in PPI - found
#
# Processing pathway: amino_sugar_and_nucl_train_
# Total nodes in pathway: 83
# True labels in PPI - found
# True labels in PPI - found
# True labels in PPI - found
# True labels in PPI - found
# True labels in PPI - found
# True labels in PPI - found
# True labels in PPI - found
# True labels in PPI - found
# True labels in PPI - found
# True labels in PPI - found
#
# Processing pathway: aminoacyl-trna_biosy_train_
# Total nodes in pathway: 92
# True labels in PPI - found
# True labels in PPI - found
# True labels in PPI - found
# True labels in PPI - found
# True labels in PPI - found
# True labels in PPI - found
# True labels in PPI - found
# True labels in PPI - found
# True labels in PPI - found
# True labels in PPI - found
#
# Processing pathway: arachidonic_acid_met_train_
# Total nodes in pathway: 70
# True labels in PPI - found
# True labels in PPI - found
# True labels in PPI - found
# True labels in PPI - found
# True labels in PPI - found
# True labels in PPI - found
# True labels in PPI - found
# True labels in PPI - found
# True labels in PPI - found
# True labels in PPI - found
#
# Processing pathway: arginine_and_proline_train_
# Total nodes in pathway: 104
# True labels in PPI - found
# True labels in PPI - found
# True labels in PPI - found
# True labels in PPI - found
# True labels in PPI - found
# True labels in PPI - found
# True labels in PPI - found
# True labels in PPI - found
# True labels in PPI - found
# True labels in PPI - found
#
# Processing pathway: ascorbate_and_aldara_train_
# Total nodes in pathway: 31
# True labels in PPI - found
# True labels in PPI - found
# True labels in PPI - found
# No True Label found in PPI
# True labels in PPI - found
# True labels in PPI - found
# True labels in PPI - found
# No True Label found in PPI
# True labels in PPI - found
# No True Label found in PPI
#
# Processing pathway: beta-alanine_metabol_train_
# Total nodes in pathway: 44
# True labels in PPI - found
# True labels in PPI - found
# True labels in PPI - found
# True labels in PPI - found
# True labels in PPI - found
# True labels in PPI - found
# True labels in PPI - found
# True labels in PPI - found
# True labels in PPI - found
# True labels in PPI - found
#
# Processing pathway: biosynthesis_of_unsa_train_
# Total nodes in pathway: 66
# True labels in PPI - found
# True labels in PPI - found
# True labels in PPI - found
# True labels in PPI - found
# True labels in PPI - found
# True labels in PPI - found
# True labels in PPI - found
# True labels in PPI - found
# True labels in PPI - found
# True labels in PPI - found
#
# Processing pathway: biotin_metabolism_train_
# Total nodes in pathway: 10
# No True Label found in PPI
# No True Label found in PPI
# No True Label found in PPI
# No True Label found in PPI
# No True Label found in PPI
# No True Label found in PPI
# No True Label found in PPI
# True labels in PPI - found
# True labels in PPI - found
# No True Label found in PPI
#
# Processing pathway: butanoate_metabolism_train_
# Total nodes in pathway: 41
# True labels in PPI - found
# True labels in PPI - found
# True labels in PPI - found
# True labels in PPI - found
# True labels in PPI - found
# True labels in PPI - found
# True labels in PPI - found
# True labels in PPI - found
# True labels in PPI - found
# True labels in PPI - found
#
# Processing pathway: butirosin_and_neomyc_train_
# Total nodes in pathway: 7
# No True Label found in PPI
# No True Label found in PPI
# No True Label found in PPI
# No True Label found in PPI
# No True Label found in PPI
# No True Label found in PPI
# No True Label found in PPI
# No True Label found in PPI
# No True Label found in PPI
# No True Label found in PPI
#
# Processing pathway: caffeine_metabolism_train_
# Total nodes in pathway: 17
# True labels in PPI - found
# True labels in PPI - found
# True labels in PPI - found
# True labels in PPI - found
# No True Label found in PPI
# True labels in PPI - found
# True labels in PPI - found
# True labels in PPI - found
# True labels in PPI - found
# True labels in PPI - found
#
# Processing pathway: citrate_cycle_(tca_c_train_
# Total nodes in pathway: 46
# True labels in PPI - found
# True labels in PPI - found
# True labels in PPI - found
# True labels in PPI - found
# True labels in PPI - found
# True labels in PPI - found
# True labels in PPI - found
# True labels in PPI - found
# True labels in PPI - found
# True labels in PPI - found
#
# Processing pathway: cyanoamino_acid_meta_train_
# Total nodes in pathway: 10
# True labels in PPI - found
# No True Label found in PPI
# True labels in PPI - found
# No True Label found in PPI
# True labels in PPI - found
# No True Label found in PPI
# No True Label found in PPI
# No True Label found in PPI
# No True Label found in PPI
# No True Label found in PPI
#
# Processing pathway: cysteine_and_methion_train_
# Total nodes in pathway: 48
# True labels in PPI - found
# True labels in PPI - found
# True labels in PPI - found
# True labels in PPI - found
# True labels in PPI - found
# True labels in PPI - found
# True labels in PPI - found
# True labels in PPI - found
# True labels in PPI - found
# True labels in PPI - found
#
# Processing pathway: d-arginine_and_d-orn_train_
# Total nodes in pathway: 7
# No True Label found in PPI
# No True Label found in PPI
# No True Label found in PPI
# No True Label found in PPI
# No True Label found in PPI
# No True Label found in PPI
# No True Label found in PPI
# No True Label found in PPI
# No True Label found in PPI
# No True Label found in PPI
#
# Processing pathway: drug_metabolism_-_ot_train_
# Total nodes in pathway: 96
# True labels in PPI - found
# True labels in PPI - found
# True labels in PPI - found
# True labels in PPI - found
# True labels in PPI - found
# True labels in PPI - found
# True labels in PPI - found
# True labels in PPI - found
# True labels in PPI - found
# True labels in PPI - found
#
# Processing pathway: d-glutamine_and_d-gl_train_
# Total nodes in pathway: 6
# No True Label found in PPI
# No True Label found in PPI
# No True Label found in PPI
# No True Label found in PPI
# No True Label found in PPI
# No True Label found in PPI
# No True Label found in PPI
# No True Label found in PPI
# No True Label found in PPI
# No True Label found in PPI
#
# Processing pathway: drug_metabolism_-_cy_train_
# Total nodes in pathway: 131
# True labels in PPI - found
# True labels in PPI - found
# True labels in PPI - found
# True labels in PPI - found
# True labels in PPI - found
# True labels in PPI - found
# True labels in PPI - found
# True labels in PPI - found
# True labels in PPI - found
# True labels in PPI - found
#
# Processing pathway: ether_lipid_metaboli_train_
# Total nodes in pathway: 56
# True labels in PPI - found
# True labels in PPI - found
# True labels in PPI - found
# True labels in PPI - found
# True labels in PPI - found
# True labels in PPI - found
# True labels in PPI - found
# True labels in PPI - found
# True labels in PPI - found
# True labels in PPI - found
#
# Processing pathway: fatty_acid_biosynthe_train_
# Total nodes in pathway: 41
# True labels in PPI - found
# True labels in PPI - found
# True labels in PPI - found
# True labels in PPI - found
# True labels in PPI - found
# True labels in PPI - found
# True labels in PPI - found
# True labels in PPI - found
# True labels in PPI - found
# True labels in PPI - found
#
# Processing pathway: fatty_acid_elongatio_train_
# Total nodes in pathway: 33
# True labels in PPI - found
# True labels in PPI - found
# True labels in PPI - found
# True labels in PPI - found
# True labels in PPI - found
# True labels in PPI - found
# True labels in PPI - found
# True labels in PPI - found
# No True Label found in PPI
# True labels in PPI - found
#
# Processing pathway: folate_biosynthesis_train_
# Total nodes in pathway: 36
# True labels in PPI - found
# True labels in PPI - found
# True labels in PPI - found
# True labels in PPI - found
# True labels in PPI - found
# True labels in PPI - found
# True labels in PPI - found
# True labels in PPI - found
# True labels in PPI - found
# True labels in PPI - found
#
# Processing pathway: fructose_and_mannose_train_
# Total nodes in pathway: 42
# True labels in PPI - found
# True labels in PPI - found
# True labels in PPI - found
# True labels in PPI - found
# True labels in PPI - found
# No True Label found in PPI
# True labels in PPI - found
# True labels in PPI - found
# True labels in PPI - found
# True labels in PPI - found
#
# Processing pathway: fatty_acid_degradati_train_
# Total nodes in pathway: 74
# True labels in PPI - found
# True labels in PPI - found
# True labels in PPI - found
# True labels in PPI - found
# True labels in PPI - found
# True labels in PPI - found
# True labels in PPI - found
# True labels in PPI - found
# True labels in PPI - found
# True labels in PPI - found
#
# Processing pathway: galactose_metabolism_train_
# Total nodes in pathway: 55
# True labels in PPI - found
# True labels in PPI - found
# True labels in PPI - found
# True labels in PPI - found
# True labels in PPI - found
# True labels in PPI - found
# True labels in PPI - found
# True labels in PPI - found
# True labels in PPI - found
# True labels in PPI - found
#
# Processing pathway: glutathione_metaboli_train_
# Total nodes in pathway: 85
# True labels in PPI - found
# True labels in PPI - found
# True labels in PPI - found
# True labels in PPI - found
# True labels in PPI - found
# True labels in PPI - found
# True labels in PPI - found
# True labels in PPI - found
# True labels in PPI - found
# True labels in PPI - found
#
# Processing pathway: glycerolipid_metabol_train_
# Total nodes in pathway: 35
# True labels in PPI - found
# True labels in PPI - found
# True labels in PPI - found
# True labels in PPI - found
# True labels in PPI - found
# True labels in PPI - found
# True labels in PPI - found
# True labels in PPI - found
# True labels in PPI - found
# True labels in PPI - found
#
# Processing pathway: glycerophospholipid__train_
# Total nodes in pathway: 103
# True labels in PPI - found
# True labels in PPI - found
# True labels in PPI - found
# True labels in PPI - found
# True labels in PPI - found
# True labels in PPI - found
# True labels in PPI - found
# True labels in PPI - found
# True labels in PPI - found
# True labels in PPI - found
#
# Processing pathway: glycine,_serine_and__train_
# Total nodes in pathway: 73
# True labels in PPI - found
# True labels in PPI - found
# True labels in PPI - found
# True labels in PPI - found
# True labels in PPI - found
# True labels in PPI - found
# True labels in PPI - found
# True labels in PPI - found
# True labels in PPI - found
# True labels in PPI - found
#
# Processing pathway: glycolysis___glucone_train_
# Total nodes in pathway: 72
# True labels in PPI - found
# True labels in PPI - found
# True labels in PPI - found
# True labels in PPI - found
# True labels in PPI - found
# True labels in PPI - found
# True labels in PPI - found
# True labels in PPI - found
# True labels in PPI - found
# True labels in PPI - found
#
# Processing pathway: glycosaminoglycan_bi_(1)_train_
# Total nodes in pathway: 22
# True labels in PPI - found
# True labels in PPI - found
# True labels in PPI - found
# No True Label found in PPI
# True labels in PPI - found
# True labels in PPI - found
# True labels in PPI - found
# True labels in PPI - found
# True labels in PPI - found
# True labels in PPI - found
#
# Processing pathway: glycosaminoglycan_bi_train_
# Total nodes in pathway: 22
# True labels in PPI - found
# True labels in PPI - found
# True labels in PPI - found
# True labels in PPI - found
# True labels in PPI - found
# No True Label found in PPI
# True labels in PPI - found
# No True Label found in PPI
# True labels in PPI - found
# No True Label found in PPI
#
# Processing pathway: glycosaminoglycan_de_train_
# Total nodes in pathway: 44
# True labels in PPI - found
# True labels in PPI - found
# No True Label found in PPI
# True labels in PPI - found
# No True Label found in PPI
# True labels in PPI - found
# True labels in PPI - found
# True labels in PPI - found
# True labels in PPI - found
# True labels in PPI - found
#
# Processing pathway: glycosphingolipid_bi_(1)_train_
# Total nodes in pathway: 84
# True labels in PPI - found
# True labels in PPI - found
# True labels in PPI - found
# True labels in PPI - found
# True labels in PPI - found
# True labels in PPI - found
# True labels in PPI - found
# True labels in PPI - found
# True labels in PPI - found
# True labels in PPI - found
#
# Processing pathway: glycosphingolipid_bi_(2)_train_
# Total nodes in pathway: 45
# True labels in PPI - found
# True labels in PPI - found
# True labels in PPI - found
# True labels in PPI - found
# True labels in PPI - found
# True labels in PPI - found
# True labels in PPI - found
# True labels in PPI - found
# True labels in PPI - found
# True labels in PPI - found
#
# Processing pathway: glycosphingolipid_bi_train_
# Total nodes in pathway: 32
# No True Label found in PPI
# No True Label found in PPI
# True labels in PPI - found
# True labels in PPI - found
# True labels in PPI - found
# True labels in PPI - found
# True labels in PPI - found
# True labels in PPI - found
# True labels in PPI - found
# True labels in PPI - found
#
# Processing pathway: glycosylphosphatidyl_train_
# Total nodes in pathway: 41
# True labels in PPI - found
# True labels in PPI - found
# True labels in PPI - found
# True labels in PPI - found
# True labels in PPI - found
# True labels in PPI - found
# True labels in PPI - found
# True labels in PPI - found
# True labels in PPI - found
# True labels in PPI - found
#
# Processing pathway: glyoxylate_and_dicar_train_
# Total nodes in pathway: 24
# True labels in PPI - found
# True labels in PPI - found
# True labels in PPI - found
# True labels in PPI - found
# True labels in PPI - found
# True labels in PPI - found
# True labels in PPI - found
# True labels in PPI - found
# True labels in PPI - found
# True labels in PPI - found
#
# Processing pathway: histidine_metabolism_train_
# Total nodes in pathway: 41
# True labels in PPI - found
# True labels in PPI - found
# True labels in PPI - found
# True labels in PPI - found
# True labels in PPI - found
# True labels in PPI - found
# True labels in PPI - found
# True labels in PPI - found
# True labels in PPI - found
# True labels in PPI - found
#
# Processing pathway: inositol_phosphate_m_train_
# Total nodes in pathway: 64
# True labels in PPI - found
# True labels in PPI - found
# True labels in PPI - found
# True labels in PPI - found
# True labels in PPI - found
# True labels in PPI - found
# True labels in PPI - found
# True labels in PPI - found
# True labels in PPI - found
# True labels in PPI - found
#
# Processing pathway: linoleic_acid_metabo_train_
# Total nodes in pathway: 3
# No True Label found in PPI
# No True Label found in PPI
# No True Label found in PPI
# No True Label found in PPI
# No True Label found in PPI
# No True Label found in PPI
# No True Label found in PPI
# No True Label found in PPI
# No True Label found in PPI
# No True Label found in PPI
#
# Processing pathway: lipoic_acid_metaboli_train_
# Total nodes in pathway: 8
# No True Label found in PPI
# True labels in PPI - found
# True labels in PPI - found
# True labels in PPI - found
# True labels in PPI - found
# True labels in PPI - found
# True labels in PPI - found
# True labels in PPI - found
# True labels in PPI - found
# No True Label found in PPI
#
# Processing pathway: lysine_biosynthesis_train_
# Total nodes in pathway: 7
# No True Label found in PPI
# No True Label found in PPI
# No True Label found in PPI
# No True Label found in PPI
# No True Label found in PPI
# No True Label found in PPI
# No True Label found in PPI
# No True Label found in PPI
# No True Label found in PPI
# No True Label found in PPI
#
# Processing pathway: lysine_degradation_train_
# Total nodes in pathway: 45
# True labels in PPI - found
# True labels in PPI - found
# True labels in PPI - found
# True labels in PPI - found
# True labels in PPI - found
# True labels in PPI - found
# True labels in PPI - found
# True labels in PPI - found
# No True Label found in PPI
# True labels in PPI - found
#
# Processing pathway: metabolism_of_xenobi_train_
# Total nodes in pathway: 114
# True labels in PPI - found
# True labels in PPI - found
# True labels in PPI - found
# True labels in PPI - found
# True labels in PPI - found
# True labels in PPI - found
# True labels in PPI - found
# True labels in PPI - found
# True labels in PPI - found
# True labels in PPI - found
#
# Processing pathway: mucin_type_o-glycan__train_
# Total nodes in pathway: 26
# No True Label found in PPI
# True labels in PPI - found
# True labels in PPI - found
# True labels in PPI - found
# True labels in PPI - found
# True labels in PPI - found
# True labels in PPI - found
# True labels in PPI - found
# True labels in PPI - found
# True labels in PPI - found
#
# Processing pathway: n-glycan_biosynthesi_train_
# Total nodes in pathway: 88
# True labels in PPI - found
# True labels in PPI - found
# True labels in PPI - found
# True labels in PPI - found
# True labels in PPI - found
# True labels in PPI - found
# True labels in PPI - found
# True labels in PPI - found
# True labels in PPI - found
# True labels in PPI - found
#
# Processing pathway: nicotinate_and_nicot_train_
# Total nodes in pathway: 46
# True labels in PPI - found
# True labels in PPI - found
# True labels in PPI - found
# True labels in PPI - found
# True labels in PPI - found
# True labels in PPI - found
# True labels in PPI - found
# True labels in PPI - found
# True labels in PPI - found
# True labels in PPI - found

# %%
folder_path = 'training-samples'
files = os.listdir(folder_path)
num_files = len(files)
print(f"Total files: {num_files}")
# Out:
# Total files: 820
