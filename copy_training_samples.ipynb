# %%
import os
import shutil

# %%
def copy_files_from_list(txt_file, source_dir, dest_dir):
    """
    Reads file names from `txt_file`, then copies each file
    from `source_dir` to `dest_dir`.
    
    :param txt_file: Path to the text file containing file names (one per line).
    :param source_dir: Directory where the files are currently located.
    :param dest_dir: Directory where the files should be copied.
    """
    # Ensure destination directory exists
    os.makedirs(dest_dir, exist_ok=True)

    # Open the text file and read lines
    with open(txt_file, 'r') as f:
        file_names = [line.strip() for line in f if line.strip()]
    
    # Loop through each file name in the text file
    for file_name in file_names:
        src_file = os.path.join(source_dir, file_name)
        dst_file = os.path.join(dest_dir, file_name)
        
        # Check if file exists in the source directory
        if os.path.isfile(src_file):
            # Copy the file
            shutil.copy2(src_file, dst_file)
            print(f"Copied: {file_name}")
        else:
            print(f"File not found (skipping): {file_name}")

# %%
txt_file = "processed-data/train_files.txt"
source_dir = "training-samples"
dest_dir = "gnn-train-split-samples"

copy_files_from_list(txt_file, source_dir, dest_dir)
# Out:
# Copied: pyruvate_metabolism_train_9622.csv
# Copied: butirosin_and_neomyc_train_4999.csv
# Copied: cysteine_and_methion_train_8208.csv
# Copied: riboflavin_metabolis_train_5918.csv
# Copied: biotin_metabolism_train_7622.csv
# Copied: inositol_phosphate_m_train_6383.csv
# Copied: glutathione_metaboli_train_2142.csv
# Copied: propanoate_metabolis_train_1641.csv
# Copied: glycolysis___glucone_train_7341.csv
# Copied: amino_sugar_and_nucl_train_6644.csv
# Copied: terpenoid_backbone_b_train_1198.csv
# Copied: beta-alanine_metabol_train_2705.csv
# Copied: tyrosine_metabolism_train_8918.csv
# Copied: glycosylphosphatidyl_train_6909.csv
# Copied: pyruvate_metabolism_train_6622.csv
# Copied: porphyrin_and_chloro_train_4997.csv
# Copied: glutathione_metaboli_train_4479.csv
# Copied: glycosylphosphatidyl_train_2059.csv
# Copied: phenylalanine,_tyros_train_2425.csv
# Copied: ether_lipid_metaboli_train_1598.csv
# Copied: glycosphingolipid_bi_train_2504.csv
# Copied: glycosphingolipid_bi_train_9168.csv
# Copied: thiamine_metabolism_train_5258.csv
# Copied: steroid_hormone_bios_train_7125.csv
# Copied: butirosin_and_neomyc_train_1721.csv
# Copied: terpenoid_backbone_b_train_9404.csv
# Copied: beta-alanine_metabol_train_7183.csv
# Copied: phenylalanine_metabo_train_2067.csv
# Copied: d-arginine_and_d-orn_train_1815.csv
# Copied: d-arginine_and_d-orn_train_4827.csv
# Copied: cysteine_and_methion_train_2826.csv
# Copied: steroid_hormone_bios_train_8704.csv
# Copied: steroid_biosynthesis_train_8821.csv
# Copied: starch_and_sucrose_m_train_5869.csv
# Copied: glycosphingolipid_bi_(2)_train_7576.csv
# Copied: one_carbon_pool_by_f_train_4046.csv
# Copied: steroid_hormone_bios_train_2497.csv
# Copied: glycosphingolipid_bi_train_7369.csv
# Copied: glycosaminoglycan_bi_(1)_train_6041.csv
# Copied: biosynthesis_of_unsa_train_6470.csv
# Copied: folate_biosynthesis_train_3178.csv
# Copied: primary_bile_acid_bi_train_8799.csv
# Copied: steroid_hormone_bios_train_7327.csv
# Copied: ubiquinone_and_other_train_2366.csv
# Copied: glycosphingolipid_bi_train_7507.csv
# Copied: sphingolipid_metabol_train_2299.csv
# Copied: pantothenate_and_coa_train_3035.csv
# Copied: glycosaminoglycan_bi_(1)_train_4495.csv
# Copied: d-glutamine_and_d-gl_train_6453.csv
# Copied: glycolysis___glucone_train_8450.csv
# Copied: mucin_type_o-glycan__train_5726.csv
# Copied: linoleic_acid_metabo_train_9139.csv
# Copied: alanine,_aspartate_a_train_6130.csv
# Copied: metabolism_of_xenobi_train_4073.csv
# Copied: alpha-linolenic_acid_train_6633.csv
# Copied: pantothenate_and_coa_train_7317.csv
# Copied: thiamine_metabolism_train_8748.csv
# Copied: selenocompound_metab_train_5417.csv
# Copied: tryptophan_metabolis_train_9256.csv
# Copied: riboflavin_metabolis_train_6043.csv
# Copied: arachidonic_acid_met_train_2983.csv
# Copied: glycerolipid_metabol_train_5382.csv
# Copied: fatty_acid_elongatio_train_7460.csv
# Copied: drug_metabolism_-_ot_train_6253.csv
# Copied: galactose_metabolism_train_8430.csv
# Copied: glycine,_serine_and__train_6145.csv
# Copied: fatty_acid_degradati_train_4206.csv
# Copied: glyoxylate_and_dicar_train_2960.csv
# Copied: glycerolipid_metabol_train_5932.csv
# Copied: lipoic_acid_metaboli_train_6521.csv
# Copied: ubiquinone_and_other_train_2997.csv
# Copied: arachidonic_acid_met_train_2867.csv
# Copied: steroid_biosynthesis_train_7878.csv
# Copied: histidine_metabolism_train_5677.csv
# Copied: nicotinate_and_nicot_train_6943.csv
# Copied: terpenoid_backbone_b_train_4588.csv
# Copied: pantothenate_and_coa_train_2787.csv
# Copied: phenylalanine_metabo_train_3213.csv
# Copied: starch_and_sucrose_m_train_5925.csv
# Copied: taurine_and_hypotaur_train_1875.csv
# Copied: pantothenate_and_coa_train_9992.csv
# Copied: lysine_degradation_train_9699.csv
# Copied: fructose_and_mannose_train_8580.csv
# Copied: tryptophan_metabolis_train_9385.csv
# Copied: glycosaminoglycan_de_train_3162.csv
# Copied: glycosphingolipid_bi_train_4181.csv
# Copied: caffeine_metabolism_train_4187.csv
# Copied: phenylalanine_metabo_train_8640.csv
# Copied: glutathione_metaboli_train_1578.csv
# Copied: arachidonic_acid_met_train_3457.csv
# Copied: glutathione_metaboli_train_4039.csv
# Copied: n-glycan_biosynthesi_train_5411.csv
# Copied: sphingolipid_metabol_train_8777.csv
# Copied: terpenoid_backbone_b_train_8657.csv
# Copied: galactose_metabolism_train_5798.csv
# Copied: purine_metabolism_train_1409.csv
# Copied: glycolysis___glucone_train_7813.csv
# Copied: drug_metabolism_-_cy_train_4503.csv
# Copied: glyoxylate_and_dicar_train_1587.csv
# Copied: propanoate_metabolis_train_8432.csv
# Copied: tyrosine_metabolism_train_6010.csv
# Copied: biotin_metabolism_train_3135.csv
# Copied: other_types_of_o-gly_train_9407.csv
# Copied: phenylalanine,_tyros_train_2724.csv
# Copied: tryptophan_metabolis_train_5522.csv
# Copied: retinol_metabolism_train_5470.csv
# Copied: caffeine_metabolism_train_3176.csv
# Copied: fructose_and_mannose_train_9217.csv
# Copied: biotin_metabolism_train_8673.csv
# Copied: vitamin_b6_metabolis_train_7405.csv
# Copied: metabolism_of_xenobi_train_1891.csv
# Copied: pyruvate_metabolism_train_7605.csv
# Copied: pentose_and_glucuron_train_6395.csv
# Copied: purine_metabolism_train_2263.csv
# Copied: glycerolipid_metabol_train_6242.csv
# Copied: cysteine_and_methion_train_8949.csv
# Copied: alanine,_aspartate_a_train_2535.csv
# Copied: lipoic_acid_metaboli_train_8189.csv
# Copied: pyruvate_metabolism_train_2459.csv
# Copied: glycerolipid_metabol_train_8006.csv
# Copied: porphyrin_and_chloro_train_6817.csv
# Copied: other_types_of_o-gly_train_6246.csv
# Copied: retinol_metabolism_train_4089.csv
# Copied: nitrogen_metabolism_train_6141.csv
# Copied: glycerophospholipid__train_3822.csv
# Copied: lysine_degradation_train_1404.csv
# Copied: histidine_metabolism_train_3733.csv
# Copied: pyruvate_metabolism_train_3867.csv
# Copied: thiamine_metabolism_train_3773.csv
# Copied: glycosylphosphatidyl_train_7490.csv
# Copied: sphingolipid_metabol_train_7532.csv
# Copied: glutathione_metaboli_train_3693.csv
# Copied: alanine,_aspartate_a_train_3273.csv
# Copied: steroid_biosynthesis_train_8131.csv
# Copied: retinol_metabolism_train_1453.csv
# Copied: terpenoid_backbone_b_train_6459.csv
# Copied: steroid_biosynthesis_train_9585.csv
# Copied: fatty_acid_biosynthe_train_6264.csv
# Copied: alpha-linolenic_acid_train_4263.csv
# Copied: glycosaminoglycan_de_train_2488.csv
# Copied: other_types_of_o-gly_train_6244.csv
# Copied: glycosaminoglycan_de_train_7274.csv
# Copied: mucin_type_o-glycan__train_1207.csv
# Copied: caffeine_metabolism_train_4696.csv
# Copied: other_types_of_o-gly_train_6804.csv
# Copied: glycosaminoglycan_bi_(1)_train_6852.csv
# Copied: synthesis_and_degrad_train_2802.csv
# Copied: tyrosine_metabolism_train_5403.csv
# Copied: amino_sugar_and_nucl_train_9691.csv
# Copied: glycine,_serine_and__train_8905.csv
# Copied: nitrogen_metabolism_train_9395.csv
# Copied: valine,_leucine_and__train_3704.csv
# Copied: one_carbon_pool_by_f_train_5988.csv
# Copied: phenylalanine_metabo_train_7746.csv
# Copied: glutathione_metaboli_train_5956.csv
# Copied: terpenoid_backbone_b_train_8942.csv
# Copied: biosynthesis_of_unsa_train_5667.csv
# Copied: ether_lipid_metaboli_train_3063.csv
# Copied: glycosylphosphatidyl_train_3575.csv
# Copied: glycosaminoglycan_de_train_4549.csv
# Copied: purine_metabolism_train_9583.csv
# Copied: pentose_phosphate_pa_train_9496.csv
# Copied: tyrosine_metabolism_train_2226.csv
# Copied: propanoate_metabolis_train_5106.csv
# Copied: glycosphingolipid_bi_(2)_train_9384.csv
# Copied: fatty_acid_elongatio_train_4296.csv
# Copied: lysine_biosynthesis_train_4196.csv
# Copied: glycolysis___glucone_train_3045.csv
# Copied: beta-alanine_metabol_train_7979.csv
# Copied: fatty_acid_degradati_train_3405.csv
# Copied: pyrimidine_metabolis_train_3799.csv
# Copied: d-glutamine_and_d-gl_train_6415.csv
# Copied: thiamine_metabolism_train_3962.csv
# Copied: cyanoamino_acid_meta_train_2915.csv
# Copied: synthesis_and_degrad_train_3351.csv
# Copied: lipoic_acid_metaboli_train_6350.csv
# Copied: ubiquinone_and_other_train_6291.csv
# Copied: beta-alanine_metabol_train_7581.csv
# Copied: amino_sugar_and_nucl_train_1699.csv
# Copied: citrate_cycle_(tca_c_train_6943.csv
# Copied: propanoate_metabolis_train_2104.csv
# Copied: synthesis_and_degrad_train_2073.csv
# Copied: cysteine_and_methion_train_8285.csv
# Copied: butanoate_metabolism_train_8741.csv
# Copied: d-arginine_and_d-orn_train_6276.csv
# Copied: starch_and_sucrose_m_train_8147.csv
# Copied: sphingolipid_metabol_train_6402.csv
# Copied: ubiquinone_and_other_train_5916.csv
# Copied: tryptophan_metabolis_train_2110.csv
# Copied: tyrosine_metabolism_train_7807.csv
# Copied: glycerolipid_metabol_train_4441.csv
# Copied: beta-alanine_metabol_train_8672.csv
# Copied: sulfur_metabolism_train_5728.csv
# Copied: ascorbate_and_aldara_train_1853.csv
# Copied: lysine_degradation_train_8754.csv
# Copied: galactose_metabolism_train_1510.csv
# Copied: caffeine_metabolism_train_3718.csv
# Copied: aminoacyl-trna_biosy_train_4856.csv
# Copied: primary_bile_acid_bi_train_4552.csv
# Copied: glycosaminoglycan_bi_(1)_train_5476.csv
# Copied: alpha-linolenic_acid_train_9806.csv
# Copied: arachidonic_acid_met_train_6149.csv
# Copied: propanoate_metabolis_train_6366.csv
# Copied: lipoic_acid_metaboli_train_8728.csv
# Copied: arachidonic_acid_met_train_1279.csv
# Copied: glycerolipid_metabol_train_4745.csv
# Copied: one_carbon_pool_by_f_train_3035.csv
# Copied: valine,_leucine_and__train_1385.csv
# Copied: metabolism_of_xenobi_train_9086.csv
# Copied: cysteine_and_methion_train_3585.csv
# Copied: vitamin_b6_metabolis_train_1175.csv
# Copied: steroid_hormone_bios_train_8148.csv
# Copied: fatty_acid_degradati_train_7616.csv
# Copied: phenylalanine,_tyros_train_1487.csv
# Copied: d-glutamine_and_d-gl_train_6575.csv
# Copied: taurine_and_hypotaur_train_3065.csv
# Copied: folate_biosynthesis_train_8579.csv
# Copied: aminoacyl-trna_biosy_train_1565.csv
# Copied: arginine_and_proline_train_4664.csv
# Copied: sulfur_metabolism_train_5877.csv
# Copied: porphyrin_and_chloro_train_1972.csv
# Copied: fatty_acid_elongatio_train_7810.csv
# Copied: mucin_type_o-glycan__train_4852.csv
# Copied: cyanoamino_acid_meta_train_2368.csv
# Copied: porphyrin_and_chloro_train_6811.csv
# Copied: arginine_and_proline_train_4399.csv
# Copied: glycosaminoglycan_de_train_1711.csv
# Copied: beta-alanine_metabol_train_3310.csv
# Copied: fructose_and_mannose_train_1791.csv
# Copied: amino_sugar_and_nucl_train_3796.csv
# Copied: fatty_acid_biosynthe_train_7404.csv
# Copied: amino_sugar_and_nucl_train_5376.csv
# Copied: glycosphingolipid_bi_train_5557.csv
# Copied: retinol_metabolism_train_8948.csv
# Copied: ascorbate_and_aldara_train_8171.csv
# Copied: fatty_acid_elongatio_train_3530.csv
# Copied: mucin_type_o-glycan__train_4957.csv
# Copied: ether_lipid_metaboli_train_4815.csv
# Copied: inositol_phosphate_m_train_8965.csv
# Copied: d-arginine_and_d-orn_train_8863.csv
# Copied: biosynthesis_of_unsa_train_4693.csv
# Copied: thiamine_metabolism_train_2100.csv
# Copied: primary_bile_acid_bi_train_7793.csv
# Copied: butirosin_and_neomyc_train_5617.csv
# Copied: galactose_metabolism_train_4880.csv
# Copied: purine_metabolism_train_7936.csv
# Copied: arginine_and_proline_train_1599.csv
# Copied: starch_and_sucrose_m_train_5671.csv
# Copied: vitamin_b6_metabolis_train_6815.csv
# Copied: pyrimidine_metabolis_train_7160.csv
# Copied: riboflavin_metabolis_train_4802.csv
# Copied: galactose_metabolism_train_4572.csv
# Copied: glycolysis___glucone_train_3351.csv
# Copied: glycosaminoglycan_de_train_8470.csv
# Copied: steroid_biosynthesis_train_3268.csv
# Copied: phenylalanine,_tyros_train_3774.csv
# Copied: tyrosine_metabolism_train_1681.csv
# Copied: alanine,_aspartate_a_train_6672.csv
# Copied: nitrogen_metabolism_train_8986.csv
# Copied: fructose_and_mannose_train_6210.csv
# Copied: glycosphingolipid_bi_(2)_train_4272.csv
# Copied: phenylalanine,_tyros_train_4519.csv
# Copied: sulfur_metabolism_train_9748.csv
# Copied: linoleic_acid_metabo_train_5657.csv
# Copied: fructose_and_mannose_train_9475.csv
# Copied: arginine_and_proline_train_9140.csv
# Copied: lysine_biosynthesis_train_2016.csv
# Copied: taurine_and_hypotaur_train_3206.csv
# Copied: glycerophospholipid__train_6257.csv
# Copied: biotin_metabolism_train_7733.csv
# Copied: ether_lipid_metaboli_train_2397.csv
# Copied: butirosin_and_neomyc_train_2981.csv
# Copied: nicotinate_and_nicot_train_5849.csv
# Copied: starch_and_sucrose_m_train_5326.csv
# Copied: purine_metabolism_train_9503.csv
# Copied: histidine_metabolism_train_9640.csv
# Copied: biosynthesis_of_unsa_train_3280.csv
# Copied: glycosaminoglycan_bi_train_9612.csv
# Copied: pentose_and_glucuron_train_5502.csv
# Copied: propanoate_metabolis_train_7079.csv
# Copied: n-glycan_biosynthesi_train_4978.csv
# Copied: alanine,_aspartate_a_train_8527.csv
# Copied: riboflavin_metabolis_train_5826.csv
# Copied: vitamin_b6_metabolis_train_1544.csv
# Copied: riboflavin_metabolis_train_1552.csv
# Copied: selenocompound_metab_train_1652.csv
# Copied: steroid_biosynthesis_train_4516.csv
# Copied: glyoxylate_and_dicar_train_8802.csv
# Copied: butanoate_metabolism_train_6334.csv
# Copied: primary_bile_acid_bi_train_2793.csv
# Copied: cyanoamino_acid_meta_train_8714.csv
# Copied: d-glutamine_and_d-gl_train_9381.csv
# Copied: synthesis_and_degrad_train_2698.csv
# Copied: n-glycan_biosynthesi_train_4637.csv
# Copied: arachidonic_acid_met_train_1685.csv
# Copied: fructose_and_mannose_train_6794.csv
# Copied: fructose_and_mannose_train_5404.csv
# Copied: valine,_leucine_and__(1)_train_9534.csv
# Copied: pentose_phosphate_pa_train_1208.csv
# Copied: arginine_and_proline_train_2834.csv
# Copied: folate_biosynthesis_train_9494.csv
# Copied: nicotinate_and_nicot_train_4753.csv
# Copied: sphingolipid_metabol_train_5576.csv
# Copied: valine,_leucine_and__(1)_train_7923.csv
# Copied: alanine,_aspartate_a_train_9941.csv
# Copied: glycosaminoglycan_bi_train_2241.csv
# Copied: lysine_degradation_train_6900.csv
# Copied: fatty_acid_elongatio_train_6026.csv
# Copied: synthesis_and_degrad_train_5068.csv
# Copied: folate_biosynthesis_train_9363.csv
# Copied: drug_metabolism_-_ot_train_6155.csv
# Copied: fatty_acid_degradati_train_2826.csv
# Copied: nicotinate_and_nicot_train_9363.csv
# Copied: amino_sugar_and_nucl_train_2444.csv
# Copied: cyanoamino_acid_meta_train_8911.csv
# Copied: citrate_cycle_(tca_c_train_8425.csv
# Copied: histidine_metabolism_train_5160.csv
# Copied: pentose_phosphate_pa_train_2673.csv
# Copied: taurine_and_hypotaur_train_5698.csv
# Copied: nitrogen_metabolism_train_9476.csv
# Copied: glycerophospholipid__train_5031.csv
# Copied: ubiquinone_and_other_train_7545.csv
# Copied: glycerophospholipid__train_3243.csv
# Copied: ascorbate_and_aldara_train_9303.csv
# Copied: fructose_and_mannose_train_6584.csv
# Copied: glycerophospholipid__train_9901.csv
# Copied: glyoxylate_and_dicar_train_3794.csv
# Copied: riboflavin_metabolis_train_6750.csv
# Copied: metabolism_of_xenobi_train_2276.csv
# Copied: drug_metabolism_-_cy_train_6262.csv
# Copied: cysteine_and_methion_train_5119.csv
# Copied: pyruvate_metabolism_train_7292.csv
# Copied: sphingolipid_metabol_train_3883.csv
# Copied: beta-alanine_metabol_train_2559.csv
# Copied: folate_biosynthesis_train_3931.csv
# Copied: glycosphingolipid_bi_(2)_train_4472.csv
# Copied: taurine_and_hypotaur_train_4985.csv
# Copied: tryptophan_metabolis_train_1628.csv
# Copied: caffeine_metabolism_train_1005.csv
# Copied: fatty_acid_degradati_train_3240.csv
# Copied: glycerolipid_metabol_train_1672.csv
# Copied: sphingolipid_metabol_train_7075.csv
# Copied: glycolysis___glucone_train_9576.csv
# Copied: glutathione_metaboli_train_1590.csv
# Copied: fatty_acid_degradati_train_8271.csv
# Copied: arginine_and_proline_train_8211.csv
# Copied: fatty_acid_degradati_train_8270.csv
# Copied: thiamine_metabolism_train_1501.csv
# Copied: fatty_acid_elongatio_train_4051.csv
# Copied: d-arginine_and_d-orn_train_3362.csv
# Copied: biosynthesis_of_unsa_train_3803.csv
# Copied: inositol_phosphate_m_train_9582.csv
# Copied: tryptophan_metabolis_train_8942.csv
# Copied: nicotinate_and_nicot_train_1497.csv
# Copied: pyruvate_metabolism_train_3848.csv
# Copied: lysine_biosynthesis_train_2992.csv
# Copied: valine,_leucine_and__train_4369.csv
# Copied: aminoacyl-trna_biosy_train_5281.csv
# Copied: steroid_hormone_bios_train_5673.csv
# Copied: mucin_type_o-glycan__train_7491.csv
# Copied: riboflavin_metabolis_train_9684.csv
# Copied: glycosaminoglycan_bi_train_8023.csv
# Copied: glycolysis___glucone_train_9972.csv
# Copied: ascorbate_and_aldara_train_5955.csv
# Copied: fatty_acid_elongatio_train_2789.csv
# Copied: alanine,_aspartate_a_train_1510.csv
# Copied: histidine_metabolism_train_6614.csv
# Copied: ascorbate_and_aldara_train_8501.csv
# Copied: phenylalanine,_tyros_train_9535.csv
# Copied: alanine,_aspartate_a_train_3781.csv
# Copied: biosynthesis_of_unsa_train_4673.csv
# Copied: biotin_metabolism_train_6989.csv
# Copied: valine,_leucine_and__train_1950.csv
# Copied: arachidonic_acid_met_train_4290.csv
# Copied: retinol_metabolism_train_9167.csv
# Copied: lipoic_acid_metaboli_train_6169.csv
# Copied: other_types_of_o-gly_train_1299.csv
# Copied: lysine_degradation_train_7617.csv
# Copied: starch_and_sucrose_m_train_3953.csv
# Copied: butirosin_and_neomyc_train_4135.csv
# Copied: phenylalanine_metabo_train_7866.csv
# Copied: glyoxylate_and_dicar_train_2996.csv
# Copied: cyanoamino_acid_meta_train_7427.csv
# Copied: pyrimidine_metabolis_train_1990.csv
# Copied: other_types_of_o-gly_train_2394.csv
# Copied: pyruvate_metabolism_train_2623.csv
# Copied: glycosphingolipid_bi_(1)_train_3112.csv
# Copied: mucin_type_o-glycan__train_5398.csv
# Copied: metabolism_of_xenobi_train_5605.csv
# Copied: n-glycan_biosynthesi_train_2873.csv
# Copied: steroid_hormone_bios_train_4468.csv
# Copied: starch_and_sucrose_m_train_2356.csv
# Copied: butirosin_and_neomyc_train_6864.csv
# Copied: butanoate_metabolism_train_4180.csv
# Copied: lipoic_acid_metaboli_train_5732.csv
# Copied: glyoxylate_and_dicar_train_7549.csv
# Copied: starch_and_sucrose_m_train_5329.csv
# Copied: primary_bile_acid_bi_train_4704.csv
# Copied: lipoic_acid_metaboli_train_8541.csv
# Copied: aminoacyl-trna_biosy_train_3815.csv
# Copied: tryptophan_metabolis_train_6412.csv
# Copied: biosynthesis_of_unsa_train_9439.csv
# Copied: pentose_phosphate_pa_train_1506.csv
# Copied: folate_biosynthesis_train_4994.csv
# Copied: glyoxylate_and_dicar_train_9556.csv
# Copied: cyanoamino_acid_meta_train_3747.csv
# Copied: glycosylphosphatidyl_train_8928.csv
# Copied: caffeine_metabolism_train_9692.csv
# Copied: drug_metabolism_-_cy_train_7684.csv
# Copied: one_carbon_pool_by_f_train_1671.csv
# Copied: valine,_leucine_and__train_7204.csv
# Copied: vitamin_b6_metabolis_train_6075.csv
# Copied: vitamin_b6_metabolis_train_2567.csv
# Copied: phenylalanine,_tyros_train_2296.csv
# Copied: fatty_acid_biosynthe_train_9579.csv
# Copied: glycosphingolipid_bi_(1)_train_1944.csv
# Copied: vitamin_b6_metabolis_train_3761.csv
# Copied: n-glycan_biosynthesi_train_1584.csv
# Copied: caffeine_metabolism_train_4536.csv
# Copied: one_carbon_pool_by_f_train_4656.csv
# Copied: nitrogen_metabolism_train_9511.csv
# Copied: cysteine_and_methion_train_3400.csv
# Copied: drug_metabolism_-_cy_train_3545.csv
# Copied: lysine_degradation_train_1177.csv
# Copied: lipoic_acid_metaboli_train_8800.csv
# Copied: glycosphingolipid_bi_train_5121.csv
# Copied: valine,_leucine_and__train_6172.csv
# Copied: amino_sugar_and_nucl_train_1494.csv
# Copied: sphingolipid_metabol_train_7417.csv
# Copied: glycosaminoglycan_bi_(1)_train_5286.csv
# Copied: steroid_hormone_bios_train_6668.csv
# Copied: pyrimidine_metabolis_train_7241.csv
# Copied: tyrosine_metabolism_train_8180.csv
# Copied: glycosphingolipid_bi_(2)_train_3085.csv
# Copied: inositol_phosphate_m_train_5151.csv
# Copied: aminoacyl-trna_biosy_train_9784.csv
# Copied: other_types_of_o-gly_train_2494.csv
# Copied: drug_metabolism_-_ot_train_5565.csv
# Copied: retinol_metabolism_train_8393.csv
# Copied: phenylalanine_metabo_train_7995.csv
# Copied: beta-alanine_metabol_train_7864.csv
# Copied: retinol_metabolism_train_3941.csv
# Copied: thiamine_metabolism_train_4084.csv
# Copied: caffeine_metabolism_train_8310.csv
# Copied: caffeine_metabolism_train_6505.csv
# Copied: lysine_degradation_train_8293.csv
# Copied: cyanoamino_acid_meta_train_9451.csv
# Copied: inositol_phosphate_m_train_9162.csv
# Copied: fructose_and_mannose_train_1904.csv
# Copied: glycolysis___glucone_train_2851.csv
# Copied: citrate_cycle_(tca_c_train_3071.csv
# Copied: pyruvate_metabolism_train_4916.csv
# Copied: citrate_cycle_(tca_c_train_2573.csv
# Copied: nitrogen_metabolism_train_4204.csv
# Copied: glycosaminoglycan_de_train_4714.csv
# Copied: inositol_phosphate_m_train_3161.csv
# Copied: biosynthesis_of_unsa_train_6279.csv
# Copied: pyrimidine_metabolis_train_5903.csv
# Copied: lysine_biosynthesis_train_9154.csv
# Copied: ascorbate_and_aldara_train_6755.csv
# Copied: histidine_metabolism_train_1209.csv
# Copied: mucin_type_o-glycan__train_8983.csv
# Copied: glycerolipid_metabol_train_7776.csv
# Copied: histidine_metabolism_train_2211.csv
# Copied: ubiquinone_and_other_train_7233.csv
# Copied: d-arginine_and_d-orn_train_3096.csv
# Copied: steroid_biosynthesis_train_9054.csv
# Copied: alpha-linolenic_acid_train_1854.csv
# Copied: pantothenate_and_coa_train_8645.csv
# Copied: one_carbon_pool_by_f_train_3699.csv
# Copied: glutathione_metaboli_train_3710.csv
# Copied: butirosin_and_neomyc_train_4159.csv
# Copied: amino_sugar_and_nucl_train_1703.csv
# Copied: glycine,_serine_and__train_8859.csv
# Copied: alpha-linolenic_acid_train_7454.csv
# Copied: folate_biosynthesis_train_5346.csv
# Copied: valine,_leucine_and__(1)_train_8676.csv
# Copied: folate_biosynthesis_train_8418.csv
# Copied: phenylalanine_metabo_train_1899.csv
# Copied: galactose_metabolism_train_7283.csv
# Copied: citrate_cycle_(tca_c_train_3195.csv
# Copied: ether_lipid_metaboli_train_6855.csv
# Copied: cyanoamino_acid_meta_train_5188.csv
# Copied: citrate_cycle_(tca_c_train_5290.csv
# Copied: butirosin_and_neomyc_train_1241.csv
# Copied: glycosphingolipid_bi_(1)_train_1917.csv
# Copied: amino_sugar_and_nucl_train_1225.csv
# Copied: n-glycan_biosynthesi_train_8163.csv
# Copied: arginine_and_proline_train_1355.csv
# Copied: glycosphingolipid_bi_(2)_train_6820.csv
# Copied: alpha-linolenic_acid_train_2371.csv
# Copied: linoleic_acid_metabo_train_9824.csv
# Copied: glycerolipid_metabol_train_6560.csv
# Copied: porphyrin_and_chloro_train_7647.csv
# Copied: glyoxylate_and_dicar_train_9051.csv
# Copied: ether_lipid_metaboli_train_3747.csv
# Copied: sulfur_metabolism_train_4864.csv
# Copied: galactose_metabolism_train_8272.csv
# Copied: sulfur_metabolism_train_8644.csv
# Copied: one_carbon_pool_by_f_train_1466.csv
# Copied: glycosaminoglycan_bi_train_7399.csv
# Copied: d-glutamine_and_d-gl_train_9192.csv
# Copied: porphyrin_and_chloro_train_5886.csv
# Copied: metabolism_of_xenobi_train_8796.csv
# Copied: vitamin_b6_metabolis_train_7692.csv
# Copied: nicotinate_and_nicot_train_1758.csv
# Copied: d-glutamine_and_d-gl_train_7147.csv
# Copied: glycosylphosphatidyl_train_3818.csv
# Copied: selenocompound_metab_train_7080.csv
# Copied: vitamin_b6_metabolis_train_3756.csv
# Copied: pyrimidine_metabolis_train_1615.csv
# Copied: ether_lipid_metaboli_train_4088.csv
# Copied: biotin_metabolism_train_9514.csv
# Copied: glycosylphosphatidyl_train_8703.csv
# Copied: ubiquinone_and_other_train_5477.csv
# Copied: alpha-linolenic_acid_train_5783.csv
# Copied: fatty_acid_elongatio_train_1228.csv
# Copied: riboflavin_metabolis_train_4823.csv
# Copied: cysteine_and_methion_train_7360.csv
# Copied: caffeine_metabolism_train_9240.csv
# Copied: synthesis_and_degrad_train_3187.csv
# Copied: glutathione_metaboli_train_7124.csv
# Copied: primary_bile_acid_bi_train_8404.csv
# Copied: glycine,_serine_and__train_9194.csv
# Copied: drug_metabolism_-_ot_train_1722.csv
# Copied: lysine_biosynthesis_train_8594.csv
# Copied: pantothenate_and_coa_train_8176.csv
# Copied: propanoate_metabolis_train_6395.csv
# Copied: porphyrin_and_chloro_train_4809.csv
# Copied: histidine_metabolism_train_4986.csv
# Copied: phenylalanine,_tyros_train_9302.csv
# Copied: terpenoid_backbone_b_train_6621.csv
# Copied: glycosylphosphatidyl_train_8203.csv
# Copied: glycine,_serine_and__train_9687.csv
# Copied: glycosaminoglycan_bi_train_9670.csv
# Copied: selenocompound_metab_train_8403.csv
# Copied: glycerolipid_metabol_train_3584.csv
# Copied: alpha-linolenic_acid_train_9373.csv
# Copied: fatty_acid_biosynthe_train_6304.csv
# Copied: biotin_metabolism_train_6078.csv
# Copied: pentose_and_glucuron_train_7711.csv
# Copied: alpha-linolenic_acid_train_5635.csv
# Copied: metabolism_of_xenobi_train_6798.csv
# Copied: glycine,_serine_and__train_4766.csv
# Copied: aminoacyl-trna_biosy_train_3887.csv
# Copied: lysine_degradation_train_5043.csv
# Copied: metabolism_of_xenobi_train_7505.csv
# Copied: d-arginine_and_d-orn_train_2204.csv
# Copied: lysine_degradation_train_3915.csv
# Copied: glycosaminoglycan_bi_train_9258.csv
# Copied: starch_and_sucrose_m_train_1473.csv
# Copied: biosynthesis_of_unsa_train_4552.csv
# Copied: linoleic_acid_metabo_train_9252.csv
# Copied: arachidonic_acid_met_train_5322.csv
# Copied: sulfur_metabolism_train_4762.csv
# Copied: fatty_acid_biosynthe_train_7456.csv
# Copied: valine,_leucine_and__train_7776.csv
# Copied: glycosaminoglycan_bi_(1)_train_7496.csv
# Copied: butanoate_metabolism_train_1100.csv
# Copied: porphyrin_and_chloro_train_8022.csv
# Copied: butanoate_metabolism_train_1491.csv
# Copied: butanoate_metabolism_train_8350.csv
# Copied: beta-alanine_metabol_train_7014.csv
# Copied: steroid_biosynthesis_train_5609.csv
# Copied: nitrogen_metabolism_train_7075.csv
# Copied: drug_metabolism_-_cy_train_7643.csv
# Copied: pyrimidine_metabolis_train_1423.csv
# Copied: valine,_leucine_and__(1)_train_6589.csv
# Copied: drug_metabolism_-_ot_train_8702.csv
# Copied: n-glycan_biosynthesi_train_1885.csv
# Copied: terpenoid_backbone_b_train_2152.csv
# Copied: one_carbon_pool_by_f_train_1293.csv
# Copied: drug_metabolism_-_cy_train_7207.csv
# Copied: fatty_acid_biosynthe_train_8014.csv
# Copied: retinol_metabolism_train_3755.csv
# Copied: valine,_leucine_and__(1)_train_9761.csv
# Copied: valine,_leucine_and__(1)_train_3551.csv
# Copied: glycine,_serine_and__train_1578.csv
# Copied: pantothenate_and_coa_train_8164.csv
# Copied: metabolism_of_xenobi_train_3385.csv
# Copied: glycosylphosphatidyl_train_5632.csv
# Copied: primary_bile_acid_bi_train_9990.csv
# Copied: inositol_phosphate_m_train_4787.csv
# Copied: propanoate_metabolis_train_4916.csv
# Copied: selenocompound_metab_train_8078.csv
# Copied: lipoic_acid_metaboli_train_8395.csv
# Copied: lipoic_acid_metaboli_train_1385.csv
# Copied: glycosphingolipid_bi_(2)_train_1226.csv
# Copied: purine_metabolism_train_3657.csv
# Copied: butanoate_metabolism_train_4460.csv
# Copied: propanoate_metabolis_train_2520.csv
# Copied: metabolism_of_xenobi_train_5862.csv
# Copied: nitrogen_metabolism_train_7440.csv
# Copied: cysteine_and_methion_train_3415.csv
# Copied: purine_metabolism_train_1425.csv
# Copied: phenylalanine_metabo_train_9455.csv
# Copied: glycine,_serine_and__train_8019.csv
# Copied: butanoate_metabolism_train_5284.csv
# Copied: other_types_of_o-gly_train_2893.csv
# Copied: citrate_cycle_(tca_c_train_8698.csv
# Copied: glycosphingolipid_bi_train_2926.csv
# Copied: inositol_phosphate_m_train_5254.csv
# Copied: valine,_leucine_and__(1)_train_1008.csv
# Copied: histidine_metabolism_train_8687.csv
# Copied: glycosylphosphatidyl_train_2533.csv
# Copied: fatty_acid_biosynthe_train_1749.csv
# Copied: tryptophan_metabolis_train_3266.csv
# Copied: fatty_acid_elongatio_train_6374.csv
# Copied: other_types_of_o-gly_train_8552.csv
# Copied: biotin_metabolism_train_7625.csv
# Copied: glycosphingolipid_bi_(1)_train_9537.csv
# Copied: fatty_acid_biosynthe_train_8694.csv
# Copied: n-glycan_biosynthesi_train_9661.csv
# Copied: sphingolipid_metabol_train_7670.csv
# Copied: glycosaminoglycan_bi_(1)_train_6364.csv
# Copied: taurine_and_hypotaur_train_2505.csv
# Copied: ubiquinone_and_other_train_9396.csv
# Copied: terpenoid_backbone_b_train_3241.csv
# Copied: pentose_and_glucuron_train_6872.csv
# Copied: d-glutamine_and_d-gl_train_3853.csv
# Copied: lysine_biosynthesis_train_8442.csv
# Copied: pantothenate_and_coa_train_7239.csv
# Copied: cysteine_and_methion_train_9500.csv
# Copied: amino_sugar_and_nucl_train_1775.csv
# Copied: glycosaminoglycan_bi_(1)_train_4029.csv
# Copied: fatty_acid_degradati_train_2978.csv
# Copied: valine,_leucine_and__train_7495.csv
# Copied: arachidonic_acid_met_train_8539.csv
# Copied: one_carbon_pool_by_f_train_1656.csv
# Copied: aminoacyl-trna_biosy_train_7666.csv
# Copied: sulfur_metabolism_train_9149.csv
# Copied: cyanoamino_acid_meta_train_8701.csv
# Copied: alanine,_aspartate_a_train_6727.csv
# Copied: terpenoid_backbone_b_train_8661.csv
# Copied: nicotinate_and_nicot_train_4621.csv
# Copied: glycerophospholipid__train_8627.csv
# Copied: alanine,_aspartate_a_train_3711.csv
# Copied: pentose_and_glucuron_train_5923.csv
# Copied: valine,_leucine_and__(1)_train_9079.csv
# Copied: glycosphingolipid_bi_(1)_train_6175.csv
# Copied: valine,_leucine_and__(1)_train_5467.csv
# Copied: glycosphingolipid_bi_(1)_train_4541.csv
# Copied: synthesis_and_degrad_train_6205.csv
# Copied: arginine_and_proline_train_1159.csv
# Copied: mucin_type_o-glycan__train_7529.csv
# Copied: pentose_and_glucuron_train_3424.csv
# Copied: glycosaminoglycan_bi_(1)_train_4603.csv
# Copied: primary_bile_acid_bi_train_3795.csv
# Copied: galactose_metabolism_train_3584.csv
# Copied: glycosphingolipid_bi_train_8993.csv
# Copied: linoleic_acid_metabo_train_8653.csv
# Copied: drug_metabolism_-_ot_train_1108.csv
# Copied: thiamine_metabolism_train_6802.csv
# Copied: butirosin_and_neomyc_train_9691.csv
# Copied: pentose_phosphate_pa_train_1855.csv
# Copied: glycosaminoglycan_bi_train_6131.csv

# %%
folder_path = 'gnn-train-split-samples'
files = os.listdir(folder_path)
num_files = len(files)
print(f"Total files: {num_files}")
# Out:
# Total files: 656
