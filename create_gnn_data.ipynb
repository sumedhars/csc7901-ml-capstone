# %%
import torch
import torch.nn.functional as F
from torch import nn
from torch_geometric.nn import EdgeConv, NNConv
from torch_geometric.data import Data, DataLoader

# %%
import pandas as pd
import os

# %% [markdown]
# ### Load training samples

# %%
files = os.listdir('training-samples')
files = [f for f in files if os.path.isfile('training-samples'+'/'+f)]
len(files)
# Out:
# 820

# %% [markdown]
# ### Data Preparation for GNN

# %% [markdown]
# - `edge_attr`: GNN Layer can use edge feature
#     - Edge feature matrix with shape `[num_edges, num_edge_features]`
# - `edge_index`: Graph connectivity with shape `[2, num_edges]`
#
# References: https://pytorch-geometric.readthedocs.io/en/2.6.0/get_started/introduction.html#data-handling-of-graphs

# %% [markdown]
# **Create Node Label to Integer Index Mapping**
# - Extract all unique node labels from dataset (can get this from `union_ppi`)
# - Create dictionary that maps each label to a unique integer index

# %%
union_ppi = pd.read_csv('processed-data/union_ppi.txt', sep='\t', header=None)
unique_nodes = set(union_ppi[0].tolist() + union_ppi[1].tolist())

# %%
# build mapping for label -> int ID
label_id_map = {label: idx for idx, label in enumerate(sorted(unique_nodes))}
num_nodes = len(label_id_map)
print(f"Total unique nodes: {num_nodes}")
# Out:
# Total unique nodes: 17407

# %% [markdown]
# **Build the `Data` objects - one for each training sample**

# %%
data_folder = 'training-samples/'
data_list = []

for training_sample in files:
    print('Processing: ', training_sample)
    training_df = pd.read_csv(os.path.join(data_folder, training_sample), sep='\t')
    training_data = training_df.values.tolist()
    
    edge_index_list = [[], []]
    edge_attr_list = []  # each edge attribute: [prize]
    edge_labels = []     # this will get passed as data.y
    selected_edges = []  # store indices of nodes for edges with label 1

    for data_sample in training_data:
        node1, node2, prize, flag, label = data_sample
        idx1 = label_id_map[node1]
        idx2 = label_id_map[node2]
        edge_index_list[0].append(idx1)
        edge_index_list[1].append(idx2)
        edge_attr_list.append([prize])
        edge_labels.append(label)
        
        # if edge label = 1, then record its nodes
        if label == 1:
            selected_edges.append((idx1, idx2))
    
    # lists -> torch tensors
    edge_index = torch.tensor(edge_index_list, dtype=torch.long)
    edge_attr = torch.tensor(edge_attr_list, dtype=torch.float)
    edge_labels = torch.tensor(edge_labels, dtype=torch.float).view(-1, 1)
    
    # init node features: one feature per node (0 by default)
    num_nodes = len(label_id_map)
    x = torch.zeros((num_nodes, 1), dtype=torch.float)
    
    # update node features - mark nodes as 1 if they are connected by a selected edge
    for idx1, idx2 in selected_edges:
        x[idx1] = 1
        x[idx2] = 1
    
    data_obj = Data(x=x, edge_index=edge_index, edge_attr=edge_attr, y=edge_labels)
    data_obj.file_name = training_sample
    data_list.append(data_obj)
# Out:
# Processing:  alanine__aspartate_a_train_2535.csv
# Processing:  alanine__aspartate_a_train_3273.csv
# Processing:  alanine__aspartate_a_train_3711.csv
# Processing:  alanine__aspartate_a_train_3781.csv
# Processing:  alanine__aspartate_a_train_6130.csv
# Processing:  alanine__aspartate_a_train_6672.csv
# Processing:  alanine__aspartate_a_train_6727.csv
# Processing:  alanine__aspartate_a_train_8527.csv
# Processing:  alanine__aspartate_a_train_9941.csv
# Processing:  alpha_linolenic_acid_train_1854.csv
# Processing:  alpha_linolenic_acid_train_2371.csv
# Processing:  alpha_linolenic_acid_train_4263.csv
# Processing:  alpha_linolenic_acid_train_4939.csv
# Processing:  alpha_linolenic_acid_train_5635.csv
# Processing:  alpha_linolenic_acid_train_5783.csv
# Processing:  alpha_linolenic_acid_train_6633.csv
# Processing:  alpha_linolenic_acid_train_7454.csv
# Processing:  alpha_linolenic_acid_train_9373.csv
# Processing:  alpha_linolenic_acid_train_9806.csv
# Processing:  aminoacyl_trna_biosy_train_1565.csv
# Processing:  aminoacyl_trna_biosy_train_2796.csv
# Processing:  aminoacyl_trna_biosy_train_3815.csv
# Processing:  aminoacyl_trna_biosy_train_3887.csv
# Processing:  aminoacyl_trna_biosy_train_4856.csv
# Processing:  aminoacyl_trna_biosy_train_5281.csv
# Processing:  aminoacyl_trna_biosy_train_5354.csv
# Processing:  aminoacyl_trna_biosy_train_7666.csv
# Processing:  aminoacyl_trna_biosy_train_8954.csv
# Processing:  aminoacyl_trna_biosy_train_9784.csv
# Processing:  beta_alanine_metabol_train_2559.csv
# Processing:  amino_sugar_and_nucl_train_1225.csv
# Processing:  amino_sugar_and_nucl_train_1494.csv
# Processing:  amino_sugar_and_nucl_train_1699.csv
# Processing:  amino_sugar_and_nucl_train_1703.csv
# Processing:  amino_sugar_and_nucl_train_1775.csv
# Processing:  amino_sugar_and_nucl_train_2444.csv
# Processing:  amino_sugar_and_nucl_train_3796.csv
# Processing:  amino_sugar_and_nucl_train_5376.csv
# Processing:  amino_sugar_and_nucl_train_6644.csv
# Processing:  amino_sugar_and_nucl_train_9691.csv
# Processing:  arachidonic_acid_met_train_1279.csv
# Processing:  arachidonic_acid_met_train_1685.csv
# Processing:  arachidonic_acid_met_train_2867.csv
# Processing:  arachidonic_acid_met_train_2983.csv
# Processing:  arachidonic_acid_met_train_3457.csv
# Processing:  arachidonic_acid_met_train_3652.csv
# Processing:  arachidonic_acid_met_train_4290.csv
# Processing:  arachidonic_acid_met_train_5322.csv
# Processing:  arachidonic_acid_met_train_6149.csv
# Processing:  arachidonic_acid_met_train_8539.csv
# Processing:  arginine_and_proline_train_1159.csv
# Processing:  arginine_and_proline_train_1355.csv
# Processing:  arginine_and_proline_train_1599.csv
# Processing:  arginine_and_proline_train_2834.csv
# Processing:  arginine_and_proline_train_3611.csv
# Processing:  arginine_and_proline_train_4399.csv
# Processing:  arginine_and_proline_train_4664.csv
# Processing:  arginine_and_proline_train_7047.csv
# Processing:  arginine_and_proline_train_8211.csv
# Processing:  arginine_and_proline_train_9140.csv
# Processing:  ascorbate_and_aldara_train_1853.csv
# Processing:  ascorbate_and_aldara_train_3317.csv
# Processing:  ascorbate_and_aldara_train_5955.csv
# Processing:  ascorbate_and_aldara_train_6755.csv
# Processing:  ascorbate_and_aldara_train_7481.csv
# Processing:  ascorbate_and_aldara_train_8171.csv
# Processing:  ascorbate_and_aldara_train_8253.csv
# Processing:  ascorbate_and_aldara_train_8407.csv
# Processing:  ascorbate_and_aldara_train_8501.csv
# Processing:  ascorbate_and_aldara_train_9303.csv
# Processing:  beta_alanine_metabol_train_2705.csv
# Processing:  beta_alanine_metabol_train_3310.csv
# Processing:  beta_alanine_metabol_train_4217.csv
# Processing:  beta_alanine_metabol_train_7014.csv
# Processing:  beta_alanine_metabol_train_7183.csv
# Processing:  beta_alanine_metabol_train_7581.csv
# Processing:  beta_alanine_metabol_train_7864.csv
# Processing:  beta_alanine_metabol_train_7979.csv
# Processing:  beta_alanine_metabol_train_8672.csv
# Processing:  citrate_cycle__tca_c_train_2573.csv
# Processing:  biosynthesis_of_unsa_train_2748.csv
# Processing:  biosynthesis_of_unsa_train_3280.csv
# Processing:  biosynthesis_of_unsa_train_3803.csv
# Processing:  biosynthesis_of_unsa_train_4552.csv
# Processing:  biosynthesis_of_unsa_train_4673.csv
# Processing:  biosynthesis_of_unsa_train_4693.csv
# Processing:  biosynthesis_of_unsa_train_5667.csv
# Processing:  biosynthesis_of_unsa_train_6279.csv
# Processing:  biosynthesis_of_unsa_train_6470.csv
# Processing:  biosynthesis_of_unsa_train_9439.csv
# Processing:  biotin_metabolism_train_1902.csv
# Processing:  biotin_metabolism_train_2424.csv
# Processing:  biotin_metabolism_train_3135.csv
# Processing:  biotin_metabolism_train_6078.csv
# Processing:  biotin_metabolism_train_6989.csv
# Processing:  biotin_metabolism_train_7622.csv
# Processing:  biotin_metabolism_train_7625.csv
# Processing:  biotin_metabolism_train_7733.csv
# Processing:  biotin_metabolism_train_8673.csv
# Processing:  biotin_metabolism_train_9514.csv
# Processing:  butanoate_metabolism_train_1100.csv
# Processing:  butanoate_metabolism_train_1491.csv
# Processing:  butanoate_metabolism_train_4180.csv
# Processing:  butanoate_metabolism_train_4190.csv
# Processing:  butanoate_metabolism_train_4460.csv
# Processing:  butanoate_metabolism_train_5284.csv
# Processing:  butanoate_metabolism_train_5885.csv
# Processing:  butanoate_metabolism_train_6334.csv
# Processing:  butanoate_metabolism_train_8350.csv
# Processing:  butanoate_metabolism_train_8741.csv
# Processing:  butirosin_and_neomyc_train_1241.csv
# Processing:  butirosin_and_neomyc_train_1721.csv
# Processing:  butirosin_and_neomyc_train_2981.csv
# Processing:  butirosin_and_neomyc_train_4135.csv
# Processing:  butirosin_and_neomyc_train_4159.csv
# Processing:  butirosin_and_neomyc_train_4999.csv
# Processing:  butirosin_and_neomyc_train_5617.csv
# Processing:  butirosin_and_neomyc_train_6864.csv
# Processing:  butirosin_and_neomyc_train_7673.csv
# Processing:  butirosin_and_neomyc_train_9691.csv
# Processing:  caffeine_metabolism_train_1005.csv
# Processing:  caffeine_metabolism_train_3176.csv
# Processing:  caffeine_metabolism_train_3718.csv
# Processing:  caffeine_metabolism_train_4187.csv
# Processing:  caffeine_metabolism_train_4536.csv
# Processing:  caffeine_metabolism_train_4696.csv
# Processing:  caffeine_metabolism_train_6505.csv
# Processing:  caffeine_metabolism_train_8310.csv
# Processing:  caffeine_metabolism_train_9240.csv
# Processing:  caffeine_metabolism_train_9692.csv
# Processing:  citrate_cycle__tca_c_train_3071.csv
# Processing:  citrate_cycle__tca_c_train_3195.csv
# Processing:  citrate_cycle__tca_c_train_5290.csv
# Processing:  citrate_cycle__tca_c_train_5392.csv
# Processing:  citrate_cycle__tca_c_train_5519.csv
# Processing:  citrate_cycle__tca_c_train_6720.csv
# Processing:  citrate_cycle__tca_c_train_6943.csv
# Processing:  citrate_cycle__tca_c_train_8425.csv
# Processing:  citrate_cycle__tca_c_train_8698.csv
# Processing:  d_arginine_and_d_orn_train_1815.csv
# Processing:  cyanoamino_acid_meta_train_2368.csv
# Processing:  cyanoamino_acid_meta_train_2915.csv
# Processing:  cyanoamino_acid_meta_train_3267.csv
# Processing:  cyanoamino_acid_meta_train_3747.csv
# Processing:  cyanoamino_acid_meta_train_5188.csv
# Processing:  cyanoamino_acid_meta_train_7427.csv
# Processing:  cyanoamino_acid_meta_train_8701.csv
# Processing:  cyanoamino_acid_meta_train_8714.csv
# Processing:  cyanoamino_acid_meta_train_8911.csv
# Processing:  cyanoamino_acid_meta_train_9451.csv
# Processing:  cysteine_and_methion_train_2826.csv
# Processing:  cysteine_and_methion_train_3400.csv
# Processing:  cysteine_and_methion_train_3415.csv
# Processing:  cysteine_and_methion_train_3585.csv
# Processing:  cysteine_and_methion_train_5119.csv
# Processing:  cysteine_and_methion_train_7360.csv
# Processing:  cysteine_and_methion_train_8208.csv
# Processing:  cysteine_and_methion_train_8285.csv
# Processing:  cysteine_and_methion_train_8949.csv
# Processing:  cysteine_and_methion_train_9500.csv
# Processing:  d_arginine_and_d_orn_train_2204.csv
# Processing:  d_arginine_and_d_orn_train_3096.csv
# Processing:  d_arginine_and_d_orn_train_3362.csv
# Processing:  d_arginine_and_d_orn_train_4582.csv
# Processing:  d_arginine_and_d_orn_train_4827.csv
# Processing:  d_arginine_and_d_orn_train_5224.csv
# Processing:  d_arginine_and_d_orn_train_6276.csv
# Processing:  d_arginine_and_d_orn_train_6400.csv
# Processing:  d_arginine_and_d_orn_train_8863.csv
# Processing:  d_glutamine_and_d_gl_train_3853.csv
# Processing:  d_glutamine_and_d_gl_train_5918.csv
# Processing:  d_glutamine_and_d_gl_train_6415.csv
# Processing:  d_glutamine_and_d_gl_train_6453.csv
# Processing:  d_glutamine_and_d_gl_train_6575.csv
# Processing:  d_glutamine_and_d_gl_train_7147.csv
# Processing:  d_glutamine_and_d_gl_train_7653.csv
# Processing:  d_glutamine_and_d_gl_train_8627.csv
# Processing:  d_glutamine_and_d_gl_train_9192.csv
# Processing:  d_glutamine_and_d_gl_train_9381.csv
# Processing:  drug_metabolism___cy_train_1576.csv
# Processing:  drug_metabolism___cy_train_2581.csv
# Processing:  drug_metabolism___cy_train_2665.csv
# Processing:  drug_metabolism___cy_train_3545.csv
# Processing:  drug_metabolism___cy_train_4503.csv
# Processing:  drug_metabolism___cy_train_6262.csv
# Processing:  drug_metabolism___cy_train_7207.csv
# Processing:  drug_metabolism___cy_train_7291.csv
# Processing:  drug_metabolism___cy_train_7643.csv
# Processing:  drug_metabolism___cy_train_7684.csv
# Processing:  drug_metabolism___ot_train_1108.csv
# Processing:  drug_metabolism___ot_train_1722.csv
# Processing:  drug_metabolism___ot_train_1801.csv
# Processing:  drug_metabolism___ot_train_4485.csv
# Processing:  drug_metabolism___ot_train_5565.csv
# Processing:  drug_metabolism___ot_train_6155.csv
# Processing:  drug_metabolism___ot_train_6253.csv
# Processing:  drug_metabolism___ot_train_6288.csv
# Processing:  drug_metabolism___ot_train_8702.csv
# Processing:  drug_metabolism___ot_train_9953.csv
# Processing:  glycerophospholipid_train_1191.csv
# Processing:  ether_lipid_metaboli_train_1598.csv
# Processing:  ether_lipid_metaboli_train_2397.csv
# Processing:  ether_lipid_metaboli_train_3063.csv
# Processing:  ether_lipid_metaboli_train_3321.csv
# Processing:  ether_lipid_metaboli_train_3747.csv
# Processing:  ether_lipid_metaboli_train_4088.csv
# Processing:  ether_lipid_metaboli_train_4815.csv
# Processing:  ether_lipid_metaboli_train_6855.csv
# Processing:  ether_lipid_metaboli_train_7450.csv
# Processing:  ether_lipid_metaboli_train_9182.csv
# Processing:  fatty_acid_biosynthe_train_1183.csv
# Processing:  fatty_acid_biosynthe_train_1363.csv
# Processing:  fatty_acid_biosynthe_train_1749.csv
# Processing:  fatty_acid_biosynthe_train_6264.csv
# Processing:  fatty_acid_biosynthe_train_6304.csv
# Processing:  fatty_acid_biosynthe_train_7404.csv
# Processing:  fatty_acid_biosynthe_train_7456.csv
# Processing:  fatty_acid_biosynthe_train_8014.csv
# Processing:  fatty_acid_biosynthe_train_8694.csv
# Processing:  fatty_acid_biosynthe_train_9579.csv
# Processing:  fatty_acid_degradati_train_2123.csv
# Processing:  fatty_acid_degradati_train_2826.csv
# Processing:  fatty_acid_degradati_train_2865.csv
# Processing:  fatty_acid_degradati_train_2978.csv
# Processing:  fatty_acid_degradati_train_3240.csv
# Processing:  fatty_acid_degradati_train_3405.csv
# Processing:  fatty_acid_degradati_train_4206.csv
# Processing:  fatty_acid_degradati_train_7616.csv
# Processing:  fatty_acid_degradati_train_8270.csv
# Processing:  fatty_acid_degradati_train_8271.csv
# Processing:  fatty_acid_elongatio_train_1228.csv
# Processing:  fatty_acid_elongatio_train_2789.csv
# Processing:  fatty_acid_elongatio_train_3530.csv
# Processing:  fatty_acid_elongatio_train_3978.csv
# Processing:  fatty_acid_elongatio_train_4051.csv
# Processing:  fatty_acid_elongatio_train_4296.csv
# Processing:  fatty_acid_elongatio_train_6026.csv
# Processing:  fatty_acid_elongatio_train_6374.csv
# Processing:  fatty_acid_elongatio_train_7460.csv
# Processing:  fatty_acid_elongatio_train_7810.csv
# Processing:  folate_biosynthesis_train_3178.csv
# Processing:  folate_biosynthesis_train_3931.csv
# Processing:  folate_biosynthesis_train_4994.csv
# Processing:  folate_biosynthesis_train_5097.csv
# Processing:  folate_biosynthesis_train_5346.csv
# Processing:  folate_biosynthesis_train_5773.csv
# Processing:  folate_biosynthesis_train_8418.csv
# Processing:  folate_biosynthesis_train_8579.csv
# Processing:  folate_biosynthesis_train_9363.csv
# Processing:  folate_biosynthesis_train_9494.csv
# Processing:  fructose_and_mannose_train_1791.csv
# Processing:  fructose_and_mannose_train_1904.csv
# Processing:  fructose_and_mannose_train_5194.csv
# Processing:  fructose_and_mannose_train_5404.csv
# Processing:  fructose_and_mannose_train_6210.csv
# Processing:  fructose_and_mannose_train_6584.csv
# Processing:  fructose_and_mannose_train_6794.csv
# Processing:  fructose_and_mannose_train_8580.csv
# Processing:  fructose_and_mannose_train_9217.csv
# Processing:  fructose_and_mannose_train_9475.csv
# Processing:  galactose_metabolism_train_1510.csv
# Processing:  galactose_metabolism_train_2135.csv
# Processing:  galactose_metabolism_train_3584.csv
# Processing:  galactose_metabolism_train_4572.csv
# Processing:  galactose_metabolism_train_4802.csv
# Processing:  galactose_metabolism_train_4880.csv
# Processing:  galactose_metabolism_train_5798.csv
# Processing:  galactose_metabolism_train_7283.csv
# Processing:  galactose_metabolism_train_8272.csv
# Processing:  galactose_metabolism_train_8430.csv
# Processing:  glutathione_metaboli_train_1578.csv
# Processing:  glutathione_metaboli_train_1590.csv
# Processing:  glutathione_metaboli_train_2142.csv
# Processing:  glutathione_metaboli_train_3693.csv
# Processing:  glutathione_metaboli_train_3710.csv
# Processing:  glutathione_metaboli_train_4039.csv
# Processing:  glutathione_metaboli_train_4479.csv
# Processing:  glutathione_metaboli_train_5956.csv
# Processing:  glutathione_metaboli_train_7124.csv
# Processing:  glutathione_metaboli_train_8472.csv
# Processing:  glycerolipid_metabol_train_1672.csv
# Processing:  glycerolipid_metabol_train_3584.csv
# Processing:  glycerolipid_metabol_train_4441.csv
# Processing:  glycerolipid_metabol_train_4745.csv
# Processing:  glycerolipid_metabol_train_5382.csv
# Processing:  glycerolipid_metabol_train_5932.csv
# Processing:  glycerolipid_metabol_train_6242.csv
# Processing:  glycerolipid_metabol_train_6560.csv
# Processing:  glycerolipid_metabol_train_7776.csv
# Processing:  glycerolipid_metabol_train_8006.csv
# Processing:  glycerophospholipid_train_2901.csv
# Processing:  glycerophospholipid_train_3243.csv
# Processing:  glycerophospholipid_train_3822.csv
# Processing:  glycerophospholipid_train_5031.csv
# Processing:  glycerophospholipid_train_6257.csv
# Processing:  glycerophospholipid_train_8627.csv
# Processing:  glycerophospholipid_train_8885.csv
# Processing:  glycerophospholipid_train_9385.csv
# Processing:  glycerophospholipid_train_9901.csv
# Processing:  glycine__serine_and_train_1327.csv
# Processing:  glycine__serine_and_train_1578.csv
# Processing:  glycine__serine_and_train_4766.csv
# Processing:  glycine__serine_and_train_6145.csv
# Processing:  glycine__serine_and_train_8019.csv
# Processing:  glycine__serine_and_train_8569.csv
# Processing:  glycine__serine_and_train_8859.csv
# Processing:  glycine__serine_and_train_8905.csv
# Processing:  glycine__serine_and_train_9194.csv
# Processing:  glycine__serine_and_train_9687.csv
# Processing:  glycosaminoglycan_bi__1_train_4029.csv
# Processing:  glycolysis___glucone_train_2851.csv
# Processing:  glycolysis___glucone_train_3045.csv
# Processing:  glycolysis___glucone_train_3272.csv
# Processing:  glycolysis___glucone_train_3351.csv
# Processing:  glycolysis___glucone_train_7341.csv
# Processing:  glycolysis___glucone_train_7813.csv
# Processing:  glycolysis___glucone_train_8450.csv
# Processing:  glycolysis___glucone_train_9461.csv
# Processing:  glycolysis___glucone_train_9576.csv
# Processing:  glycolysis___glucone_train_9972.csv
# Processing:  glycosaminoglycan_bi__1_train_4067.csv
# Processing:  glycosaminoglycan_bi__1_train_4495.csv
# Processing:  glycosaminoglycan_bi__1_train_4603.csv
# Processing:  glycosaminoglycan_bi__1_train_5286.csv
# Processing:  glycosaminoglycan_bi__1_train_5476.csv
# Processing:  glycosaminoglycan_bi__1_train_6041.csv
# Processing:  glycosaminoglycan_bi__1_train_6364.csv
# Processing:  glycosaminoglycan_bi__1_train_6852.csv
# Processing:  glycosaminoglycan_bi__1_train_7496.csv
# Processing:  glycosphingolipid_bi__1_train_1917.csv
# Processing:  glycosaminoglycan_bi_train_2241.csv
# Processing:  glycosaminoglycan_bi_train_4526.csv
# Processing:  glycosaminoglycan_bi_train_6131.csv
# Processing:  glycosaminoglycan_bi_train_6194.csv
# Processing:  glycosaminoglycan_bi_train_7399.csv
# Processing:  glycosaminoglycan_bi_train_7747.csv
# Processing:  glycosaminoglycan_bi_train_8023.csv
# Processing:  glycosaminoglycan_bi_train_9258.csv
# Processing:  glycosaminoglycan_bi_train_9612.csv
# Processing:  glycosaminoglycan_bi_train_9670.csv
# Processing:  glycosaminoglycan_de_train_1224.csv
# Processing:  glycosaminoglycan_de_train_1711.csv
# Processing:  glycosaminoglycan_de_train_2488.csv
# Processing:  glycosaminoglycan_de_train_3162.csv
# Processing:  glycosaminoglycan_de_train_3395.csv
# Processing:  glycosaminoglycan_de_train_4549.csv
# Processing:  glycosaminoglycan_de_train_4714.csv
# Processing:  glycosaminoglycan_de_train_7274.csv
# Processing:  glycosaminoglycan_de_train_8470.csv
# Processing:  glycosaminoglycan_de_train_9198.csv
# Processing:  glycosphingolipid_bi__1_train_1944.csv
# Processing:  glycosphingolipid_bi__1_train_2264.csv
# Processing:  glycosphingolipid_bi__1_train_2271.csv
# Processing:  glycosphingolipid_bi__1_train_3112.csv
# Processing:  glycosphingolipid_bi__1_train_4340.csv
# Processing:  glycosphingolipid_bi__1_train_4541.csv
# Processing:  glycosphingolipid_bi__1_train_6175.csv
# Processing:  glycosphingolipid_bi__1_train_8148.csv
# Processing:  glycosphingolipid_bi__1_train_9537.csv
# Processing:  glycosphingolipid_bi__2_train_1226.csv
# Processing:  glycosphingolipid_bi__2_train_1757.csv
# Processing:  glycosphingolipid_bi__2_train_2594.csv
# Processing:  glycosphingolipid_bi__2_train_3085.csv
# Processing:  glycosphingolipid_bi__2_train_4272.csv
# Processing:  glycosphingolipid_bi__2_train_4472.csv
# Processing:  glycosphingolipid_bi__2_train_6820.csv
# Processing:  glycosphingolipid_bi__2_train_7576.csv
# Processing:  glycosphingolipid_bi__2_train_7608.csv
# Processing:  glycosphingolipid_bi__2_train_9384.csv
# Processing:  mucin_type_o_glycan_train_1207.csv
# Processing:  glycosphingolipid_bi_train_2504.csv
# Processing:  glycosphingolipid_bi_train_2926.csv
# Processing:  glycosphingolipid_bi_train_4181.csv
# Processing:  glycosphingolipid_bi_train_4993.csv
# Processing:  glycosphingolipid_bi_train_5121.csv
# Processing:  glycosphingolipid_bi_train_5557.csv
# Processing:  glycosphingolipid_bi_train_7369.csv
# Processing:  glycosphingolipid_bi_train_7507.csv
# Processing:  glycosphingolipid_bi_train_8993.csv
# Processing:  glycosphingolipid_bi_train_9168.csv
# Processing:  glycosylphosphatidyl_train_2059.csv
# Processing:  glycosylphosphatidyl_train_2533.csv
# Processing:  glycosylphosphatidyl_train_3575.csv
# Processing:  glycosylphosphatidyl_train_3818.csv
# Processing:  glycosylphosphatidyl_train_5632.csv
# Processing:  glycosylphosphatidyl_train_6909.csv
# Processing:  glycosylphosphatidyl_train_7490.csv
# Processing:  glycosylphosphatidyl_train_8203.csv
# Processing:  glycosylphosphatidyl_train_8703.csv
# Processing:  glycosylphosphatidyl_train_8928.csv
# Processing:  glyoxylate_and_dicar_train_1587.csv
# Processing:  glyoxylate_and_dicar_train_2960.csv
# Processing:  glyoxylate_and_dicar_train_2996.csv
# Processing:  glyoxylate_and_dicar_train_3343.csv
# Processing:  glyoxylate_and_dicar_train_3794.csv
# Processing:  glyoxylate_and_dicar_train_4579.csv
# Processing:  glyoxylate_and_dicar_train_7549.csv
# Processing:  glyoxylate_and_dicar_train_8802.csv
# Processing:  glyoxylate_and_dicar_train_9051.csv
# Processing:  glyoxylate_and_dicar_train_9556.csv
# Processing:  histidine_metabolism_train_1209.csv
# Processing:  histidine_metabolism_train_2211.csv
# Processing:  histidine_metabolism_train_3733.csv
# Processing:  histidine_metabolism_train_4981.csv
# Processing:  histidine_metabolism_train_4986.csv
# Processing:  histidine_metabolism_train_5160.csv
# Processing:  histidine_metabolism_train_5677.csv
# Processing:  histidine_metabolism_train_6614.csv
# Processing:  histidine_metabolism_train_8687.csv
# Processing:  histidine_metabolism_train_9640.csv
# Processing:  inositol_phosphate_m_train_1337.csv
# Processing:  inositol_phosphate_m_train_3161.csv
# Processing:  inositol_phosphate_m_train_3768.csv
# Processing:  inositol_phosphate_m_train_4787.csv
# Processing:  inositol_phosphate_m_train_5151.csv
# Processing:  inositol_phosphate_m_train_5254.csv
# Processing:  inositol_phosphate_m_train_6383.csv
# Processing:  inositol_phosphate_m_train_8965.csv
# Processing:  inositol_phosphate_m_train_9162.csv
# Processing:  inositol_phosphate_m_train_9582.csv
# Processing:  linoleic_acid_metabo_train_3626.csv
# Processing:  linoleic_acid_metabo_train_4253.csv
# Processing:  linoleic_acid_metabo_train_5657.csv
# Processing:  linoleic_acid_metabo_train_8221.csv
# Processing:  linoleic_acid_metabo_train_8653.csv
# Processing:  linoleic_acid_metabo_train_9139.csv
# Processing:  linoleic_acid_metabo_train_9252.csv
# Processing:  linoleic_acid_metabo_train_9553.csv
# Processing:  linoleic_acid_metabo_train_9785.csv
# Processing:  linoleic_acid_metabo_train_9824.csv
# Processing:  lipoic_acid_metaboli_train_1385.csv
# Processing:  lipoic_acid_metaboli_train_5732.csv
# Processing:  lipoic_acid_metaboli_train_6169.csv
# Processing:  lipoic_acid_metaboli_train_6350.csv
# Processing:  lipoic_acid_metaboli_train_6521.csv
# Processing:  lipoic_acid_metaboli_train_8189.csv
# Processing:  lipoic_acid_metaboli_train_8395.csv
# Processing:  lipoic_acid_metaboli_train_8541.csv
# Processing:  lipoic_acid_metaboli_train_8728.csv
# Processing:  lipoic_acid_metaboli_train_8800.csv
# Processing:  lysine_biosynthesis_train_1871.csv
# Processing:  lysine_biosynthesis_train_2016.csv
# Processing:  lysine_biosynthesis_train_2992.csv
# Processing:  lysine_biosynthesis_train_4196.csv
# Processing:  lysine_biosynthesis_train_4741.csv
# Processing:  lysine_biosynthesis_train_6293.csv
# Processing:  lysine_biosynthesis_train_8435.csv
# Processing:  lysine_biosynthesis_train_8442.csv
# Processing:  lysine_biosynthesis_train_8594.csv
# Processing:  lysine_biosynthesis_train_9154.csv
# Processing:  lysine_degradation_train_1177.csv
# Processing:  lysine_degradation_train_1404.csv
# Processing:  lysine_degradation_train_3915.csv
# Processing:  lysine_degradation_train_5043.csv
# Processing:  lysine_degradation_train_6900.csv
# Processing:  lysine_degradation_train_7617.csv
# Processing:  lysine_degradation_train_8293.csv
# Processing:  lysine_degradation_train_8754.csv
# Processing:  lysine_degradation_train_9667.csv
# Processing:  lysine_degradation_train_9699.csv
# Processing:  metabolism_of_xenobi_train_1891.csv
# Processing:  metabolism_of_xenobi_train_2276.csv
# Processing:  metabolism_of_xenobi_train_3385.csv
# Processing:  metabolism_of_xenobi_train_4073.csv
# Processing:  metabolism_of_xenobi_train_5605.csv
# Processing:  metabolism_of_xenobi_train_5862.csv
# Processing:  metabolism_of_xenobi_train_6798.csv
# Processing:  metabolism_of_xenobi_train_7505.csv
# Processing:  metabolism_of_xenobi_train_8796.csv
# Processing:  metabolism_of_xenobi_train_9086.csv
# Processing:  mucin_type_o_glycan_train_2449.csv
# Processing:  mucin_type_o_glycan_train_4852.csv
# Processing:  mucin_type_o_glycan_train_4957.csv
# Processing:  mucin_type_o_glycan_train_5398.csv
# Processing:  mucin_type_o_glycan_train_5726.csv
# Processing:  mucin_type_o_glycan_train_5763.csv
# Processing:  mucin_type_o_glycan_train_7491.csv
# Processing:  mucin_type_o_glycan_train_7529.csv
# Processing:  mucin_type_o_glycan_train_8983.csv
# Processing:  n_glycan_biosynthesi_train_1584.csv
# Processing:  n_glycan_biosynthesi_train_1885.csv
# Processing:  n_glycan_biosynthesi_train_2873.csv
# Processing:  n_glycan_biosynthesi_train_3427.csv
# Processing:  n_glycan_biosynthesi_train_4637.csv
# Processing:  n_glycan_biosynthesi_train_4870.csv
# Processing:  n_glycan_biosynthesi_train_4978.csv
# Processing:  n_glycan_biosynthesi_train_5411.csv
# Processing:  n_glycan_biosynthesi_train_8163.csv
# Processing:  n_glycan_biosynthesi_train_9661.csv
# Processing:  other_types_of_o_gly_train_1299.csv
# Processing:  nicotinate_and_nicot_train_1497.csv
# Processing:  nicotinate_and_nicot_train_1758.csv
# Processing:  nicotinate_and_nicot_train_3074.csv
# Processing:  nicotinate_and_nicot_train_3087.csv
# Processing:  nicotinate_and_nicot_train_4621.csv
# Processing:  nicotinate_and_nicot_train_4753.csv
# Processing:  nicotinate_and_nicot_train_5849.csv
# Processing:  nicotinate_and_nicot_train_6359.csv
# Processing:  nicotinate_and_nicot_train_6943.csv
# Processing:  nicotinate_and_nicot_train_9363.csv
# Processing:  nitrogen_metabolism_train_3442.csv
# Processing:  nitrogen_metabolism_train_4157.csv
# Processing:  nitrogen_metabolism_train_4204.csv
# Processing:  nitrogen_metabolism_train_6141.csv
# Processing:  nitrogen_metabolism_train_7075.csv
# Processing:  nitrogen_metabolism_train_7440.csv
# Processing:  nitrogen_metabolism_train_8986.csv
# Processing:  nitrogen_metabolism_train_9395.csv
# Processing:  nitrogen_metabolism_train_9476.csv
# Processing:  nitrogen_metabolism_train_9511.csv
# Processing:  one_carbon_pool_by_f_train_1293.csv
# Processing:  one_carbon_pool_by_f_train_1466.csv
# Processing:  one_carbon_pool_by_f_train_1656.csv
# Processing:  one_carbon_pool_by_f_train_1671.csv
# Processing:  one_carbon_pool_by_f_train_3035.csv
# Processing:  one_carbon_pool_by_f_train_3699.csv
# Processing:  one_carbon_pool_by_f_train_4046.csv
# Processing:  one_carbon_pool_by_f_train_4656.csv
# Processing:  one_carbon_pool_by_f_train_5988.csv
# Processing:  one_carbon_pool_by_f_train_9250.csv
# Processing:  other_types_of_o_gly_train_2394.csv
# Processing:  other_types_of_o_gly_train_2494.csv
# Processing:  other_types_of_o_gly_train_2893.csv
# Processing:  other_types_of_o_gly_train_5221.csv
# Processing:  other_types_of_o_gly_train_6244.csv
# Processing:  other_types_of_o_gly_train_6246.csv
# Processing:  other_types_of_o_gly_train_6804.csv
# Processing:  other_types_of_o_gly_train_8552.csv
# Processing:  other_types_of_o_gly_train_9407.csv
# Processing:  phenylalanine__tyros_train_1487.csv
# Processing:  pantothenate_and_coa_train_2787.csv
# Processing:  pantothenate_and_coa_train_3035.csv
# Processing:  pantothenate_and_coa_train_7239.csv
# Processing:  pantothenate_and_coa_train_7317.csv
# Processing:  pantothenate_and_coa_train_7783.csv
# Processing:  pantothenate_and_coa_train_8164.csv
# Processing:  pantothenate_and_coa_train_8176.csv
# Processing:  pantothenate_and_coa_train_8645.csv
# Processing:  pantothenate_and_coa_train_8812.csv
# Processing:  pantothenate_and_coa_train_9992.csv
# Processing:  pentose_and_glucuron_train_1585.csv
# Processing:  pentose_and_glucuron_train_3424.csv
# Processing:  pentose_and_glucuron_train_5502.csv
# Processing:  pentose_and_glucuron_train_5923.csv
# Processing:  pentose_and_glucuron_train_6395.csv
# Processing:  pentose_and_glucuron_train_6832.csv
# Processing:  pentose_and_glucuron_train_6872.csv
# Processing:  pentose_and_glucuron_train_7254.csv
# Processing:  pentose_and_glucuron_train_7711.csv
# Processing:  pentose_and_glucuron_train_8480.csv
# Processing:  pentose_phosphate_pa_train_1208.csv
# Processing:  pentose_phosphate_pa_train_1506.csv
# Processing:  pentose_phosphate_pa_train_1855.csv
# Processing:  pentose_phosphate_pa_train_2673.csv
# Processing:  pentose_phosphate_pa_train_3930.csv
# Processing:  pentose_phosphate_pa_train_4578.csv
# Processing:  pentose_phosphate_pa_train_5518.csv
# Processing:  pentose_phosphate_pa_train_6584.csv
# Processing:  pentose_phosphate_pa_train_8739.csv
# Processing:  pentose_phosphate_pa_train_9496.csv
# Processing:  phenylalanine__tyros_train_2296.csv
# Processing:  phenylalanine__tyros_train_2425.csv
# Processing:  phenylalanine__tyros_train_2724.csv
# Processing:  phenylalanine__tyros_train_3774.csv
# Processing:  phenylalanine__tyros_train_4121.csv
# Processing:  phenylalanine__tyros_train_4519.csv
# Processing:  phenylalanine__tyros_train_9302.csv
# Processing:  phenylalanine__tyros_train_9535.csv
# Processing:  phenylalanine__tyros_train_9660.csv
# Processing:  phenylalanine_metabo_train_1899.csv
# Processing:  phenylalanine_metabo_train_2067.csv
# Processing:  phenylalanine_metabo_train_2940.csv
# Processing:  phenylalanine_metabo_train_3213.csv
# Processing:  phenylalanine_metabo_train_5357.csv
# Processing:  phenylalanine_metabo_train_7746.csv
# Processing:  phenylalanine_metabo_train_7866.csv
# Processing:  phenylalanine_metabo_train_7995.csv
# Processing:  phenylalanine_metabo_train_8640.csv
# Processing:  phenylalanine_metabo_train_9455.csv
# Processing:  porphyrin_and_chloro_train_1972.csv
# Processing:  porphyrin_and_chloro_train_4809.csv
# Processing:  porphyrin_and_chloro_train_4873.csv
# Processing:  porphyrin_and_chloro_train_4997.csv
# Processing:  porphyrin_and_chloro_train_5886.csv
# Processing:  porphyrin_and_chloro_train_6811.csv
# Processing:  porphyrin_and_chloro_train_6817.csv
# Processing:  porphyrin_and_chloro_train_7647.csv
# Processing:  porphyrin_and_chloro_train_8022.csv
# Processing:  porphyrin_and_chloro_train_8247.csv
# Processing:  primary_bile_acid_bi_train_2793.csv
# Processing:  primary_bile_acid_bi_train_3795.csv
# Processing:  primary_bile_acid_bi_train_4552.csv
# Processing:  primary_bile_acid_bi_train_4704.csv
# Processing:  primary_bile_acid_bi_train_7460.csv
# Processing:  primary_bile_acid_bi_train_7793.csv
# Processing:  primary_bile_acid_bi_train_8404.csv
# Processing:  primary_bile_acid_bi_train_8799.csv
# Processing:  primary_bile_acid_bi_train_9453.csv
# Processing:  primary_bile_acid_bi_train_9990.csv
# Processing:  propanoate_metabolis_train_1641.csv
# Processing:  propanoate_metabolis_train_2104.csv
# Processing:  propanoate_metabolis_train_2520.csv
# Processing:  propanoate_metabolis_train_4916.csv
# Processing:  propanoate_metabolis_train_5106.csv
# Processing:  propanoate_metabolis_train_6366.csv
# Processing:  propanoate_metabolis_train_6395.csv
# Processing:  propanoate_metabolis_train_7079.csv
# Processing:  propanoate_metabolis_train_8432.csv
# Processing:  propanoate_metabolis_train_9228.csv
# Processing:  purine_metabolism_train_1035.csv
# Processing:  purine_metabolism_train_1409.csv
# Processing:  purine_metabolism_train_1425.csv
# Processing:  purine_metabolism_train_2263.csv
# Processing:  purine_metabolism_train_3580.csv
# Processing:  purine_metabolism_train_3657.csv
# Processing:  purine_metabolism_train_5896.csv
# Processing:  purine_metabolism_train_7936.csv
# Processing:  purine_metabolism_train_9503.csv
# Processing:  purine_metabolism_train_9583.csv
# Processing:  pyrimidine_metabolis_train_1423.csv
# Processing:  pyrimidine_metabolis_train_1615.csv
# Processing:  pyrimidine_metabolis_train_1990.csv
# Processing:  pyrimidine_metabolis_train_3799.csv
# Processing:  pyrimidine_metabolis_train_5325.csv
# Processing:  pyrimidine_metabolis_train_5903.csv
# Processing:  pyrimidine_metabolis_train_7160.csv
# Processing:  pyrimidine_metabolis_train_7241.csv
# Processing:  pyrimidine_metabolis_train_8850.csv
# Processing:  pyrimidine_metabolis_train_9011.csv
# Processing:  pyruvate_metabolism_train_2459.csv
# Processing:  pyruvate_metabolism_train_2623.csv
# Processing:  pyruvate_metabolism_train_2916.csv
# Processing:  pyruvate_metabolism_train_3848.csv
# Processing:  pyruvate_metabolism_train_3867.csv
# Processing:  pyruvate_metabolism_train_4916.csv
# Processing:  pyruvate_metabolism_train_6622.csv
# Processing:  pyruvate_metabolism_train_7292.csv
# Processing:  pyruvate_metabolism_train_7605.csv
# Processing:  pyruvate_metabolism_train_9622.csv
# Processing:  retinol_metabolism_train_1453.csv
# Processing:  retinol_metabolism_train_3755.csv
# Processing:  sulfur_metabolism_train_1891.csv
# Processing:  retinol_metabolism_train_3941.csv
# Processing:  retinol_metabolism_train_4089.csv
# Processing:  retinol_metabolism_train_5470.csv
# Processing:  retinol_metabolism_train_6244.csv
# Processing:  retinol_metabolism_train_8393.csv
# Processing:  retinol_metabolism_train_8948.csv
# Processing:  retinol_metabolism_train_9167.csv
# Processing:  retinol_metabolism_train_9664.csv
# Processing:  riboflavin_metabolis_train_1552.csv
# Processing:  riboflavin_metabolis_train_2807.csv
# Processing:  riboflavin_metabolis_train_4802.csv
# Processing:  riboflavin_metabolis_train_4823.csv
# Processing:  riboflavin_metabolis_train_5743.csv
# Processing:  riboflavin_metabolis_train_5826.csv
# Processing:  riboflavin_metabolis_train_5918.csv
# Processing:  riboflavin_metabolis_train_6043.csv
# Processing:  riboflavin_metabolis_train_6750.csv
# Processing:  riboflavin_metabolis_train_9684.csv
# Processing:  selenocompound_metab_train_1652.csv
# Processing:  selenocompound_metab_train_2780.csv
# Processing:  selenocompound_metab_train_5417.csv
# Processing:  selenocompound_metab_train_5508.csv
# Processing:  selenocompound_metab_train_5553.csv
# Processing:  selenocompound_metab_train_7080.csv
# Processing:  selenocompound_metab_train_8078.csv
# Processing:  selenocompound_metab_train_8196.csv
# Processing:  selenocompound_metab_train_8403.csv
# Processing:  selenocompound_metab_train_9397.csv
# Processing:  sphingolipid_metabol_train_1064.csv
# Processing:  sphingolipid_metabol_train_2299.csv
# Processing:  sphingolipid_metabol_train_3883.csv
# Processing:  sphingolipid_metabol_train_5576.csv
# Processing:  sphingolipid_metabol_train_6402.csv
# Processing:  sphingolipid_metabol_train_7075.csv
# Processing:  sphingolipid_metabol_train_7417.csv
# Processing:  sphingolipid_metabol_train_7532.csv
# Processing:  sphingolipid_metabol_train_7670.csv
# Processing:  sphingolipid_metabol_train_8777.csv
# Processing:  starch_and_sucrose_m_train_1473.csv
# Processing:  starch_and_sucrose_m_train_2356.csv
# Processing:  starch_and_sucrose_m_train_3953.csv
# Processing:  starch_and_sucrose_m_train_4604.csv
# Processing:  starch_and_sucrose_m_train_5326.csv
# Processing:  starch_and_sucrose_m_train_5329.csv
# Processing:  starch_and_sucrose_m_train_5671.csv
# Processing:  starch_and_sucrose_m_train_5869.csv
# Processing:  starch_and_sucrose_m_train_5925.csv
# Processing:  starch_and_sucrose_m_train_8147.csv
# Processing:  steroid_biosynthesis_train_1126.csv
# Processing:  steroid_biosynthesis_train_3268.csv
# Processing:  steroid_biosynthesis_train_4516.csv
# Processing:  steroid_biosynthesis_train_5084.csv
# Processing:  steroid_biosynthesis_train_5609.csv
# Processing:  steroid_biosynthesis_train_7878.csv
# Processing:  steroid_biosynthesis_train_8131.csv
# Processing:  steroid_biosynthesis_train_8821.csv
# Processing:  steroid_biosynthesis_train_9054.csv
# Processing:  steroid_biosynthesis_train_9585.csv
# Processing:  steroid_hormone_bios_train_2497.csv
# Processing:  steroid_hormone_bios_train_2798.csv
# Processing:  steroid_hormone_bios_train_4468.csv
# Processing:  steroid_hormone_bios_train_5673.csv
# Processing:  steroid_hormone_bios_train_6668.csv
# Processing:  steroid_hormone_bios_train_7125.csv
# Processing:  steroid_hormone_bios_train_7327.csv
# Processing:  steroid_hormone_bios_train_8148.csv
# Processing:  steroid_hormone_bios_train_8704.csv
# Processing:  steroid_hormone_bios_train_8921.csv
# Processing:  sulfur_metabolism_train_3820.csv
# Processing:  sulfur_metabolism_train_4762.csv
# Processing:  sulfur_metabolism_train_4864.csv
# Processing:  sulfur_metabolism_train_5728.csv
# Processing:  sulfur_metabolism_train_5877.csv
# Processing:  sulfur_metabolism_train_6064.csv
# Processing:  sulfur_metabolism_train_8644.csv
# Processing:  sulfur_metabolism_train_9149.csv
# Processing:  sulfur_metabolism_train_9748.csv
# Processing:  synthesis_and_degrad_train_2073.csv
# Processing:  synthesis_and_degrad_train_2698.csv
# Processing:  synthesis_and_degrad_train_2802.csv
# Processing:  synthesis_and_degrad_train_2915.csv
# Processing:  synthesis_and_degrad_train_3187.csv
# Processing:  synthesis_and_degrad_train_3351.csv
# Processing:  synthesis_and_degrad_train_3972.csv
# Processing:  synthesis_and_degrad_train_5068.csv
# Processing:  synthesis_and_degrad_train_6205.csv
# Processing:  synthesis_and_degrad_train_6376.csv
# Processing:  taurine_and_hypotaur_train_1079.csv
# Processing:  taurine_and_hypotaur_train_1875.csv
# Processing:  taurine_and_hypotaur_train_2474.csv
# Processing:  taurine_and_hypotaur_train_2505.csv
# Processing:  taurine_and_hypotaur_train_3065.csv
# Processing:  taurine_and_hypotaur_train_3206.csv
# Processing:  taurine_and_hypotaur_train_4985.csv
# Processing:  taurine_and_hypotaur_train_5698.csv
# Processing:  taurine_and_hypotaur_train_6366.csv
# Processing:  taurine_and_hypotaur_train_9891.csv
# Processing:  terpenoid_backbone_b_train_1198.csv
# Processing:  terpenoid_backbone_b_train_2152.csv
# Processing:  terpenoid_backbone_b_train_3241.csv
# Processing:  terpenoid_backbone_b_train_4588.csv
# Processing:  terpenoid_backbone_b_train_6459.csv
# Processing:  terpenoid_backbone_b_train_6621.csv
# Processing:  terpenoid_backbone_b_train_8657.csv
# Processing:  terpenoid_backbone_b_train_8661.csv
# Processing:  terpenoid_backbone_b_train_8942.csv
# Processing:  terpenoid_backbone_b_train_9404.csv
# Processing:  thiamine_metabolism_train_1501.csv
# Processing:  thiamine_metabolism_train_2100.csv
# Processing:  thiamine_metabolism_train_3773.csv
# Processing:  thiamine_metabolism_train_3962.csv
# Processing:  thiamine_metabolism_train_4084.csv
# Processing:  thiamine_metabolism_train_5258.csv
# Processing:  thiamine_metabolism_train_5980.csv
# Processing:  thiamine_metabolism_train_6802.csv
# Processing:  thiamine_metabolism_train_8748.csv
# Processing:  thiamine_metabolism_train_9623.csv
# Processing:  tryptophan_metabolis_train_1628.csv
# Processing:  tryptophan_metabolis_train_2110.csv
# Processing:  tryptophan_metabolis_train_3266.csv
# Processing:  tryptophan_metabolis_train_5522.csv
# Processing:  tryptophan_metabolis_train_6237.csv
# Processing:  tryptophan_metabolis_train_6412.csv
# Processing:  tryptophan_metabolis_train_6753.csv
# Processing:  tryptophan_metabolis_train_8942.csv
# Processing:  tryptophan_metabolis_train_9256.csv
# Processing:  tryptophan_metabolis_train_9385.csv
# Processing:  tyrosine_metabolism_train_1290.csv
# Processing:  tyrosine_metabolism_train_1681.csv
# Processing:  tyrosine_metabolism_train_2226.csv
# Processing:  tyrosine_metabolism_train_4111.csv
# Processing:  tyrosine_metabolism_train_5403.csv
# Processing:  tyrosine_metabolism_train_6010.csv
# Processing:  tyrosine_metabolism_train_7101.csv
# Processing:  tyrosine_metabolism_train_7807.csv
# Processing:  tyrosine_metabolism_train_8180.csv
# Processing:  tyrosine_metabolism_train_8918.csv
# Processing:  ubiquinone_and_other_train_2366.csv
# Processing:  ubiquinone_and_other_train_2517.csv
# Processing:  ubiquinone_and_other_train_2997.csv
# Processing:  ubiquinone_and_other_train_4287.csv
# Processing:  ubiquinone_and_other_train_5477.csv
# Processing:  ubiquinone_and_other_train_5916.csv
# Processing:  ubiquinone_and_other_train_6291.csv
# Processing:  ubiquinone_and_other_train_7233.csv
# Processing:  ubiquinone_and_other_train_7545.csv
# Processing:  ubiquinone_and_other_train_9396.csv
# Processing:  valine__leucine_and___1_train_3551.csv
# Processing:  valine__leucine_and___1_train_4437.csv
# Processing:  valine__leucine_and___1_train_5467.csv
# Processing:  valine__leucine_and___1_train_6589.csv
# Processing:  valine__leucine_and___1_train_7923.csv
# Processing:  valine__leucine_and___1_train_8676.csv
# Processing:  valine__leucine_and___1_train_9079.csv
# Processing:  valine__leucine_and___1_train_9534.csv
# Processing:  valine__leucine_and___1_train_9761.csv
# Processing:  valine__leucine_and_train_1385.csv
# Processing:  valine__leucine_and_train_1863.csv
# Processing:  valine__leucine_and_train_1950.csv
# Processing:  valine__leucine_and_train_3704.csv
# Processing:  valine__leucine_and_train_4369.csv
# Processing:  valine__leucine_and_train_6172.csv
# Processing:  valine__leucine_and_train_7204.csv
# Processing:  valine__leucine_and_train_7368.csv
# Processing:  valine__leucine_and_train_7495.csv
# Processing:  valine__leucine_and_train_7776.csv
# Processing:  vitamin_b6_metabolis_train_1175.csv
# Processing:  vitamin_b6_metabolis_train_1544.csv
# Processing:  vitamin_b6_metabolis_train_2567.csv
# Processing:  vitamin_b6_metabolis_train_3756.csv
# Processing:  vitamin_b6_metabolis_train_3761.csv
# Processing:  vitamin_b6_metabolis_train_6075.csv
# Processing:  vitamin_b6_metabolis_train_6815.csv
# Processing:  vitamin_b6_metabolis_train_6881.csv
# Processing:  vitamin_b6_metabolis_train_7405.csv
# Processing:  vitamin_b6_metabolis_train_7692.csv
# Processing:  alanine__aspartate_a_train_1510.csv
# Processing:  valine__leucine_and___1_train_1008.csv

# %%
# Save the dataset to disk
torch.save(data_list, 'dataset.pt')
