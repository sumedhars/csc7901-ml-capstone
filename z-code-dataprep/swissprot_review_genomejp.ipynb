# %%
import pandas as pd
import requests
import re

# %%
mapped_ids = pd.read_csv('uniprot-entry-names.csv')
mapped_ids.head()
# Out:
#   gene_name    entry_name
# 0   PLA2G10   PA2GX_HUMAN
# 1   PLA2G10  H3BRW4_HUMAN
# 2   PLA2G10  L8E7V2_HUMAN
# 3     FDFT1    FDFT_HUMAN
# 4     FDFT1  E9PNM1_HUMAN

# %% [markdown]
# #### Selecting only Uniprot IDs that are also SwissProt IDs i.e. have been manually reviewed

# %%
def filter_dataframe(df):
    base_url = "https://www.genome.jp/entry/sp:"
    # list to keep track of rows to keep
    rows_to_keep = []
    df = df.dropna()
    for index, row in df.iterrows():
        uniprot_id = row['entry_name']
        url = f"{base_url}{uniprot_id}"
        response = requests.get(url)
        if "No such data was found." not in response.text:
            rows_to_keep.append(index)
            print("SwissProt exists for: ", uniprot_id)
        # else:
            # print("SwissProt DOES NOT exist for: ", uniprot_id)
    # filter the DataFrame to keep only the desired rows
    filtered_df = df.loc[rows_to_keep].reset_index(drop=True)
    return filtered_df

# %%
mapped_ids_copy = mapped_ids.copy()

# %%
mapped_ids_swissprot = filter_dataframe(mapped_ids_copy)
# Out:
# SwissProt exists for:  PA2GX_HUMAN
# SwissProt exists for:  FDFT_HUMAN
# SwissProt exists for:  CEGT_HUMAN
# SwissProt exists for:  CP1A2_HUMAN
# SwissProt exists for:  SYRM_HUMAN
# SwissProt exists for:  GBA3_HUMAN
# SwissProt exists for:  APT_HUMAN
# SwissProt exists for:  METH_HUMAN
# SwissProt exists for:  UDB11_HUMAN
# SwissProt exists for:  HMOX1_HUMAN
# SwissProt exists for:  CPT1A_HUMAN
# SwissProt exists for:  GSH0_HUMAN
# SwissProt exists for:  SIA7A_HUMAN
# SwissProt exists for:  SNAT_HUMAN
# SwissProt exists for:  PCCA_HUMAN
# SwissProt exists for:  PPA6_HUMAN
# SwissProt exists for:  SYTM_HUMAN
# SwissProt exists for:  CP1B1_HUMAN
# SwissProt exists for:  DOPP1_HUMAN
# SwissProt exists for:  GSTA2_HUMAN
# SwissProt exists for:  EBP_HUMAN
# SwissProt exists for:  UDB28_HUMAN
# SwissProt exists for:  KHK_HUMAN
# SwissProt exists for:  MVD1_HUMAN
# SwissProt exists for:  PRI2_HUMAN
# SwissProt exists for:  PTSS1_HUMAN
# SwissProt exists for:  PPT1_HUMAN
# SwissProt exists for:  RIFK_HUMAN
# SwissProt exists for:  KITH_HUMAN
# SwissProt exists for:  ADH1G_HUMAN
# SwissProt exists for:  PIGA_HUMAN
# SwissProt exists for:  CHSS1_HUMAN
# SwissProt exists for:  TKFC_HUMAN
# SwissProt exists for:  LCAT_HUMAN
# SwissProt exists for:  CRLS1_HUMAN
# SwissProt exists for:  PDE6B_HUMAN
# SwissProt exists for:  PTPS_HUMAN
# SwissProt exists for:  CP27B_HUMAN
# SwissProt exists for:  LIPR2_HUMAN
# SwissProt exists for:  ENPP1_HUMAN
# SwissProt exists for:  GSTM1_HUMAN
# SwissProt exists for:  MTM1_HUMAN
# SwissProt exists for:  PDXK_HUMAN
# SwissProt exists for:  CP2C8_HUMAN
# SwissProt exists for:  UD13_HUMAN
# SwissProt exists for:  B3GN3_HUMAN
# SwissProt exists for:  AGT1_HUMAN
# SwissProt exists for:  PRI1_HUMAN
# SwissProt exists for:  AGM1_HUMAN
# SwissProt exists for:  CH3L1_HUMAN
# SwissProt exists for:  PCY2_HUMAN
# SwissProt exists for:  ARSA_HUMAN
# SwissProt exists for:  PANK3_HUMAN
# SwissProt exists for:  CP11A_HUMAN
# SwissProt exists for:  PDE8A_HUMAN
# SwissProt exists for:  CP2CI_HUMAN
# SwissProt exists for:  UDB10_HUMAN
# SwissProt exists for:  OXDA_HUMAN
# SwissProt exists for:  IMDH1_HUMAN
# SwissProt exists for:  PGP_HUMAN
# SwissProt exists for:  UDB17_HUMAN
# SwissProt exists for:  DCAM_HUMAN
# SwissProt exists for:  ADCY3_HUMAN
# SwissProt exists for:  KCRS_HUMAN
# SwissProt exists for:  F16P1_HUMAN
# SwissProt exists for:  ADPRM_HUMAN
# SwissProt exists for:  PUR9_HUMAN
# SwissProt exists for:  DHB7_HUMAN
# SwissProt exists for:  MTMR6_HUMAN
# SwissProt exists for:  ACADS_HUMAN
# SwissProt exists for:  LOX12_HUMAN
# SwissProt exists for:  GSHR_HUMAN
# SwissProt exists for:  HKDC1_HUMAN
# SwissProt exists for:  DHB3_HUMAN
# SwissProt exists for:  MIF_HUMAN
# SwissProt exists for:  TPK1_HUMAN
# SwissProt exists for:  SYWM_HUMAN
# SwissProt exists for:  BAAT_HUMAN
# SwissProt exists for:  PLOD1_HUMAN
# SwissProt exists for:  ARGI1_HUMAN
# SwissProt exists for:  GUAA_HUMAN
# SwissProt exists for:  GNA1_HUMAN
# SwissProt exists for:  AEDO_HUMAN
# SwissProt exists for:  AL7A1_HUMAN
# SwissProt exists for:  CBS_HUMAN
# SwissProt exists for:  DHE4_HUMAN
# SwissProt exists for:  PGLT1_HUMAN
# SwissProt exists for:  BUP1_HUMAN
# SwissProt exists for:  PNPO_HUMAN
# SwissProt exists for:  PDE3A_HUMAN
# SwissProt exists for:  GATM_HUMAN
# SwissProt exists for:  GSTA5_HUMAN
# SwissProt exists for:  PHOP1_HUMAN
# SwissProt exists for:  ST1A2_HUMAN
# SwissProt exists for:  PMGT1_HUMAN
# SwissProt exists for:  ADH6_HUMAN
# SwissProt exists for:  AATC_HUMAN
# SwissProt exists for:  ACOHC_HUMAN
# SwissProt exists for:  ADH4_HUMAN
# SwissProt exists for:  CAH1_HUMAN
# SwissProt exists for:  PDE1B_HUMAN
# SwissProt exists for:  PI42A_HUMAN
# SwissProt exists for:  DCE2_HUMAN
# SwissProt exists for:  DPOE2_HUMAN
# SwissProt exists for:  NUD12_HUMAN
# SwissProt exists for:  DAD1_HUMAN
# SwissProt exists for:  UD17_HUMAN
# SwissProt exists for:  CP39A_HUMAN
# SwissProt exists for:  ALG9_HUMAN
# SwissProt exists for:  FXDC2_HUMAN
# SwissProt exists for:  5NTC_HUMAN
# SwissProt exists for:  GLO2_HUMAN
# SwissProt exists for:  GLYC_HUMAN
# SwissProt exists for:  DHRS3_HUMAN
# SwissProt exists for:  AGAL_HUMAN
# SwissProt exists for:  3BHS7_HUMAN
# SwissProt exists for:  PEMT_HUMAN
# SwissProt exists for:  PA2G3_HUMAN
# SwissProt exists for:  SCD5_HUMAN
# SwissProt exists for:  UD18_HUMAN
# SwissProt exists for:  AACS_HUMAN
# SwissProt exists for:  GYS2_HUMAN
# SwissProt exists for:  AOFB_HUMAN
# SwissProt exists for:  OFUT1_HUMAN
# SwissProt exists for:  AL1L2_HUMAN
# SwissProt exists for:  SYYM_HUMAN
# SwissProt exists for:  DPOD1_HUMAN
# SwissProt exists for:  3HIDH_HUMAN
# SwissProt exists for:  5NTD_HUMAN
# SwissProt exists for:  NDK5_HUMAN
# SwissProt exists for:  FADS2_HUMAN
# SwissProt exists for:  ACACA_HUMAN
# SwissProt exists for:  AZIN2_HUMAN
# SwissProt exists for:  FAS_HUMAN
# SwissProt exists for:  ACSA_HUMAN
# SwissProt exists for:  CHLE_HUMAN
# SwissProt exists for:  PI5PA_HUMAN
# SwissProt exists for:  MGST1_HUMAN
# SwissProt exists for:  PCAT2_HUMAN
# SwissProt exists for:  GLCNE_HUMAN
# SwissProt exists for:  HCD2_HUMAN
# SwissProt exists for:  ACES_HUMAN
# SwissProt exists for:  AK1C4_HUMAN
# SwissProt exists for:  PNCB_HUMAN
# SwissProt exists for:  TREA_HUMAN
# SwissProt exists for:  ALDR_HUMAN
# SwissProt exists for:  SUCA_HUMAN
# SwissProt exists for:  PFKAP_HUMAN
# SwissProt exists for:  PYRG1_HUMAN
# SwissProt exists for:  MMSA_HUMAN
# SwissProt exists for:  NDKB_HUMAN
# SwissProt exists for:  PYGM_HUMAN
# SwissProt exists for:  PGPS1_HUMAN
# SwissProt exists for:  DHRS4_HUMAN
# SwissProt exists for:  HPRT_HUMAN
# SwissProt exists for:  COMT_HUMAN
# SwissProt exists for:  ENOA_HUMAN
# SwissProt exists for:  NRK1_HUMAN
# SwissProt exists for:  FUT4_HUMAN
# SwissProt exists for:  HYES_HUMAN
# SwissProt exists for:  PA2GE_HUMAN
# SwissProt exists for:  MGAT3_HUMAN
# SwissProt exists for:  SYPM_HUMAN
# SwissProt exists for:  CSAD_HUMAN
# SwissProt exists for:  ECHA_HUMAN
# SwissProt exists for:  PRDX4_HUMAN
# SwissProt exists for:  GSTO1_HUMAN
# SwissProt exists for:  LSS_HUMAN
# SwissProt exists for:  MDHC_HUMAN
# SwissProt exists for:  PLPP_HUMAN
# SwissProt exists for:  P3C2B_HUMAN
# SwissProt exists for:  SIA7F_HUMAN
# SwissProt exists for:  ST2B1_HUMAN
# SwissProt exists for:  PDE11_HUMAN
# SwissProt exists for:  REV3L_HUMAN
# SwissProt exists for:  ALG12_HUMAN
# SwissProt exists for:  SIA7E_HUMAN
# SwissProt exists for:  PIGG_HUMAN
# SwissProt exists for:  FOLC_HUMAN
# SwissProt exists for:  SMS1_HUMAN
# SwissProt exists for:  GSTM3_HUMAN
# SwissProt exists for:  CHSTB_HUMAN
# SwissProt exists for:  F264_HUMAN
# SwissProt exists for:  OGDHL_HUMAN
# SwissProt exists for:  TYPH_HUMAN
# SwissProt exists for:  PPOX_HUMAN
# SwissProt exists for:  ALG8_HUMAN
# SwissProt exists for:  CP343_HUMAN
# SwissProt exists for:  ENTP5_HUMAN
# SwissProt exists for:  HMOX2_HUMAN
# SwissProt exists for:  PDE6A_HUMAN
# SwissProt exists for:  DPOD2_HUMAN
# SwissProt exists for:  ACO12_HUMAN
# SwissProt exists for:  ALLC_HUMAN
# SwissProt exists for:  PLCE1_HUMAN
# SwissProt exists for:  NADE_HUMAN
# SwissProt exists for:  EXTL1_HUMAN
# SwissProt exists for:  GCH1_HUMAN
# SwissProt exists for:  GSTM4_HUMAN
# SwissProt exists for:  HYEP_HUMAN
# SwissProt exists for:  XYLT2_HUMAN
# SwissProt exists for:  CP2D6_HUMAN
# SwissProt exists for:  PH4H_HUMAN
# SwissProt exists for:  DHB4_HUMAN
# SwissProt exists for:  AL3A2_HUMAN
# SwissProt exists for:  AGK_HUMAN
# SwissProt exists for:  PHP14_HUMAN
# SwissProt exists for:  ACOT2_HUMAN
# SwissProt exists for:  NAGS_HUMAN
# SwissProt exists for:  CHKA_HUMAN
# SwissProt exists for:  PDE4A_HUMAN
# SwissProt exists for:  AOC1_HUMAN
# SwissProt exists for:  BGAT_HUMAN
# SwissProt exists for:  AMYP_HUMAN
# SwissProt exists for:  LPP60_HUMAN
# SwissProt exists for:  PPCS_HUMAN
# SwissProt exists for:  P5CR3_HUMAN
# SwissProt exists for:  ASMT_HUMAN
# SwissProt exists for:  PLPL9_HUMAN
# SwissProt exists for:  THIM_HUMAN
# SwissProt exists for:  MOGT3_HUMAN
# SwissProt exists for:  C1GLT_HUMAN
# SwissProt exists for:  NUD16_HUMAN
# SwissProt exists for:  H17B6_HUMAN
# SwissProt exists for:  GLPK2_HUMAN
# SwissProt exists for:  MTMR7_HUMAN
# SwissProt exists for:  NB5R1_HUMAN
# SwissProt exists for:  FUT9_HUMAN
# SwissProt exists for:  TYRP2_HUMAN
# SwissProt exists for:  DEOC_HUMAN
# SwissProt exists for:  NTPCR_HUMAN
# SwissProt exists for:  5NT3A_HUMAN
# SwissProt exists for:  RENBP_HUMAN
# SwissProt exists for:  PDE4C_HUMAN
# SwissProt exists for:  B4GT6_HUMAN
# SwissProt exists for:  PG12A_HUMAN
# SwissProt exists for:  PNPT1_HUMAN
# SwissProt exists for:  KMO_HUMAN
# SwissProt exists for:  PA24B_HUMAN
# SwissProt exists for:  CPT1C_HUMAN
# SwissProt exists for:  PDE8B_HUMAN
# SwissProt exists for:  ST1A3_HUMAN
# SwissProt exists for:  HEXA_HUMAN
# SwissProt exists for:  ST2A1_HUMAN
# SwissProt exists for:  OAT_HUMAN
# SwissProt exists for:  KBL_HUMAN
# SwissProt exists for:  ADHX_HUMAN
# SwissProt exists for:  HEM0_HUMAN
# SwissProt exists for:  MOGS_HUMAN
# SwissProt exists for:  ACOX2_HUMAN
# SwissProt exists for:  ALDOC_HUMAN
# SwissProt exists for:  LDH6A_HUMAN
# SwissProt exists for:  DPOE3_HUMAN
# SwissProt exists for:  NSDHL_HUMAN
# SwissProt exists for:  ADH1A_HUMAN
# SwissProt exists for:  S27A5_HUMAN
# SwissProt exists for:  5NT1A_HUMAN
# SwissProt exists for:  ACER3_HUMAN
# SwissProt exists for:  FTCD_HUMAN
# SwissProt exists for:  ADPPT_HUMAN
# SwissProt exists for:  KAT1_HUMAN
# SwissProt exists for:  THTPA_HUMAN
# SwissProt exists for:  INMT_HUMAN
# SwissProt exists for:  MAON_HUMAN
# SwissProt exists for:  ALG2_HUMAN
# SwissProt exists for:  EST5A_HUMAN
# SwissProt exists for:  CLAT_HUMAN
# SwissProt exists for:  NUD14_HUMAN
# SwissProt exists for:  EPT1_HUMAN
# SwissProt exists for:  NT5C_HUMAN
# SwissProt exists for:  GFPT1_HUMAN
# SwissProt exists for:  IDI1_HUMAN
# SwissProt exists for:  3BHS1_HUMAN
# SwissProt exists for:  HNMT_HUMAN
# SwissProt exists for:  SDHA_HUMAN
# SwissProt exists for:  B3GLT_HUMAN
# SwissProt exists for:  PIGH_HUMAN
# SwissProt exists for:  PCY1A_HUMAN
# SwissProt exists for:  MGST2_HUMAN
# SwissProt exists for:  DHC24_HUMAN
# SwissProt exists for:  LIPL_HUMAN
# SwissProt exists for:  GPT_HUMAN
# SwissProt exists for:  ECHM_HUMAN
# SwissProt exists for:  CNCG_HUMAN
# SwissProt exists for:  GPX6_HUMAN
# SwissProt exists for:  PDE7A_HUMAN
# SwissProt exists for:  PISD_HUMAN
# SwissProt exists for:  ECHP_HUMAN
# SwissProt exists for:  PDE1A_HUMAN
# SwissProt exists for:  COX10_HUMAN
# SwissProt exists for:  KITM_HUMAN
# SwissProt exists for:  GALNS_HUMAN
# SwissProt exists for:  TY3H_HUMAN
# SwissProt exists for:  SOX_HUMAN
# SwissProt exists for:  SPS1_HUMAN
# SwissProt exists for:  RPE65_HUMAN
# SwissProt exists for:  MTHFS_HUMAN
# SwissProt exists for:  PIGM_HUMAN
# SwissProt exists for:  KPYM_HUMAN
# SwissProt exists for:  ST1A1_HUMAN
# SwissProt exists for:  UD11_HUMAN
# SwissProt exists for:  CP4AM_HUMAN
# SwissProt exists for:  HCDH_HUMAN
# SwissProt exists for:  CP51A_HUMAN
# SwissProt exists for:  B3GT5_HUMAN
# SwissProt exists for:  ACSL4_HUMAN
# SwissProt exists for:  COQ7_HUMAN
# SwissProt exists for:  C11B1_HUMAN
# SwissProt exists for:  GLNA_HUMAN
# SwissProt exists for:  COAC_HUMAN
# SwissProt exists for:  LX15B_HUMAN
# SwissProt exists for:  SARDH_HUMAN
# SwissProt exists for:  PYR1_HUMAN
# SwissProt exists for:  CP2C9_HUMAN
# SwissProt exists for:  GNS_HUMAN
# SwissProt exists for:  SIAS_HUMAN
# SwissProt exists for:  RIR1_HUMAN
# SwissProt exists for:  GGCT_HUMAN
# SwissProt exists for:  AWAT2_HUMAN
# SwissProt exists for:  ACADL_HUMAN
# SwissProt exists for:  MGAT2_HUMAN
# SwissProt exists for:  ENPP6_HUMAN
# SwissProt exists for:  KAD3_HUMAN
# SwissProt exists for:  GNPAT_HUMAN
# SwissProt exists for:  NEUR4_HUMAN
# SwissProt exists for:  HXK2_HUMAN
# SwissProt exists for:  PAPS2_HUMAN
# SwissProt exists for:  DHI2_HUMAN
# SwissProt exists for:  C1TM_HUMAN
# SwissProt exists for:  SGPP1_HUMAN
# SwissProt exists for:  AOFA_HUMAN
# SwissProt exists for:  PIGO_HUMAN
# SwissProt exists for:  STS_HUMAN
# SwissProt exists for:  GPX4_HUMAN
# SwissProt exists for:  PDE4D_HUMAN
# SwissProt exists for:  ALG3_HUMAN
# SwissProt exists for:  HEM6_HUMAN
# SwissProt exists for:  P4HA3_HUMAN
# SwissProt exists for:  FUT3_HUMAN
# SwissProt exists for:  ADH7_HUMAN
# SwissProt exists for:  AOC2_HUMAN
# SwissProt exists for:  CATA_HUMAN
# SwissProt exists for:  SYHM_HUMAN
# SwissProt exists for:  GABT_HUMAN
# SwissProt exists for:  HAOX2_HUMAN
# SwissProt exists for:  SYNJ2_HUMAN
# SwissProt exists for:  GCNT1_HUMAN
# SwissProt exists for:  MPI_HUMAN
# SwissProt exists for:  6PGD_HUMAN
# SwissProt exists for:  ACOT4_HUMAN
# SwissProt exists for:  B4GT4_HUMAN
# SwissProt exists for:  CP2E1_HUMAN
# SwissProt exists for:  I5P2_HUMAN
# SwissProt exists for:  MBOA5_HUMAN
# SwissProt exists for:  PSTK_HUMAN
# SwissProt exists for:  ADA_HUMAN
# SwissProt exists for:  LICH_HUMAN
# SwissProt exists for:  SIAT1_HUMAN
# SwissProt exists for:  EST2_HUMAN
# SwissProt exists for:  CNDP1_HUMAN
# SwissProt exists for:  DHSO_HUMAN
# SwissProt exists for:  GALT_HUMAN
# SwissProt exists for:  FUT5_HUMAN
# SwissProt exists for:  AMACR_HUMAN
# SwissProt exists for:  GAMT_HUMAN
# SwissProt exists for:  B4GA1_HUMAN
# SwissProt exists for:  MIOX_HUMAN
# SwissProt exists for:  XDH_HUMAN
# SwissProt exists for:  G6PI_HUMAN
# SwissProt exists for:  FUT8_HUMAN
# SwissProt exists for:  DHRS9_HUMAN
# SwissProt exists for:  PGM2_HUMAN
# SwissProt exists for:  AP4A_HUMAN
# SwissProt exists for:  CP1A1_HUMAN
# SwissProt exists for:  GBGT1_HUMAN
# SwissProt exists for:  ADK_HUMAN
# SwissProt exists for:  ASNS_HUMAN
# SwissProt exists for:  GCDH_HUMAN
# SwissProt exists for:  BDH_HUMAN
# SwissProt exists for:  GNT2A_HUMAN
# SwissProt exists for:  IDUA_HUMAN
# SwissProt exists for:  ASAH1_HUMAN
# SwissProt exists for:  PLB1_HUMAN
# SwissProt exists for:  PIGL_HUMAN
# SwissProt exists for:  B3GT2_HUMAN
# SwissProt exists for:  BPNT1_HUMAN
# SwissProt exists for:  FUT2_HUMAN
# SwissProt exists for:  GRHPR_HUMAN
# SwissProt exists for:  ODBB_HUMAN
# SwissProt exists for:  PDE3B_HUMAN
# SwissProt exists for:  TECR_HUMAN
# SwissProt exists for:  HPSE2_HUMAN
# SwissProt exists for:  NANP_HUMAN
# SwissProt exists for:  GDAH_HUMAN
# SwissProt exists for:  PANK2_HUMAN
# SwissProt exists for:  ALG1_HUMAN
# SwissProt exists for:  MOD5_HUMAN
# SwissProt exists for:  PDE10_HUMAN
# SwissProt exists for:  ARY2_HUMAN
# SwissProt exists for:  PANK4_HUMAN
# SwissProt exists for:  CP2R1_HUMAN
# SwissProt exists for:  B4GT5_HUMAN
# SwissProt exists for:  CH25H_HUMAN
# SwissProt exists for:  DPOLA_HUMAN
# SwissProt exists for:  GSTP1_HUMAN
# SwissProt exists for:  NEUR1_HUMAN
# SwissProt exists for:  ERG1_HUMAN
# SwissProt exists for:  MGT4C_HUMAN
# SwissProt exists for:  HXK3_HUMAN
# SwissProt exists for:  DOLK_HUMAN
# SwissProt exists for:  PIGZ_HUMAN
# SwissProt exists for:  TRXR3_HUMAN
# SwissProt exists for:  AL9A1_HUMAN
# SwissProt exists for:  POMT1_HUMAN
# SwissProt exists for:  LFNG_HUMAN
# SwissProt exists for:  ACYP2_HUMAN
# SwissProt exists for:  NDK6_HUMAN
# SwissProt exists for:  DPOG2_HUMAN
# SwissProt exists for:  GANAB_HUMAN
# SwissProt exists for:  PTEN_HUMAN
# SwissProt exists for:  ENPP2_HUMAN
# SwissProt exists for:  THIL_HUMAN
# SwissProt exists for:  NIT2_HUMAN
# SwissProt exists for:  DGUOK_HUMAN
# SwissProt exists for:  SYLM_HUMAN
# SwissProt exists for:  PI51B_HUMAN
# SwissProt exists for:  SC5D_HUMAN
# SwissProt exists for:  GSTO2_HUMAN
# SwissProt exists for:  TMLH_HUMAN
# SwissProt exists for:  OGT1_HUMAN
# SwissProt exists for:  SERC_HUMAN
# SwissProt exists for:  BLVRB_HUMAN
# SwissProt exists for:  GCNT4_HUMAN
# SwissProt exists for:  PDE9A_HUMAN
# SwissProt exists for:  ALG14_HUMAN
# SwissProt exists for:  UD2B4_HUMAN
# SwissProt exists for:  HUTI_HUMAN
# SwissProt exists for:  ARSB_HUMAN
# SwissProt exists for:  IVD_HUMAN
# SwissProt exists for:  PYRD_HUMAN
# SwissProt exists for:  B3GA2_HUMAN
# SwissProt exists for:  RPC10_HUMAN
# SwissProt exists for:  B3GL1_HUMAN
# SwissProt exists for:  PLOD2_HUMAN
# SwissProt exists for:  NDKM_HUMAN
# SwissProt exists for:  MTHR_HUMAN
# SwissProt exists for:  NDKA_HUMAN
# SwissProt exists for:  UD2A2_HUMAN
# SwissProt exists for:  ALG5_HUMAN
# SwissProt exists for:  AG10A_HUMAN
# SwissProt exists for:  P4HA2_HUMAN
# SwissProt exists for:  PUR2_HUMAN
# SwissProt exists for:  CGT_HUMAN
# SwissProt exists for:  LGAT1_HUMAN
# SwissProt exists for:  ENTP2_HUMAN
# SwissProt exists for:  COQ6_HUMAN
# SwissProt exists for:  HEMH_HUMAN
# SwissProt exists for:  IMPA2_HUMAN
# SwissProt exists for:  ODP2_HUMAN
# SwissProt exists for:  HEM4_HUMAN
# SwissProt exists for:  IPMK_HUMAN
# SwissProt exists for:  OXSM_HUMAN
# SwissProt exists for:  TBA8_HUMAN
# SwissProt exists for:  GMPR2_HUMAN
# SwissProt exists for:  LX12B_HUMAN
# SwissProt exists for:  UMPS_HUMAN
# SwissProt exists for:  ST1A4_HUMAN
# SwissProt exists for:  LPCT4_HUMAN
# SwissProt exists for:  HEM2_HUMAN
# SwissProt exists for:  G6PC2_HUMAN
# SwissProt exists for:  CP2B6_HUMAN
# SwissProt exists for:  IDS_HUMAN
# SwissProt exists for:  ERG24_HUMAN
# SwissProt exists for:  NOS3_HUMAN
# SwissProt exists for:  CHPT1_HUMAN
# SwissProt exists for:  SIA8E_HUMAN
# SwissProt exists for:  DPOA2_HUMAN
# SwissProt exists for:  ODBA_HUMAN
# SwissProt exists for:  DLDH_HUMAN
# SwissProt exists for:  MGT5B_HUMAN
# SwissProt exists for:  CP7A1_HUMAN
# SwissProt exists for:  GLSK_HUMAN
# SwissProt exists for:  ACADM_HUMAN
# SwissProt exists for:  GSTK1_HUMAN
# SwissProt exists for:  AL3A1_HUMAN
# SwissProt exists for:  TRXR2_HUMAN
# SwissProt exists for:  PGM2L_HUMAN
# SwissProt exists for:  CP27A_HUMAN
# SwissProt exists for:  PI42B_HUMAN
# SwissProt exists for:  BODG_HUMAN
# SwissProt exists for:  MAOX_HUMAN
# SwissProt exists for:  DPOE1_HUMAN
# SwissProt exists for:  UD15_HUMAN
# SwissProt exists for:  IMDH2_HUMAN
# SwissProt exists for:  B4GT2_HUMAN
# SwissProt exists for:  PANK1_HUMAN
# SwissProt exists for:  PGM1_HUMAN
# SwissProt exists for:  RPIA_HUMAN
# SwissProt exists for:  ENTP3_HUMAN
# SwissProt exists for:  MA1B1_HUMAN
# SwissProt exists for:  UXS1_HUMAN
# SwissProt exists for:  CP17A_HUMAN
# SwissProt exists for:  B4GN1_HUMAN
# SwissProt exists for:  GALC_HUMAN
# SwissProt exists for:  PIGC_HUMAN
# SwissProt exists for:  SIA10_HUMAN
# SwissProt exists for:  RBSK_HUMAN
# SwissProt exists for:  AOC3_HUMAN
# SwissProt exists for:  METL6_HUMAN
# SwissProt exists for:  MECR_HUMAN
# SwissProt exists for:  B3GT4_HUMAN
# SwissProt exists for:  HACD1_HUMAN
# SwissProt exists for:  KAT3_HUMAN
# SwissProt exists for:  NNTM_HUMAN
# SwissProt exists for:  DPOD3_HUMAN
# SwissProt exists for:  MGT4B_HUMAN
# SwissProt exists for:  ACY1_HUMAN
# SwissProt exists for:  AK1BA_HUMAN
# SwissProt exists for:  BCAT2_HUMAN
# SwissProt exists for:  TKTL2_HUMAN
# SwissProt exists for:  AMY1A_HUMAN
# SwissProt exists for:  DPM2_HUMAN
# SwissProt exists for:  ATTY_HUMAN
# SwissProt exists for:  P4HA1_HUMAN
# SwissProt exists for:  LDHD_HUMAN
# SwissProt exists for:  KGUA_HUMAN
# SwissProt exists for:  KPYR_HUMAN
# SwissProt exists for:  INO1_HUMAN
# SwissProt exists for:  MGLL_HUMAN
# SwissProt exists for:  MTMR2_HUMAN
# SwissProt exists for:  NPL_HUMAN
# SwissProt exists for:  CHIT1_HUMAN
# SwissProt exists for:  CPT1B_HUMAN
# SwissProt exists for:  PMGE_HUMAN
# SwissProt exists for:  RETST_HUMAN
# SwissProt exists for:  SUCB2_HUMAN
# SwissProt exists for:  ACY2_HUMAN
# SwissProt exists for:  OPLA_HUMAN
# SwissProt exists for:  PA2GA_HUMAN
# SwissProt exists for:  PAFA2_HUMAN
# SwissProt exists for:  PTSS2_HUMAN
# SwissProt exists for:  GGPPS_HUMAN
# SwissProt exists for:  RDH11_HUMAN
# SwissProt exists for:  ACAD8_HUMAN
# SwissProt exists for:  ALG6_HUMAN
# SwissProt exists for:  NAGK_HUMAN
# SwissProt exists for:  B3GT1_HUMAN
# SwissProt exists for:  PLD1_HUMAN
# SwissProt exists for:  PIGF_HUMAN
# SwissProt exists for:  XYLT1_HUMAN
# SwissProt exists for:  PDE7B_HUMAN
# SwissProt exists for:  INP4B_HUMAN
# SwissProt exists for:  SYSM_HUMAN
# SwissProt exists for:  CP7B1_HUMAN
# SwissProt exists for:  SIA7D_HUMAN
# SwissProt exists for:  KFA_HUMAN
# SwissProt exists for:  ACADV_HUMAN
# SwissProt exists for:  GGH_HUMAN
# SwissProt exists for:  5NT1B_HUMAN
# SwissProt exists for:  GNMT_HUMAN
# SwissProt exists for:  NAGAB_HUMAN
# SwissProt exists for:  NADK_HUMAN
# SwissProt exists for:  B3GN5_HUMAN
# SwissProt exists for:  MA2A2_HUMAN
# SwissProt exists for:  PLPL4_HUMAN
# SwissProt exists for:  MBOA7_HUMAN
# SwissProt exists for:  NUDT9_HUMAN
# SwissProt exists for:  PIGN_HUMAN
# SwissProt exists for:  ODO2_HUMAN
# SwissProt exists for:  PUR6_HUMAN
# SwissProt exists for:  MAAI_HUMAN
# SwissProt exists for:  GANC_HUMAN
# SwissProt exists for:  FHIT_HUMAN
# SwissProt exists for:  VNN2_HUMAN
# SwissProt exists for:  PIGP_HUMAN
# SwissProt exists for:  IDH3G_HUMAN
# SwissProt exists for:  6PGL_HUMAN
# SwissProt exists for:  NEUA_HUMAN
# SwissProt exists for:  SERB_HUMAN
# SwissProt exists for:  GDE_HUMAN
# SwissProt exists for:  DUT_HUMAN
# SwissProt exists for:  AK1A1_HUMAN
# SwissProt exists for:  BTD_HUMAN
# SwissProt exists for:  GSTT1_HUMAN
# SwissProt exists for:  ELOV6_HUMAN
# SwissProt exists for:  SPTC1_HUMAN
# SwissProt exists for:  SSDH_HUMAN
# SwissProt exists for:  NFS1_HUMAN
# SwissProt exists for:  UD14_HUMAN
# SwissProt exists for:  PIGY_HUMAN
# SwissProt exists for:  NDK3_HUMAN
# SwissProt exists for:  TYSY_HUMAN
# SwissProt exists for:  GPDM_HUMAN
# SwissProt exists for:  AMY1C_HUMAN
# SwissProt exists for:  ENOG_HUMAN
# SwissProt exists for:  CP2AD_HUMAN
# SwissProt exists for:  UD19_HUMAN
# SwissProt exists for:  CGL_HUMAN
# SwissProt exists for:  G3P_HUMAN
# SwissProt exists for:  DPYD_HUMAN
# SwissProt exists for:  ITPK1_HUMAN
# SwissProt exists for:  UD2B7_HUMAN
# SwissProt exists for:  PK3C3_HUMAN
# SwissProt exists for:  DPOG1_HUMAN
# SwissProt exists for:  SCOT2_HUMAN
# SwissProt exists for:  PUR8_HUMAN
# SwissProt exists for:  SGPL1_HUMAN
# SwissProt exists for:  GCNT3_HUMAN
# SwissProt exists for:  A4GAT_HUMAN
# SwissProt exists for:  PRDX6_HUMAN
# SwissProt exists for:  B3GN6_HUMAN
# SwissProt exists for:  LIPT2_HUMAN
# SwissProt exists for:  CP2J2_HUMAN
# SwissProt exists for:  L2HDH_HUMAN
# SwissProt exists for:  BHMT1_HUMAN
# SwissProt exists for:  SAT2_HUMAN
# SwissProt exists for:  THIK_HUMAN
# SwissProt exists for:  PDE2A_HUMAN
# SwissProt exists for:  CP46A_HUMAN
# SwissProt exists for:  MGA_HUMAN
# SwissProt exists for:  SIA4A_HUMAN
# SwissProt exists for:  PA24A_HUMAN
# SwissProt exists for:  BPL1_HUMAN
# SwissProt exists for:  PHLD_HUMAN
# SwissProt exists for:  AATM_HUMAN
# SwissProt exists for:  MAOM_HUMAN
# SwissProt exists for:  UPP2_HUMAN
# SwissProt exists for:  TXD12_HUMAN
# SwissProt exists for:  SPRE_HUMAN
# SwissProt exists for:  SYCM_HUMAN
# SwissProt exists for:  SCLY_HUMAN
# SwissProt exists for:  MBOA1_HUMAN
# SwissProt exists for:  FMT_HUMAN
# SwissProt exists for:  MTMR1_HUMAN
# SwissProt exists for:  ARY1_HUMAN
# SwissProt exists for:  PYC_HUMAN
# SwissProt exists for:  UD16_HUMAN
# SwissProt exists for:  PA2GD_HUMAN
# SwissProt exists for:  PUR4_HUMAN
# SwissProt exists for:  GSTA1_HUMAN
# SwissProt exists for:  GALT4_HUMAN
# SwissProt exists for:  ODO1_HUMAN
# SwissProt exists for:  SIA4C_HUMAN
# SwissProt exists for:  TPMT_HUMAN
# SwissProt exists for:  OXDD_HUMAN
# SwissProt exists for:  NNMT_HUMAN
# SwissProt exists for:  AOXA_HUMAN
# SwissProt exists for:  PIGB_HUMAN
# SwissProt exists for:  KMT5B_HUMAN
# SwissProt exists for:  COQ5_HUMAN
# SwissProt exists for:  SR5A3_HUMAN
# SwissProt exists for:  ENOB_HUMAN
# SwissProt exists for:  SPEE_HUMAN
# SwissProt exists for:  SMS2_HUMAN
# SwissProt exists for:  ACSM5_HUMAN
# SwissProt exists for:  DYR_HUMAN
# SwissProt exists for:  SCP2_HUMAN
# SwissProt exists for:  ALG11_HUMAN
# SwissProt exists for:  UGDH_HUMAN
# SwissProt exists for:  DEGS1_HUMAN
# SwissProt exists for:  UD2A1_HUMAN
# SwissProt exists for:  IPPK_HUMAN
# SwissProt exists for:  SYAM_HUMAN
# SwissProt exists for:  NEUR2_HUMAN
# SwissProt exists for:  UD110_HUMAN
# SwissProt exists for:  GGT5_HUMAN
# SwissProt exists for:  GSTA3_HUMAN
# SwissProt exists for:  P5CS_HUMAN
# SwissProt exists for:  GPAT3_HUMAN
# SwissProt exists for:  SYEM_HUMAN
# SwissProt exists for:  IDH3B_HUMAN
# SwissProt exists for:  HXK4_HUMAN
# SwissProt exists for:  CNRG_HUMAN
# SwissProt exists for:  GMPPB_HUMAN
# SwissProt exists for:  GCST_HUMAN
# SwissProt exists for:  CD38_HUMAN
# SwissProt exists for:  CERS1_HUMAN
# SwissProt exists for:  GSHB_HUMAN
# SwissProt exists for:  I23O2_HUMAN
# SwissProt exists for:  PNMT_HUMAN
# SwissProt exists for:  SIAT9_HUMAN
# SwissProt exists for:  CHDH_HUMAN
# SwissProt exists for:  ASSY_HUMAN
# SwissProt exists for:  COASY_HUMAN
# SwissProt exists for:  DCE1_HUMAN
# SwissProt exists for:  GNPI2_HUMAN
# SwissProt exists for:  NDK7_HUMAN
# SwissProt exists for:  DOPO_HUMAN
# SwissProt exists for:  SIA8A_HUMAN
# SwissProt exists for:  SUCB1_HUMAN
# SwissProt exists for:  SUIS_HUMAN
# SwissProt exists for:  B4GT7_HUMAN
# SwissProt exists for:  AK1D1_HUMAN
# SwissProt exists for:  PA21B_HUMAN
# SwissProt exists for:  PG12B_HUMAN
# SwissProt exists for:  AMY2B_HUMAN
# SwissProt exists for:  AMPN_HUMAN
# SwissProt exists for:  ADPGK_HUMAN
# SwissProt exists for:  AASS_HUMAN
# SwissProt exists for:  B3GT6_HUMAN
# SwissProt exists for:  SIAT6_HUMAN
# SwissProt exists for:  IDHC_HUMAN
# SwissProt exists for:  TUT4_HUMAN
# SwissProt exists for:  ASM_HUMAN
# SwissProt exists for:  GST2_HUMAN
# SwissProt exists for:  PROD_HUMAN
# SwissProt exists for:  CP21A_HUMAN
# SwissProt exists for:  HXK1_HUMAN
# SwissProt exists for:  LGUL_HUMAN
# SwissProt exists for:  ANAG_HUMAN
# SwissProt exists for:  UCK1_HUMAN
# SwissProt exists for:  PDE1C_HUMAN
# SwissProt exists for:  DCK_HUMAN
# SwissProt exists for:  HEM1_HUMAN
# SwissProt exists for:  PIGW_HUMAN
# SwissProt exists for:  AMY1B_HUMAN
# SwissProt exists for:  EXT1_HUMAN
# SwissProt exists for:  GMDS_HUMAN
# SwissProt exists for:  HGNAT_HUMAN
# SwissProt exists for:  AMPL_HUMAN
# SwissProt exists for:  CGAT2_HUMAN
# SwissProt exists for:  PA2GC_HUMAN
# SwissProt exists for:  TYRO_HUMAN
# SwissProt exists for:  OXLA_HUMAN
# SwissProt exists for:  CDIPT_HUMAN
# SwissProt exists for:  DHB12_HUMAN
# SwissProt exists for:  ADH1B_HUMAN
# SwissProt exists for:  SAST_HUMAN
# SwissProt exists for:  ITPA_HUMAN
# SwissProt exists for:  PLPP3_HUMAN
# SwissProt exists for:  DDC_HUMAN
# SwissProt exists for:  SIA7C_HUMAN
# SwissProt exists for:  PDE4B_HUMAN
# SwissProt exists for:  SYIM_HUMAN
# SwissProt exists for:  SRR_HUMAN
# SwissProt exists for:  PI4KB_HUMAN
# SwissProt exists for:  GPD1L_HUMAN
# SwissProt exists for:  MGT5A_HUMAN
# SwissProt exists for:  CPT2_HUMAN
# SwissProt exists for:  HUTH_HUMAN
# SwissProt exists for:  NEUR3_HUMAN
# SwissProt exists for:  KYNU_HUMAN
# SwissProt exists for:  B4GT1_HUMAN
# SwissProt exists for:  DR4L2_HUMAN
# SwissProt exists for:  STT3B_HUMAN
# SwissProt exists for:  DHCR7_HUMAN
# SwissProt exists for:  ODPB_HUMAN
# SwissProt exists for:  NMNA3_HUMAN
# SwissProt exists for:  TALDO_HUMAN
# SwissProt exists for:  HPSE_HUMAN
# SwissProt exists for:  CP2CJ_HUMAN
# SwissProt exists for:  MGAT1_HUMAN
# SwissProt exists for:  PON1_HUMAN
# SwissProt exists for:  SYFA_HUMAN
# SwissProt exists for:  HYPDH_HUMAN
# SwissProt exists for:  RDHE2_HUMAN
# SwissProt exists for:  PCKGM_HUMAN
# SwissProt exists for:  NUDT5_HUMAN
# SwissProt exists for:  EXTL3_HUMAN
# SwissProt exists for:  LRAT_HUMAN
# SwissProt exists for:  BGLR_HUMAN
# SwissProt exists for:  NADC_HUMAN
# SwissProt exists for:  PIGV_HUMAN
# SwissProt exists for:  ACDSB_HUMAN
# SwissProt exists for:  DPOD4_HUMAN
# SwissProt exists for:  HIBCH_HUMAN
# SwissProt exists for:  PDE6D_HUMAN
# SwissProt exists for:  ARLY_HUMAN
# SwissProt exists for:  COQ3_HUMAN
# SwissProt exists for:  CHPF2_HUMAN
# SwissProt exists for:  NAMPT_HUMAN
# SwissProt exists for:  IDHP_HUMAN
# SwissProt exists for:  PA2GF_HUMAN
# SwissProt exists for:  CRNS1_HUMAN
# SwissProt exists for:  KTHY_HUMAN
# SwissProt exists for:  GSTM2_HUMAN
# SwissProt exists for:  GXLT1_HUMAN
# SwissProt exists for:  INPP_HUMAN
# SwissProt exists for:  NT5M_HUMAN
# SwissProt exists for:  MTD2L_HUMAN
# SwissProt exists for:  P3C2G_HUMAN
# SwissProt exists for:  PNPH_HUMAN
# SwissProt exists for:  AL1A1_HUMAN
# SwissProt exists for:  PI42C_HUMAN
# SwissProt exists for:  LPH_HUMAN
# SwissProt exists for:  NAGA_HUMAN
# SwissProt exists for:  SPHK2_HUMAN
# SwissProt exists for:  MAT2B_HUMAN
# SwissProt exists for:  G6PE_HUMAN
# SwissProt exists for:  PIGQ_HUMAN
# SwissProt exists for:  B4GT3_HUMAN
# SwissProt exists for:  PA2G5_HUMAN
# SwissProt exists for:  GALM_HUMAN
# SwissProt exists for:  LIPT_HUMAN
# SwissProt exists for:  MGST3_HUMAN
# SwissProt exists for:  PDE6C_HUMAN
# SwissProt exists for:  CDD_HUMAN
# SwissProt exists for:  TRXR1_HUMAN
# SwissProt exists for:  GUC2D_HUMAN
# SwissProt exists for:  C1TC_HUMAN
# SwissProt exists for:  IDH3A_HUMAN
# SwissProt exists for:  ELOV2_HUMAN
# SwissProt exists for:  DCUP_HUMAN
# SwissProt exists for:  GCSP_HUMAN
# SwissProt exists for:  PLOD3_HUMAN
# SwissProt exists for:  HPPD_HUMAN
# SwissProt exists for:  CDS1_HUMAN
# SwissProt exists for:  HEM3_HUMAN
# SwissProt exists for:  GMPR1_HUMAN
# SwissProt exists for:  GSTM5_HUMAN
# SwissProt exists for:  DCOR_HUMAN
# SwissProt exists for:  PIGX_HUMAN
# SwissProt exists for:  PA24E_HUMAN
# SwissProt exists for:  SUOX_HUMAN
# SwissProt exists for:  CEPT1_HUMAN
# SwissProt exists for:  GSTA4_HUMAN
# SwissProt exists for:  KDSR_HUMAN
# SwissProt exists for:  OTC_HUMAN
# SwissProt exists for:  P3C2A_HUMAN
# SwissProt exists for:  UDB15_HUMAN
# SwissProt exists for:  MINP1_HUMAN
# SwissProt exists for:  ACOX3_HUMAN
# SwissProt exists for:  CHIA_HUMAN
# SwissProt exists for:  FUT1_HUMAN
# SwissProt exists for:  G6PD_HUMAN
# SwissProt exists for:  G3ST1_HUMAN
# SwissProt exists for:  IP3KB_HUMAN
# SwissProt exists for:  AL4A1_HUMAN
# SwissProt exists for:  BGAL_HUMAN
# SwissProt exists for:  DPYS_HUMAN
# SwissProt exists for:  HGD_HUMAN
# SwissProt exists for:  HUTU_HUMAN
# SwissProt exists for:  ALG13_HUMAN
# SwissProt exists for:  SPHM_HUMAN
# SwissProt exists for:  UD2A3_HUMAN
# SwissProt exists for:  MOCS1_HUMAN
# SwissProt exists for:  PDE5A_HUMAN
# SwissProt exists for:  XYLB_HUMAN
# SwissProt exists for:  SERA_HUMAN
# SwissProt exists for:  DHPR_HUMAN
# SwissProt exists for:  CPSM_HUMAN
# SwissProt exists for:  DPOE4_HUMAN
# SwissProt exists for:  ACON_HUMAN
# SwissProt exists for:  SOAT1_HUMAN
# SwissProt exists for:  CCHL_HUMAN
# SwissProt exists for:  HYI_HUMAN
# SwissProt exists for:  PK3CB_HUMAN
# SwissProt exists for:  FTMT_HUMAN
# SwissProt exists for:  MCEE_HUMAN
# SwissProt exists for:  DHDDS_HUMAN
# SwissProt exists for:  CERK1_HUMAN
# SwissProt exists for:  COX15_HUMAN
# SwissProt exists for:  CP26C_HUMAN
# SwissProt exists for:  HYAL1_HUMAN
# SwissProt exists for:  DPS1_HUMAN
# SwissProt exists for:  PERT_HUMAN
# SwissProt exists for:  MCCB_HUMAN
# SwissProt exists for:  ADAS_HUMAN
# SwissProt exists for:  C11B2_HUMAN
# SwissProt exists for:  MMAB_HUMAN
# SwissProt exists for:  PK3CA_HUMAN
# SwissProt exists for:  FUT7_HUMAN
# SwissProt exists for:  TYRP1_HUMAN
# SwissProt exists for:  PPBI_HUMAN
# SwissProt exists for:  PK3CD_HUMAN
# SwissProt exists for:  SDHL_HUMAN
# SwissProt exists for:  PK3CG_HUMAN
# SwissProt exists for:  SPCS_HUMAN
# SwissProt exists for:  FYV1_HUMAN
# SwissProt exists for:  MOC2A_HUMAN
# SwissProt exists for:  MOC2B_HUMAN

# %%
print(len(mapped_ids_swissprot))
print(len(mapped_ids))
# Out:
# 871
# 6413

# %%
mapped_ids_swissprot.head()
# Out:
#   gene_name   entry_name
# 0   PLA2G10  PA2GX_HUMAN
# 1     FDFT1   FDFT_HUMAN
# 2      UGCG   CEGT_HUMAN
# 3    CYP1A2  CP1A2_HUMAN
# 4     RARS2   SYRM_HUMAN

# %%
mapped_ids_swissprot.to_csv('mapped_ids_reviewed.csv',sep='\t',index=False)
