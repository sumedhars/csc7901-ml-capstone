# %%
import pandas as pd
import os
import re

# %%
ind_pathway_files = [f for f in os.listdir('pathwaycommons-individual') if f.endswith('.txt')]

# %%
mapped_ids_reviewed = pd.read_csv('processed-data/mapped_ids_reviewed.csv', sep='\t')
mapped_ids_reviewed.head()
# Out:
#   gene_name   entry_name
# 0   PLA2G10  PA2GX_HUMAN
# 1     FDFT1   FDFT_HUMAN
# 2      UGCG   CEGT_HUMAN
# 3    CYP1A2  CP1A2_HUMAN
# 4     RARS2   SYRM_HUMAN

# %%
all_relations = ['catalysis-precedes',
 'interacts-with',
 'consumption-controlled-by',
 'controls-production-of',
 'reacts-with',
 'used-to-produce']
undirected = ['in-complex-with', 'interacts-with', 'neighbor-of', 'reacts-with']
directed = [item for item in all_relations if item not in undirected]

# %%
mapping_dict = dict(zip(mapped_ids_reviewed["gene_name"], mapped_ids_reviewed["entry_name"]))

# %%
for ind_pathway in ind_pathway_files:
    # path_name = os.path.splitext(os.path.basename(ind_pathway))[0]
    read_file = os.path.join('pathwaycommons-individual', ind_pathway)
    ind_pathway = ind_pathway[:-4]
    # print(ind_pathway)
    pc_df = pd.read_csv(read_file, sep='\t',header=None)
    pc_df[0] = pc_df[0].replace(mapping_dict)
    pc_df[2] = pc_df[2].replace(mapping_dict)
    pc_df[4] = pc_df[2].apply(lambda x: 'D' if x in directed else 'U')
    pc_df.drop(columns=[1], inplace=True)
    pc_df.rename(columns={0:'Node1', 2:'Node2',4:'Directionality'}, inplace=True)
    output_path = 'processed-pc-individual-pathways/' + re.sub(r'\W+', '_', ind_pathway).strip('_').lower() + '.txt'
    # print(output_path)
    pc_df.to_csv(output_path, index=False, sep='\t')

# %%
import os
import re

src_dir = 'training-samples/'
# match “anything” + “_train_<digits>.csv” as two groups
suffix_pattern = re.compile(r'^(.*?)(_train_\d+\.csv)$')

for fname in os.listdir(src_dir):
    full_path = os.path.join(src_dir, fname)

    m = suffix_pattern.match(fname)
    if m:
        prefix, suffix = m.group(1), m.group(2)
        # normalize only the prefix
        clean = (
            re.sub(r'\W+', '_', prefix)  # non-word → _
              .strip('_')                 # drop leading/trailing _
              .lower()                    # lowercase
        )
        new_fname = clean + suffix
    else:
        # fallback for any file not ending in _train_###.csv
        new_fname = (
            re.sub(r'\W+', '_', fname)
              .strip('_')
              .lower()
        )

    if new_fname != fname:
        old = os.path.join(src_dir, fname)
        new = os.path.join(src_dir, new_fname)
        print(f"Renaming: {fname} → {new_fname}")
        os.rename(old, new)
# Out:
# Renaming: alanine,_aspartate_a_train_1510.csv → alanine__aspartate_a_train_1510.csv
# Renaming: alanine,_aspartate_a_train_2535.csv → alanine__aspartate_a_train_2535.csv
# Renaming: alanine,_aspartate_a_train_3273.csv → alanine__aspartate_a_train_3273.csv
# Renaming: alanine,_aspartate_a_train_3711.csv → alanine__aspartate_a_train_3711.csv
# Renaming: alanine,_aspartate_a_train_3781.csv → alanine__aspartate_a_train_3781.csv
# Renaming: alanine,_aspartate_a_train_6130.csv → alanine__aspartate_a_train_6130.csv
# Renaming: alanine,_aspartate_a_train_6672.csv → alanine__aspartate_a_train_6672.csv
# Renaming: alanine,_aspartate_a_train_6727.csv → alanine__aspartate_a_train_6727.csv
# Renaming: alanine,_aspartate_a_train_8527.csv → alanine__aspartate_a_train_8527.csv
# Renaming: alanine,_aspartate_a_train_9941.csv → alanine__aspartate_a_train_9941.csv
# Renaming: alpha-linolenic_acid_train_1854.csv → alpha_linolenic_acid_train_1854.csv
# Renaming: alpha-linolenic_acid_train_2371.csv → alpha_linolenic_acid_train_2371.csv
# Renaming: alpha-linolenic_acid_train_4263.csv → alpha_linolenic_acid_train_4263.csv
# Renaming: alpha-linolenic_acid_train_4939.csv → alpha_linolenic_acid_train_4939.csv
# Renaming: alpha-linolenic_acid_train_5635.csv → alpha_linolenic_acid_train_5635.csv
# Renaming: alpha-linolenic_acid_train_5783.csv → alpha_linolenic_acid_train_5783.csv
# Renaming: alpha-linolenic_acid_train_6633.csv → alpha_linolenic_acid_train_6633.csv
# Renaming: alpha-linolenic_acid_train_7454.csv → alpha_linolenic_acid_train_7454.csv
# Renaming: alpha-linolenic_acid_train_9373.csv → alpha_linolenic_acid_train_9373.csv
# Renaming: alpha-linolenic_acid_train_9806.csv → alpha_linolenic_acid_train_9806.csv
# Renaming: aminoacyl-trna_biosy_train_1565.csv → aminoacyl_trna_biosy_train_1565.csv
# Renaming: aminoacyl-trna_biosy_train_2796.csv → aminoacyl_trna_biosy_train_2796.csv
# Renaming: aminoacyl-trna_biosy_train_3815.csv → aminoacyl_trna_biosy_train_3815.csv
# Renaming: aminoacyl-trna_biosy_train_3887.csv → aminoacyl_trna_biosy_train_3887.csv
# Renaming: aminoacyl-trna_biosy_train_4856.csv → aminoacyl_trna_biosy_train_4856.csv
# Renaming: aminoacyl-trna_biosy_train_5281.csv → aminoacyl_trna_biosy_train_5281.csv
# Renaming: aminoacyl-trna_biosy_train_5354.csv → aminoacyl_trna_biosy_train_5354.csv
# Renaming: aminoacyl-trna_biosy_train_7666.csv → aminoacyl_trna_biosy_train_7666.csv
# Renaming: aminoacyl-trna_biosy_train_8954.csv → aminoacyl_trna_biosy_train_8954.csv
# Renaming: aminoacyl-trna_biosy_train_9784.csv → aminoacyl_trna_biosy_train_9784.csv
# Renaming: beta-alanine_metabol_train_2559.csv → beta_alanine_metabol_train_2559.csv
# Renaming: beta-alanine_metabol_train_2705.csv → beta_alanine_metabol_train_2705.csv
# Renaming: beta-alanine_metabol_train_3310.csv → beta_alanine_metabol_train_3310.csv
# Renaming: beta-alanine_metabol_train_4217.csv → beta_alanine_metabol_train_4217.csv
# Renaming: beta-alanine_metabol_train_7014.csv → beta_alanine_metabol_train_7014.csv
# Renaming: beta-alanine_metabol_train_7183.csv → beta_alanine_metabol_train_7183.csv
# Renaming: beta-alanine_metabol_train_7581.csv → beta_alanine_metabol_train_7581.csv
# Renaming: beta-alanine_metabol_train_7864.csv → beta_alanine_metabol_train_7864.csv
# Renaming: beta-alanine_metabol_train_7979.csv → beta_alanine_metabol_train_7979.csv
# Renaming: beta-alanine_metabol_train_8672.csv → beta_alanine_metabol_train_8672.csv
# Renaming: citrate_cycle_(tca_c_train_2573.csv → citrate_cycle__tca_c_train_2573.csv
# Renaming: citrate_cycle_(tca_c_train_3071.csv → citrate_cycle__tca_c_train_3071.csv
# Renaming: citrate_cycle_(tca_c_train_3195.csv → citrate_cycle__tca_c_train_3195.csv
# Renaming: citrate_cycle_(tca_c_train_5290.csv → citrate_cycle__tca_c_train_5290.csv
# Renaming: citrate_cycle_(tca_c_train_5392.csv → citrate_cycle__tca_c_train_5392.csv
# Renaming: citrate_cycle_(tca_c_train_5519.csv → citrate_cycle__tca_c_train_5519.csv
# Renaming: citrate_cycle_(tca_c_train_6720.csv → citrate_cycle__tca_c_train_6720.csv
# Renaming: citrate_cycle_(tca_c_train_6943.csv → citrate_cycle__tca_c_train_6943.csv
# Renaming: citrate_cycle_(tca_c_train_8425.csv → citrate_cycle__tca_c_train_8425.csv
# Renaming: citrate_cycle_(tca_c_train_8698.csv → citrate_cycle__tca_c_train_8698.csv
# Renaming: d-arginine_and_d-orn_train_1815.csv → d_arginine_and_d_orn_train_1815.csv
# Renaming: d-arginine_and_d-orn_train_2204.csv → d_arginine_and_d_orn_train_2204.csv
# Renaming: d-arginine_and_d-orn_train_3096.csv → d_arginine_and_d_orn_train_3096.csv
# Renaming: d-arginine_and_d-orn_train_3362.csv → d_arginine_and_d_orn_train_3362.csv
# Renaming: d-arginine_and_d-orn_train_4582.csv → d_arginine_and_d_orn_train_4582.csv
# Renaming: d-arginine_and_d-orn_train_4827.csv → d_arginine_and_d_orn_train_4827.csv
# Renaming: d-arginine_and_d-orn_train_5224.csv → d_arginine_and_d_orn_train_5224.csv
# Renaming: d-arginine_and_d-orn_train_6276.csv → d_arginine_and_d_orn_train_6276.csv
# Renaming: d-arginine_and_d-orn_train_6400.csv → d_arginine_and_d_orn_train_6400.csv
# Renaming: d-arginine_and_d-orn_train_8863.csv → d_arginine_and_d_orn_train_8863.csv
# Renaming: d-glutamine_and_d-gl_train_3853.csv → d_glutamine_and_d_gl_train_3853.csv
# Renaming: d-glutamine_and_d-gl_train_5918.csv → d_glutamine_and_d_gl_train_5918.csv
# Renaming: d-glutamine_and_d-gl_train_6415.csv → d_glutamine_and_d_gl_train_6415.csv
# Renaming: d-glutamine_and_d-gl_train_6453.csv → d_glutamine_and_d_gl_train_6453.csv
# Renaming: d-glutamine_and_d-gl_train_6575.csv → d_glutamine_and_d_gl_train_6575.csv
# Renaming: d-glutamine_and_d-gl_train_7147.csv → d_glutamine_and_d_gl_train_7147.csv
# Renaming: d-glutamine_and_d-gl_train_7653.csv → d_glutamine_and_d_gl_train_7653.csv
# Renaming: d-glutamine_and_d-gl_train_8627.csv → d_glutamine_and_d_gl_train_8627.csv
# Renaming: d-glutamine_and_d-gl_train_9192.csv → d_glutamine_and_d_gl_train_9192.csv
# Renaming: d-glutamine_and_d-gl_train_9381.csv → d_glutamine_and_d_gl_train_9381.csv
# Renaming: drug_metabolism_-_cy_train_1576.csv → drug_metabolism___cy_train_1576.csv
# Renaming: drug_metabolism_-_cy_train_2581.csv → drug_metabolism___cy_train_2581.csv
# Renaming: drug_metabolism_-_cy_train_2665.csv → drug_metabolism___cy_train_2665.csv
# Renaming: drug_metabolism_-_cy_train_3545.csv → drug_metabolism___cy_train_3545.csv
# Renaming: drug_metabolism_-_cy_train_4503.csv → drug_metabolism___cy_train_4503.csv
# Renaming: drug_metabolism_-_cy_train_6262.csv → drug_metabolism___cy_train_6262.csv
# Renaming: drug_metabolism_-_cy_train_7207.csv → drug_metabolism___cy_train_7207.csv
# Renaming: drug_metabolism_-_cy_train_7291.csv → drug_metabolism___cy_train_7291.csv
# Renaming: drug_metabolism_-_cy_train_7643.csv → drug_metabolism___cy_train_7643.csv
# Renaming: drug_metabolism_-_cy_train_7684.csv → drug_metabolism___cy_train_7684.csv
# Renaming: drug_metabolism_-_ot_train_1108.csv → drug_metabolism___ot_train_1108.csv
# Renaming: drug_metabolism_-_ot_train_1722.csv → drug_metabolism___ot_train_1722.csv
# Renaming: drug_metabolism_-_ot_train_1801.csv → drug_metabolism___ot_train_1801.csv
# Renaming: drug_metabolism_-_ot_train_4485.csv → drug_metabolism___ot_train_4485.csv
# Renaming: drug_metabolism_-_ot_train_5565.csv → drug_metabolism___ot_train_5565.csv
# Renaming: drug_metabolism_-_ot_train_6155.csv → drug_metabolism___ot_train_6155.csv
# Renaming: drug_metabolism_-_ot_train_6253.csv → drug_metabolism___ot_train_6253.csv
# Renaming: drug_metabolism_-_ot_train_6288.csv → drug_metabolism___ot_train_6288.csv
# Renaming: drug_metabolism_-_ot_train_8702.csv → drug_metabolism___ot_train_8702.csv
# Renaming: drug_metabolism_-_ot_train_9953.csv → drug_metabolism___ot_train_9953.csv
# Renaming: glycerophospholipid__train_1191.csv → glycerophospholipid_train_1191.csv
# Renaming: glycerophospholipid__train_2901.csv → glycerophospholipid_train_2901.csv
# Renaming: glycerophospholipid__train_3243.csv → glycerophospholipid_train_3243.csv
# Renaming: glycerophospholipid__train_3822.csv → glycerophospholipid_train_3822.csv
# Renaming: glycerophospholipid__train_5031.csv → glycerophospholipid_train_5031.csv
# Renaming: glycerophospholipid__train_6257.csv → glycerophospholipid_train_6257.csv
# Renaming: glycerophospholipid__train_8627.csv → glycerophospholipid_train_8627.csv
# Renaming: glycerophospholipid__train_8885.csv → glycerophospholipid_train_8885.csv
# Renaming: glycerophospholipid__train_9385.csv → glycerophospholipid_train_9385.csv
# Renaming: glycerophospholipid__train_9901.csv → glycerophospholipid_train_9901.csv
# Renaming: glycine,_serine_and__train_1327.csv → glycine__serine_and_train_1327.csv
# Renaming: glycine,_serine_and__train_1578.csv → glycine__serine_and_train_1578.csv
# Renaming: glycine,_serine_and__train_4766.csv → glycine__serine_and_train_4766.csv
# Renaming: glycine,_serine_and__train_6145.csv → glycine__serine_and_train_6145.csv
# Renaming: glycine,_serine_and__train_8019.csv → glycine__serine_and_train_8019.csv
# Renaming: glycine,_serine_and__train_8569.csv → glycine__serine_and_train_8569.csv
# Renaming: glycine,_serine_and__train_8859.csv → glycine__serine_and_train_8859.csv
# Renaming: glycine,_serine_and__train_8905.csv → glycine__serine_and_train_8905.csv
# Renaming: glycine,_serine_and__train_9194.csv → glycine__serine_and_train_9194.csv
# Renaming: glycine,_serine_and__train_9687.csv → glycine__serine_and_train_9687.csv
# Renaming: glycosaminoglycan_bi_(1)_train_4029.csv → glycosaminoglycan_bi__1_train_4029.csv
# Renaming: glycosaminoglycan_bi_(1)_train_4067.csv → glycosaminoglycan_bi__1_train_4067.csv
# Renaming: glycosaminoglycan_bi_(1)_train_4495.csv → glycosaminoglycan_bi__1_train_4495.csv
# Renaming: glycosaminoglycan_bi_(1)_train_4603.csv → glycosaminoglycan_bi__1_train_4603.csv
# Renaming: glycosaminoglycan_bi_(1)_train_5286.csv → glycosaminoglycan_bi__1_train_5286.csv
# Renaming: glycosaminoglycan_bi_(1)_train_5476.csv → glycosaminoglycan_bi__1_train_5476.csv
# Renaming: glycosaminoglycan_bi_(1)_train_6041.csv → glycosaminoglycan_bi__1_train_6041.csv
# Renaming: glycosaminoglycan_bi_(1)_train_6364.csv → glycosaminoglycan_bi__1_train_6364.csv
# Renaming: glycosaminoglycan_bi_(1)_train_6852.csv → glycosaminoglycan_bi__1_train_6852.csv
# Renaming: glycosaminoglycan_bi_(1)_train_7496.csv → glycosaminoglycan_bi__1_train_7496.csv
# Renaming: glycosphingolipid_bi_(1)_train_1917.csv → glycosphingolipid_bi__1_train_1917.csv
# Renaming: glycosphingolipid_bi_(1)_train_1944.csv → glycosphingolipid_bi__1_train_1944.csv
# Renaming: glycosphingolipid_bi_(1)_train_2264.csv → glycosphingolipid_bi__1_train_2264.csv
# Renaming: glycosphingolipid_bi_(1)_train_2271.csv → glycosphingolipid_bi__1_train_2271.csv
# Renaming: glycosphingolipid_bi_(1)_train_3112.csv → glycosphingolipid_bi__1_train_3112.csv
# Renaming: glycosphingolipid_bi_(1)_train_4340.csv → glycosphingolipid_bi__1_train_4340.csv
# Renaming: glycosphingolipid_bi_(1)_train_4541.csv → glycosphingolipid_bi__1_train_4541.csv
# Renaming: glycosphingolipid_bi_(1)_train_6175.csv → glycosphingolipid_bi__1_train_6175.csv
# Renaming: glycosphingolipid_bi_(1)_train_8148.csv → glycosphingolipid_bi__1_train_8148.csv
# Renaming: glycosphingolipid_bi_(1)_train_9537.csv → glycosphingolipid_bi__1_train_9537.csv
# Renaming: glycosphingolipid_bi_(2)_train_1226.csv → glycosphingolipid_bi__2_train_1226.csv
# Renaming: glycosphingolipid_bi_(2)_train_1757.csv → glycosphingolipid_bi__2_train_1757.csv
# Renaming: glycosphingolipid_bi_(2)_train_2594.csv → glycosphingolipid_bi__2_train_2594.csv
# Renaming: glycosphingolipid_bi_(2)_train_3085.csv → glycosphingolipid_bi__2_train_3085.csv
# Renaming: glycosphingolipid_bi_(2)_train_4272.csv → glycosphingolipid_bi__2_train_4272.csv
# Renaming: glycosphingolipid_bi_(2)_train_4472.csv → glycosphingolipid_bi__2_train_4472.csv
# Renaming: glycosphingolipid_bi_(2)_train_6820.csv → glycosphingolipid_bi__2_train_6820.csv
# Renaming: glycosphingolipid_bi_(2)_train_7576.csv → glycosphingolipid_bi__2_train_7576.csv
# Renaming: glycosphingolipid_bi_(2)_train_7608.csv → glycosphingolipid_bi__2_train_7608.csv
# Renaming: glycosphingolipid_bi_(2)_train_9384.csv → glycosphingolipid_bi__2_train_9384.csv
# Renaming: mucin_type_o-glycan__train_1207.csv → mucin_type_o_glycan_train_1207.csv
# Renaming: mucin_type_o-glycan__train_2449.csv → mucin_type_o_glycan_train_2449.csv
# Renaming: mucin_type_o-glycan__train_4852.csv → mucin_type_o_glycan_train_4852.csv
# Renaming: mucin_type_o-glycan__train_4957.csv → mucin_type_o_glycan_train_4957.csv
# Renaming: mucin_type_o-glycan__train_5398.csv → mucin_type_o_glycan_train_5398.csv
# Renaming: mucin_type_o-glycan__train_5726.csv → mucin_type_o_glycan_train_5726.csv
# Renaming: mucin_type_o-glycan__train_5763.csv → mucin_type_o_glycan_train_5763.csv
# Renaming: mucin_type_o-glycan__train_7491.csv → mucin_type_o_glycan_train_7491.csv
# Renaming: mucin_type_o-glycan__train_7529.csv → mucin_type_o_glycan_train_7529.csv
# Renaming: mucin_type_o-glycan__train_8983.csv → mucin_type_o_glycan_train_8983.csv
# Renaming: n-glycan_biosynthesi_train_1584.csv → n_glycan_biosynthesi_train_1584.csv
# Renaming: n-glycan_biosynthesi_train_1885.csv → n_glycan_biosynthesi_train_1885.csv
# Renaming: n-glycan_biosynthesi_train_2873.csv → n_glycan_biosynthesi_train_2873.csv
# Renaming: n-glycan_biosynthesi_train_3427.csv → n_glycan_biosynthesi_train_3427.csv
# Renaming: n-glycan_biosynthesi_train_4637.csv → n_glycan_biosynthesi_train_4637.csv
# Renaming: n-glycan_biosynthesi_train_4870.csv → n_glycan_biosynthesi_train_4870.csv
# Renaming: n-glycan_biosynthesi_train_4978.csv → n_glycan_biosynthesi_train_4978.csv
# Renaming: n-glycan_biosynthesi_train_5411.csv → n_glycan_biosynthesi_train_5411.csv
# Renaming: n-glycan_biosynthesi_train_8163.csv → n_glycan_biosynthesi_train_8163.csv
# Renaming: n-glycan_biosynthesi_train_9661.csv → n_glycan_biosynthesi_train_9661.csv
# Renaming: other_types_of_o-gly_train_1299.csv → other_types_of_o_gly_train_1299.csv
# Renaming: other_types_of_o-gly_train_2394.csv → other_types_of_o_gly_train_2394.csv
# Renaming: other_types_of_o-gly_train_2494.csv → other_types_of_o_gly_train_2494.csv
# Renaming: other_types_of_o-gly_train_2893.csv → other_types_of_o_gly_train_2893.csv
# Renaming: other_types_of_o-gly_train_5221.csv → other_types_of_o_gly_train_5221.csv
# Renaming: other_types_of_o-gly_train_6244.csv → other_types_of_o_gly_train_6244.csv
# Renaming: other_types_of_o-gly_train_6246.csv → other_types_of_o_gly_train_6246.csv
# Renaming: other_types_of_o-gly_train_6804.csv → other_types_of_o_gly_train_6804.csv
# Renaming: other_types_of_o-gly_train_8552.csv → other_types_of_o_gly_train_8552.csv
# Renaming: other_types_of_o-gly_train_9407.csv → other_types_of_o_gly_train_9407.csv
# Renaming: phenylalanine,_tyros_train_1487.csv → phenylalanine__tyros_train_1487.csv
# Renaming: phenylalanine,_tyros_train_2296.csv → phenylalanine__tyros_train_2296.csv
# Renaming: phenylalanine,_tyros_train_2425.csv → phenylalanine__tyros_train_2425.csv
# Renaming: phenylalanine,_tyros_train_2724.csv → phenylalanine__tyros_train_2724.csv
# Renaming: phenylalanine,_tyros_train_3774.csv → phenylalanine__tyros_train_3774.csv
# Renaming: phenylalanine,_tyros_train_4121.csv → phenylalanine__tyros_train_4121.csv
# Renaming: phenylalanine,_tyros_train_4519.csv → phenylalanine__tyros_train_4519.csv
# Renaming: phenylalanine,_tyros_train_9302.csv → phenylalanine__tyros_train_9302.csv
# Renaming: phenylalanine,_tyros_train_9535.csv → phenylalanine__tyros_train_9535.csv
# Renaming: phenylalanine,_tyros_train_9660.csv → phenylalanine__tyros_train_9660.csv
# Renaming: README.md → readme_md
# Renaming: valine,_leucine_and__(1)_train_1008.csv → valine__leucine_and___1_train_1008.csv
# Renaming: valine,_leucine_and__(1)_train_3551.csv → valine__leucine_and___1_train_3551.csv
# Renaming: valine,_leucine_and__(1)_train_4437.csv → valine__leucine_and___1_train_4437.csv
# Renaming: valine,_leucine_and__(1)_train_5467.csv → valine__leucine_and___1_train_5467.csv
# Renaming: valine,_leucine_and__(1)_train_6589.csv → valine__leucine_and___1_train_6589.csv
# Renaming: valine,_leucine_and__(1)_train_7923.csv → valine__leucine_and___1_train_7923.csv
# Renaming: valine,_leucine_and__(1)_train_8676.csv → valine__leucine_and___1_train_8676.csv
# Renaming: valine,_leucine_and__(1)_train_9079.csv → valine__leucine_and___1_train_9079.csv
# Renaming: valine,_leucine_and__(1)_train_9534.csv → valine__leucine_and___1_train_9534.csv
# Renaming: valine,_leucine_and__(1)_train_9761.csv → valine__leucine_and___1_train_9761.csv
# Renaming: valine,_leucine_and__train_1385.csv → valine__leucine_and_train_1385.csv
# Renaming: valine,_leucine_and__train_1863.csv → valine__leucine_and_train_1863.csv
# Renaming: valine,_leucine_and__train_1950.csv → valine__leucine_and_train_1950.csv
# Renaming: valine,_leucine_and__train_3704.csv → valine__leucine_and_train_3704.csv
# Renaming: valine,_leucine_and__train_4369.csv → valine__leucine_and_train_4369.csv
# Renaming: valine,_leucine_and__train_6172.csv → valine__leucine_and_train_6172.csv
# Renaming: valine,_leucine_and__train_7204.csv → valine__leucine_and_train_7204.csv
# Renaming: valine,_leucine_and__train_7368.csv → valine__leucine_and_train_7368.csv
# Renaming: valine,_leucine_and__train_7495.csv → valine__leucine_and_train_7495.csv
# Renaming: valine,_leucine_and__train_7776.csv → valine__leucine_and_train_7776.csv
