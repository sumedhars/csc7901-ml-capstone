# %%
import torch
import torch.nn.functional as F
from torch import nn
from torch_geometric.nn import EdgeConv, NNConv
from torch_geometric.data import Data, DataLoader

# %%
import pandas as pd
import os

# %% [markdown]
# ### Load training samples

# %%
files = os.listdir('training-samples')
files = [f for f in files if os.path.isfile('training-samples'+'/'+f)]
len(files)
# Out:
# 820

# %% [markdown]
# ### Data Preparation for GNN

# %% [markdown]
# - `edge_attr`: GNN Layer can use edge feature
#     - Edge feature matrix with shape `[num_edges, num_edge_features]`
# - `edge_index`: Graph connectivity with shape `[2, num_edges]`
#
# References: https://pytorch-geometric.readthedocs.io/en/2.6.0/get_started/introduction.html#data-handling-of-graphs

# %% [markdown]
# **Create Node Label to Integer Index Mapping**
# - Extract all unique node labels from dataset (can get this from `union_ppi`)
# - Create dictionary that maps each label to a unique integer index

# %%
union_ppi = pd.read_csv('processed-data/union_ppi.txt', sep='\t', header=None)
unique_nodes = set(union_ppi[0].tolist() + union_ppi[1].tolist())

# %%
# build mapping for label -> int ID
label_id_map = {label: idx for idx, label in enumerate(sorted(unique_nodes))}
num_nodes = len(label_id_map)
print(f"Total unique nodes: {num_nodes}")
# Out:
# Total unique nodes: 17407

# %% [markdown]
# **Build the `Data` objects - one for each training sample**

# %%
data_folder = 'training-samples/'
data_list = []

for training_sample in files:
    print('Processing: ', training_sample)
    training_df = pd.read_csv(os.path.join(data_folder, training_sample), sep='\t')
    training_data = training_df.values.tolist()
    
    edge_index_list = [[], []]
    edge_attr_list = []  # each edge attribute: [prize]
    edge_labels = []     # this will get passed as data.y
    selected_edges = []  # store indices of nodes for edges with label 1

    for data_sample in training_data:
        node1, node2, prize, flag, label = data_sample
        idx1 = label_id_map[node1]
        idx2 = label_id_map[node2]
        edge_index_list[0].append(idx1)
        edge_index_list[1].append(idx2)
        edge_attr_list.append([prize])
        edge_labels.append(label)
        
        # if edge label = 1, then record its nodes
        if label == 1:
            selected_edges.append((idx1, idx2))
    
    # lists -> torch tensors
    edge_index = torch.tensor(edge_index_list, dtype=torch.long)
    edge_attr = torch.tensor(edge_attr_list, dtype=torch.float)
    edge_labels = torch.tensor(edge_labels, dtype=torch.float).view(-1, 1)
    
    # init node features: one feature per node (0 by default)
    num_nodes = len(label_id_map)
    x = torch.zeros((num_nodes, 1), dtype=torch.float)
    
    # update node features - mark nodes as 1 if they are connected by a selected edge
    for idx1, idx2 in selected_edges:
        x[idx1] = 1
        x[idx2] = 1
    
    data_obj = Data(x=x, edge_index=edge_index, edge_attr=edge_attr, y=edge_labels)
    data_obj.file_name = training_sample
    data_list.append(data_obj)
# Out:
# Processing:  biotin_metabolism_train_1902.txt
# Processing:  alanine__aspartate_a_train_2535.txt
# Processing:  alanine__aspartate_a_train_3273.txt
# Processing:  alanine__aspartate_a_train_3711.txt
# Processing:  alanine__aspartate_a_train_3781.txt
# Processing:  alanine__aspartate_a_train_6130.txt
# Processing:  alanine__aspartate_a_train_6672.txt
# Processing:  alanine__aspartate_a_train_6727.txt
# Processing:  alanine__aspartate_a_train_8527.txt
# Processing:  alanine__aspartate_a_train_9941.txt
# Processing:  alpha_linolenic_acid_train_1854.txt
# Processing:  alpha_linolenic_acid_train_2371.txt
# Processing:  alpha_linolenic_acid_train_4263.txt
# Processing:  alpha_linolenic_acid_train_4939.txt
# Processing:  alpha_linolenic_acid_train_5635.txt
# Processing:  alpha_linolenic_acid_train_5783.txt
# Processing:  alpha_linolenic_acid_train_6633.txt
# Processing:  alpha_linolenic_acid_train_7454.txt
# Processing:  alpha_linolenic_acid_train_9373.txt
# Processing:  alpha_linolenic_acid_train_9806.txt
# Processing:  aminoacyl_trna_biosy_train_1565.txt
# Processing:  aminoacyl_trna_biosy_train_2796.txt
# Processing:  aminoacyl_trna_biosy_train_3815.txt
# Processing:  aminoacyl_trna_biosy_train_3887.txt
# Processing:  aminoacyl_trna_biosy_train_4856.txt
# Processing:  aminoacyl_trna_biosy_train_5281.txt
# Processing:  aminoacyl_trna_biosy_train_5354.txt
# Processing:  aminoacyl_trna_biosy_train_7666.txt
# Processing:  aminoacyl_trna_biosy_train_8954.txt
# Processing:  aminoacyl_trna_biosy_train_9784.txt
# Processing:  beta_alanine_metabol_train_2559.txt
# Processing:  amino_sugar_and_nucl_train_1225.txt
# Processing:  amino_sugar_and_nucl_train_1494.txt
# Processing:  amino_sugar_and_nucl_train_1699.txt
# Processing:  amino_sugar_and_nucl_train_1703.txt
# Processing:  amino_sugar_and_nucl_train_1775.txt
# Processing:  amino_sugar_and_nucl_train_2444.txt
# Processing:  amino_sugar_and_nucl_train_3796.txt
# Processing:  amino_sugar_and_nucl_train_5376.txt
# Processing:  amino_sugar_and_nucl_train_6644.txt
# Processing:  amino_sugar_and_nucl_train_9691.txt
# Processing:  arachidonic_acid_met_train_1279.txt
# Processing:  arachidonic_acid_met_train_1685.txt
# Processing:  arachidonic_acid_met_train_2867.txt
# Processing:  arachidonic_acid_met_train_2983.txt
# Processing:  arachidonic_acid_met_train_3457.txt
# Processing:  arachidonic_acid_met_train_3652.txt
# Processing:  arachidonic_acid_met_train_4290.txt
# Processing:  arachidonic_acid_met_train_5322.txt
# Processing:  arachidonic_acid_met_train_6149.txt
# Processing:  arachidonic_acid_met_train_8539.txt
# Processing:  arginine_and_proline_train_1159.txt
# Processing:  arginine_and_proline_train_1355.txt
# Processing:  arginine_and_proline_train_1599.txt
# Processing:  arginine_and_proline_train_2834.txt
# Processing:  arginine_and_proline_train_3611.txt
# Processing:  arginine_and_proline_train_4399.txt
# Processing:  arginine_and_proline_train_4664.txt
# Processing:  arginine_and_proline_train_7047.txt
# Processing:  arginine_and_proline_train_8211.txt
# Processing:  arginine_and_proline_train_9140.txt
# Processing:  ascorbate_and_aldara_train_1853.txt
# Processing:  ascorbate_and_aldara_train_3317.txt
# Processing:  ascorbate_and_aldara_train_5955.txt
# Processing:  ascorbate_and_aldara_train_6755.txt
# Processing:  ascorbate_and_aldara_train_7481.txt
# Processing:  ascorbate_and_aldara_train_8171.txt
# Processing:  ascorbate_and_aldara_train_8253.txt
# Processing:  ascorbate_and_aldara_train_8407.txt
# Processing:  ascorbate_and_aldara_train_8501.txt
# Processing:  ascorbate_and_aldara_train_9303.txt
# Processing:  beta_alanine_metabol_train_2705.txt
# Processing:  beta_alanine_metabol_train_3310.txt
# Processing:  beta_alanine_metabol_train_4217.txt
# Processing:  beta_alanine_metabol_train_7014.txt
# Processing:  beta_alanine_metabol_train_7183.txt
# Processing:  beta_alanine_metabol_train_7581.txt
# Processing:  beta_alanine_metabol_train_7864.txt
# Processing:  beta_alanine_metabol_train_7979.txt
# Processing:  beta_alanine_metabol_train_8672.txt
# Processing:  citrate_cycle__tca_c_train_2573.txt
# Processing:  biosynthesis_of_unsa_train_2748.txt
# Processing:  biosynthesis_of_unsa_train_3280.txt
# Processing:  biosynthesis_of_unsa_train_3803.txt
# Processing:  biosynthesis_of_unsa_train_4552.txt
# Processing:  biosynthesis_of_unsa_train_4673.txt
# Processing:  biosynthesis_of_unsa_train_4693.txt
# Processing:  biosynthesis_of_unsa_train_5667.txt
# Processing:  biosynthesis_of_unsa_train_6279.txt
# Processing:  biosynthesis_of_unsa_train_6470.txt
# Processing:  biosynthesis_of_unsa_train_9439.txt
# Processing:  biotin_metabolism_train_2424.txt
# Processing:  biotin_metabolism_train_3135.txt
# Processing:  biotin_metabolism_train_6078.txt
# Processing:  biotin_metabolism_train_6989.txt
# Processing:  biotin_metabolism_train_7622.txt
# Processing:  biotin_metabolism_train_7625.txt
# Processing:  biotin_metabolism_train_7733.txt
# Processing:  biotin_metabolism_train_8673.txt
# Processing:  biotin_metabolism_train_9514.txt
# Processing:  butanoate_metabolism_train_1100.txt
# Processing:  butanoate_metabolism_train_1491.txt
# Processing:  butanoate_metabolism_train_4180.txt
# Processing:  butanoate_metabolism_train_4190.txt
# Processing:  butanoate_metabolism_train_4460.txt
# Processing:  butanoate_metabolism_train_5284.txt
# Processing:  butanoate_metabolism_train_5885.txt
# Processing:  butanoate_metabolism_train_6334.txt
# Processing:  butanoate_metabolism_train_8350.txt
# Processing:  butanoate_metabolism_train_8741.txt
# Processing:  butirosin_and_neomyc_train_1241.txt
# Processing:  butirosin_and_neomyc_train_1721.txt
# Processing:  butirosin_and_neomyc_train_2981.txt
# Processing:  butirosin_and_neomyc_train_4135.txt
# Processing:  butirosin_and_neomyc_train_4159.txt
# Processing:  butirosin_and_neomyc_train_4999.txt
# Processing:  butirosin_and_neomyc_train_5617.txt
# Processing:  butirosin_and_neomyc_train_6864.txt
# Processing:  butirosin_and_neomyc_train_7673.txt
# Processing:  butirosin_and_neomyc_train_9691.txt
# Processing:  caffeine_metabolism_train_1005.txt
# Processing:  caffeine_metabolism_train_3176.txt
# Processing:  caffeine_metabolism_train_3718.txt
# Processing:  caffeine_metabolism_train_4187.txt
# Processing:  caffeine_metabolism_train_4536.txt
# Processing:  caffeine_metabolism_train_4696.txt
# Processing:  caffeine_metabolism_train_6505.txt
# Processing:  caffeine_metabolism_train_8310.txt
# Processing:  caffeine_metabolism_train_9240.txt
# Processing:  caffeine_metabolism_train_9692.txt
# Processing:  citrate_cycle__tca_c_train_3071.txt
# Processing:  citrate_cycle__tca_c_train_3195.txt
# Processing:  citrate_cycle__tca_c_train_5290.txt
# Processing:  citrate_cycle__tca_c_train_5392.txt
# Processing:  citrate_cycle__tca_c_train_5519.txt
# Processing:  citrate_cycle__tca_c_train_6720.txt
# Processing:  citrate_cycle__tca_c_train_6943.txt
# Processing:  citrate_cycle__tca_c_train_8425.txt
# Processing:  citrate_cycle__tca_c_train_8698.txt
# Processing:  d_arginine_and_d_orn_train_1815.txt
# Processing:  cyanoamino_acid_meta_train_2368.txt
# Processing:  cyanoamino_acid_meta_train_2915.txt
# Processing:  cyanoamino_acid_meta_train_3267.txt
# Processing:  cyanoamino_acid_meta_train_3747.txt
# Processing:  cyanoamino_acid_meta_train_5188.txt
# Processing:  cyanoamino_acid_meta_train_7427.txt
# Processing:  cyanoamino_acid_meta_train_8701.txt
# Processing:  cyanoamino_acid_meta_train_8714.txt
# Processing:  cyanoamino_acid_meta_train_8911.txt
# Processing:  cyanoamino_acid_meta_train_9451.txt
# Processing:  cysteine_and_methion_train_2826.txt
# Processing:  cysteine_and_methion_train_3400.txt
# Processing:  cysteine_and_methion_train_3415.txt
# Processing:  cysteine_and_methion_train_3585.txt
# Processing:  cysteine_and_methion_train_5119.txt
# Processing:  cysteine_and_methion_train_7360.txt
# Processing:  cysteine_and_methion_train_8208.txt
# Processing:  cysteine_and_methion_train_8285.txt
# Processing:  cysteine_and_methion_train_8949.txt
# Processing:  cysteine_and_methion_train_9500.txt
# Processing:  d_arginine_and_d_orn_train_2204.txt
# Processing:  d_arginine_and_d_orn_train_3096.txt
# Processing:  d_arginine_and_d_orn_train_3362.txt
# Processing:  d_arginine_and_d_orn_train_4582.txt
# Processing:  d_arginine_and_d_orn_train_4827.txt
# Processing:  d_arginine_and_d_orn_train_5224.txt
# Processing:  d_arginine_and_d_orn_train_6276.txt
# Processing:  d_arginine_and_d_orn_train_6400.txt
# Processing:  d_arginine_and_d_orn_train_8863.txt
# Processing:  d_glutamine_and_d_gl_train_3853.txt
# Processing:  d_glutamine_and_d_gl_train_5918.txt
# Processing:  d_glutamine_and_d_gl_train_6415.txt
# Processing:  d_glutamine_and_d_gl_train_6453.txt
# Processing:  d_glutamine_and_d_gl_train_6575.txt
# Processing:  d_glutamine_and_d_gl_train_7147.txt
# Processing:  d_glutamine_and_d_gl_train_7653.txt
# Processing:  d_glutamine_and_d_gl_train_8627.txt
# Processing:  d_glutamine_and_d_gl_train_9192.txt
# Processing:  d_glutamine_and_d_gl_train_9381.txt
# Processing:  drug_metabolism___cy_train_1576.txt
# Processing:  drug_metabolism___cy_train_2581.txt
# Processing:  drug_metabolism___cy_train_2665.txt
# Processing:  drug_metabolism___cy_train_3545.txt
# Processing:  drug_metabolism___cy_train_4503.txt
# Processing:  drug_metabolism___cy_train_6262.txt
# Processing:  drug_metabolism___cy_train_7207.txt
# Processing:  drug_metabolism___cy_train_7291.txt
# Processing:  drug_metabolism___cy_train_7643.txt
# Processing:  drug_metabolism___cy_train_7684.txt
# Processing:  drug_metabolism___ot_train_1108.txt
# Processing:  drug_metabolism___ot_train_1722.txt
# Processing:  drug_metabolism___ot_train_1801.txt
# Processing:  drug_metabolism___ot_train_4485.txt
# Processing:  drug_metabolism___ot_train_5565.txt
# Processing:  drug_metabolism___ot_train_6155.txt
# Processing:  drug_metabolism___ot_train_6253.txt
# Processing:  drug_metabolism___ot_train_6288.txt
# Processing:  drug_metabolism___ot_train_8702.txt
# Processing:  drug_metabolism___ot_train_9953.txt
# Processing:  glycerophospholipid_train_1191.txt
# Processing:  ether_lipid_metaboli_train_1598.txt
# Processing:  ether_lipid_metaboli_train_2397.txt
# Processing:  ether_lipid_metaboli_train_3063.txt
# Processing:  ether_lipid_metaboli_train_3321.txt
# Processing:  ether_lipid_metaboli_train_3747.txt
# Processing:  ether_lipid_metaboli_train_4088.txt
# Processing:  ether_lipid_metaboli_train_4815.txt
# Processing:  ether_lipid_metaboli_train_6855.txt
# Processing:  ether_lipid_metaboli_train_7450.txt
# Processing:  ether_lipid_metaboli_train_9182.txt
# Processing:  fatty_acid_biosynthe_train_1183.txt
# Processing:  fatty_acid_biosynthe_train_1363.txt
# Processing:  fatty_acid_biosynthe_train_1749.txt
# Processing:  fatty_acid_biosynthe_train_6264.txt
# Processing:  fatty_acid_biosynthe_train_6304.txt
# Processing:  fatty_acid_biosynthe_train_7404.txt
# Processing:  fatty_acid_biosynthe_train_7456.txt
# Processing:  fatty_acid_biosynthe_train_8014.txt
# Processing:  fatty_acid_biosynthe_train_8694.txt
# Processing:  fatty_acid_biosynthe_train_9579.txt
# Processing:  fatty_acid_degradati_train_2123.txt
# Processing:  fatty_acid_degradati_train_2826.txt
# Processing:  fatty_acid_degradati_train_2865.txt
# Processing:  fatty_acid_degradati_train_2978.txt
# Processing:  fatty_acid_degradati_train_3240.txt
# Processing:  fatty_acid_degradati_train_3405.txt
# Processing:  fatty_acid_degradati_train_4206.txt
# Processing:  fatty_acid_degradati_train_7616.txt
# Processing:  fatty_acid_degradati_train_8270.txt
# Processing:  fatty_acid_degradati_train_8271.txt
# Processing:  fatty_acid_elongatio_train_1228.txt
# Processing:  fatty_acid_elongatio_train_2789.txt
# Processing:  fatty_acid_elongatio_train_3530.txt
# Processing:  fatty_acid_elongatio_train_3978.txt
# Processing:  fatty_acid_elongatio_train_4051.txt
# Processing:  fatty_acid_elongatio_train_4296.txt
# Processing:  fatty_acid_elongatio_train_6026.txt
# Processing:  fatty_acid_elongatio_train_6374.txt
# Processing:  fatty_acid_elongatio_train_7460.txt
# Processing:  fatty_acid_elongatio_train_7810.txt
# Processing:  folate_biosynthesis_train_3178.txt
# Processing:  folate_biosynthesis_train_3931.txt
# Processing:  folate_biosynthesis_train_4994.txt
# Processing:  folate_biosynthesis_train_5097.txt
# Processing:  folate_biosynthesis_train_5346.txt
# Processing:  folate_biosynthesis_train_5773.txt
# Processing:  folate_biosynthesis_train_8418.txt
# Processing:  folate_biosynthesis_train_8579.txt
# Processing:  folate_biosynthesis_train_9363.txt
# Processing:  folate_biosynthesis_train_9494.txt
# Processing:  fructose_and_mannose_train_1791.txt
# Processing:  fructose_and_mannose_train_1904.txt
# Processing:  fructose_and_mannose_train_5194.txt
# Processing:  fructose_and_mannose_train_5404.txt
# Processing:  fructose_and_mannose_train_6210.txt
# Processing:  fructose_and_mannose_train_6584.txt
# Processing:  fructose_and_mannose_train_6794.txt
# Processing:  fructose_and_mannose_train_8580.txt
# Processing:  fructose_and_mannose_train_9217.txt
# Processing:  fructose_and_mannose_train_9475.txt
# Processing:  galactose_metabolism_train_1510.txt
# Processing:  galactose_metabolism_train_2135.txt
# Processing:  galactose_metabolism_train_3584.txt
# Processing:  galactose_metabolism_train_4572.txt
# Processing:  galactose_metabolism_train_4802.txt
# Processing:  galactose_metabolism_train_4880.txt
# Processing:  galactose_metabolism_train_5798.txt
# Processing:  galactose_metabolism_train_7283.txt
# Processing:  galactose_metabolism_train_8272.txt
# Processing:  galactose_metabolism_train_8430.txt
# Processing:  glutathione_metaboli_train_1578.txt
# Processing:  glutathione_metaboli_train_1590.txt
# Processing:  glutathione_metaboli_train_2142.txt
# Processing:  glutathione_metaboli_train_3693.txt
# Processing:  glutathione_metaboli_train_3710.txt
# Processing:  glutathione_metaboli_train_4039.txt
# Processing:  glutathione_metaboli_train_4479.txt
# Processing:  glutathione_metaboli_train_5956.txt
# Processing:  glutathione_metaboli_train_7124.txt
# Processing:  glutathione_metaboli_train_8472.txt
# Processing:  glycerolipid_metabol_train_1672.txt
# Processing:  glycerolipid_metabol_train_3584.txt
# Processing:  glycerolipid_metabol_train_4441.txt
# Processing:  glycerolipid_metabol_train_4745.txt
# Processing:  glycerolipid_metabol_train_5382.txt
# Processing:  glycerolipid_metabol_train_5932.txt
# Processing:  glycerolipid_metabol_train_6242.txt
# Processing:  glycerolipid_metabol_train_6560.txt
# Processing:  glycerolipid_metabol_train_7776.txt
# Processing:  glycerolipid_metabol_train_8006.txt
# Processing:  glycerophospholipid_train_2901.txt
# Processing:  glycerophospholipid_train_3243.txt
# Processing:  glycerophospholipid_train_3822.txt
# Processing:  glycerophospholipid_train_5031.txt
# Processing:  glycerophospholipid_train_6257.txt
# Processing:  glycerophospholipid_train_8627.txt
# Processing:  glycerophospholipid_train_8885.txt
# Processing:  glycerophospholipid_train_9385.txt
# Processing:  glycerophospholipid_train_9901.txt
# Processing:  glycine__serine_and_train_1327.txt
# Processing:  glycine__serine_and_train_1578.txt
# Processing:  glycine__serine_and_train_4766.txt
# Processing:  glycine__serine_and_train_6145.txt
# Processing:  glycine__serine_and_train_8019.txt
# Processing:  glycine__serine_and_train_8569.txt
# Processing:  glycine__serine_and_train_8859.txt
# Processing:  glycine__serine_and_train_8905.txt
# Processing:  glycine__serine_and_train_9194.txt
# Processing:  glycine__serine_and_train_9687.txt
# Processing:  glycosaminoglycan_bi__1_train_4029.txt
# Processing:  glycolysis___glucone_train_2851.txt
# Processing:  glycolysis___glucone_train_3045.txt
# Processing:  glycolysis___glucone_train_3272.txt
# Processing:  glycolysis___glucone_train_3351.txt
# Processing:  glycolysis___glucone_train_7341.txt
# Processing:  glycolysis___glucone_train_7813.txt
# Processing:  glycolysis___glucone_train_8450.txt
# Processing:  glycolysis___glucone_train_9461.txt
# Processing:  glycolysis___glucone_train_9576.txt
# Processing:  glycolysis___glucone_train_9972.txt
# Processing:  glycosaminoglycan_bi__1_train_4067.txt
# Processing:  glycosaminoglycan_bi__1_train_4495.txt
# Processing:  glycosaminoglycan_bi__1_train_4603.txt
# Processing:  glycosaminoglycan_bi__1_train_5286.txt
# Processing:  glycosaminoglycan_bi__1_train_5476.txt
# Processing:  glycosaminoglycan_bi__1_train_6041.txt
# Processing:  glycosaminoglycan_bi__1_train_6364.txt
# Processing:  glycosaminoglycan_bi__1_train_6852.txt
# Processing:  glycosaminoglycan_bi__1_train_7496.txt
# Processing:  glycosphingolipid_bi__1_train_1917.txt
# Processing:  glycosaminoglycan_bi_train_2241.txt
# Processing:  glycosaminoglycan_bi_train_4526.txt
# Processing:  glycosaminoglycan_bi_train_6131.txt
# Processing:  glycosaminoglycan_bi_train_6194.txt
# Processing:  glycosaminoglycan_bi_train_7399.txt
# Processing:  glycosaminoglycan_bi_train_7747.txt
# Processing:  glycosaminoglycan_bi_train_8023.txt
# Processing:  glycosaminoglycan_bi_train_9258.txt
# Processing:  glycosaminoglycan_bi_train_9612.txt
# Processing:  glycosaminoglycan_bi_train_9670.txt
# Processing:  glycosaminoglycan_de_train_1224.txt
# Processing:  glycosaminoglycan_de_train_1711.txt
# Processing:  glycosaminoglycan_de_train_2488.txt
# Processing:  glycosaminoglycan_de_train_3162.txt
# Processing:  glycosaminoglycan_de_train_3395.txt
# Processing:  glycosaminoglycan_de_train_4549.txt
# Processing:  glycosaminoglycan_de_train_4714.txt
# Processing:  glycosaminoglycan_de_train_7274.txt
# Processing:  glycosaminoglycan_de_train_8470.txt
# Processing:  glycosaminoglycan_de_train_9198.txt
# Processing:  glycosphingolipid_bi__1_train_1944.txt
# Processing:  glycosphingolipid_bi__1_train_2264.txt
# Processing:  glycosphingolipid_bi__1_train_2271.txt
# Processing:  glycosphingolipid_bi__1_train_3112.txt
# Processing:  glycosphingolipid_bi__1_train_4340.txt
# Processing:  glycosphingolipid_bi__1_train_4541.txt
# Processing:  glycosphingolipid_bi__1_train_6175.txt
# Processing:  glycosphingolipid_bi__1_train_8148.txt
# Processing:  glycosphingolipid_bi__1_train_9537.txt
# Processing:  glycosphingolipid_bi__2_train_1226.txt
# Processing:  glycosphingolipid_bi__2_train_1757.txt
# Processing:  glycosphingolipid_bi__2_train_2594.txt
# Processing:  glycosphingolipid_bi__2_train_3085.txt
# Processing:  glycosphingolipid_bi__2_train_4272.txt
# Processing:  glycosphingolipid_bi__2_train_4472.txt
# Processing:  glycosphingolipid_bi__2_train_6820.txt
# Processing:  glycosphingolipid_bi__2_train_7576.txt
# Processing:  glycosphingolipid_bi__2_train_7608.txt
# Processing:  glycosphingolipid_bi__2_train_9384.txt
# Processing:  mucin_type_o_glycan_train_1207.txt
# Processing:  glycosphingolipid_bi_train_2504.txt
# Processing:  glycosphingolipid_bi_train_2926.txt
# Processing:  glycosphingolipid_bi_train_4181.txt
# Processing:  glycosphingolipid_bi_train_4993.txt
# Processing:  glycosphingolipid_bi_train_5121.txt
# Processing:  glycosphingolipid_bi_train_5557.txt
# Processing:  glycosphingolipid_bi_train_7369.txt
# Processing:  glycosphingolipid_bi_train_7507.txt
# Processing:  glycosphingolipid_bi_train_8993.txt
# Processing:  glycosphingolipid_bi_train_9168.txt
# Processing:  glycosylphosphatidyl_train_2059.txt
# Processing:  glycosylphosphatidyl_train_2533.txt
# Processing:  glycosylphosphatidyl_train_3575.txt
# Processing:  glycosylphosphatidyl_train_3818.txt
# Processing:  glycosylphosphatidyl_train_5632.txt
# Processing:  glycosylphosphatidyl_train_6909.txt
# Processing:  glycosylphosphatidyl_train_7490.txt
# Processing:  glycosylphosphatidyl_train_8203.txt
# Processing:  glycosylphosphatidyl_train_8703.txt
# Processing:  glycosylphosphatidyl_train_8928.txt
# Processing:  glyoxylate_and_dicar_train_1587.txt
# Processing:  glyoxylate_and_dicar_train_2960.txt
# Processing:  glyoxylate_and_dicar_train_2996.txt
# Processing:  glyoxylate_and_dicar_train_3343.txt
# Processing:  glyoxylate_and_dicar_train_3794.txt
# Processing:  glyoxylate_and_dicar_train_4579.txt
# Processing:  glyoxylate_and_dicar_train_7549.txt
# Processing:  glyoxylate_and_dicar_train_8802.txt
# Processing:  glyoxylate_and_dicar_train_9051.txt
# Processing:  glyoxylate_and_dicar_train_9556.txt
# Processing:  histidine_metabolism_train_1209.txt
# Processing:  histidine_metabolism_train_2211.txt
# Processing:  histidine_metabolism_train_3733.txt
# Processing:  histidine_metabolism_train_4981.txt
# Processing:  histidine_metabolism_train_4986.txt
# Processing:  histidine_metabolism_train_5160.txt
# Processing:  histidine_metabolism_train_5677.txt
# Processing:  histidine_metabolism_train_6614.txt
# Processing:  histidine_metabolism_train_8687.txt
# Processing:  histidine_metabolism_train_9640.txt
# Processing:  inositol_phosphate_m_train_1337.txt
# Processing:  inositol_phosphate_m_train_3161.txt
# Processing:  inositol_phosphate_m_train_3768.txt
# Processing:  inositol_phosphate_m_train_4787.txt
# Processing:  inositol_phosphate_m_train_5151.txt
# Processing:  inositol_phosphate_m_train_5254.txt
# Processing:  inositol_phosphate_m_train_6383.txt
# Processing:  inositol_phosphate_m_train_8965.txt
# Processing:  inositol_phosphate_m_train_9162.txt
# Processing:  inositol_phosphate_m_train_9582.txt
# Processing:  linoleic_acid_metabo_train_3626.txt
# Processing:  linoleic_acid_metabo_train_4253.txt
# Processing:  linoleic_acid_metabo_train_5657.txt
# Processing:  linoleic_acid_metabo_train_8221.txt
# Processing:  linoleic_acid_metabo_train_8653.txt
# Processing:  linoleic_acid_metabo_train_9139.txt
# Processing:  linoleic_acid_metabo_train_9252.txt
# Processing:  linoleic_acid_metabo_train_9553.txt
# Processing:  linoleic_acid_metabo_train_9785.txt
# Processing:  linoleic_acid_metabo_train_9824.txt
# Processing:  lipoic_acid_metaboli_train_1385.txt
# Processing:  lipoic_acid_metaboli_train_5732.txt
# Processing:  lipoic_acid_metaboli_train_6169.txt
# Processing:  lipoic_acid_metaboli_train_6350.txt
# Processing:  lipoic_acid_metaboli_train_6521.txt
# Processing:  lipoic_acid_metaboli_train_8189.txt
# Processing:  lipoic_acid_metaboli_train_8395.txt
# Processing:  lipoic_acid_metaboli_train_8541.txt
# Processing:  lipoic_acid_metaboli_train_8728.txt
# Processing:  lipoic_acid_metaboli_train_8800.txt
# Processing:  lysine_biosynthesis_train_1871.txt
# Processing:  lysine_biosynthesis_train_2016.txt
# Processing:  lysine_biosynthesis_train_2992.txt
# Processing:  lysine_biosynthesis_train_4196.txt
# Processing:  lysine_biosynthesis_train_4741.txt
# Processing:  lysine_biosynthesis_train_6293.txt
# Processing:  lysine_biosynthesis_train_8435.txt
# Processing:  lysine_biosynthesis_train_8442.txt
# Processing:  lysine_biosynthesis_train_8594.txt
# Processing:  lysine_biosynthesis_train_9154.txt
# Processing:  lysine_degradation_train_1177.txt
# Processing:  lysine_degradation_train_1404.txt
# Processing:  lysine_degradation_train_3915.txt
# Processing:  lysine_degradation_train_5043.txt
# Processing:  lysine_degradation_train_6900.txt
# Processing:  lysine_degradation_train_7617.txt
# Processing:  lysine_degradation_train_8293.txt
# Processing:  lysine_degradation_train_8754.txt
# Processing:  lysine_degradation_train_9667.txt
# Processing:  lysine_degradation_train_9699.txt
# Processing:  metabolism_of_xenobi_train_1891.txt
# Processing:  metabolism_of_xenobi_train_2276.txt
# Processing:  metabolism_of_xenobi_train_3385.txt
# Processing:  metabolism_of_xenobi_train_4073.txt
# Processing:  metabolism_of_xenobi_train_5605.txt
# Processing:  metabolism_of_xenobi_train_5862.txt
# Processing:  metabolism_of_xenobi_train_6798.txt
# Processing:  metabolism_of_xenobi_train_7505.txt
# Processing:  metabolism_of_xenobi_train_8796.txt
# Processing:  metabolism_of_xenobi_train_9086.txt
# Processing:  mucin_type_o_glycan_train_2449.txt
# Processing:  mucin_type_o_glycan_train_4852.txt
# Processing:  mucin_type_o_glycan_train_4957.txt
# Processing:  mucin_type_o_glycan_train_5398.txt
# Processing:  mucin_type_o_glycan_train_5726.txt
# Processing:  mucin_type_o_glycan_train_5763.txt
# Processing:  mucin_type_o_glycan_train_7491.txt
# Processing:  mucin_type_o_glycan_train_7529.txt
# Processing:  mucin_type_o_glycan_train_8983.txt
# Processing:  n_glycan_biosynthesi_train_1584.txt
# Processing:  n_glycan_biosynthesi_train_1885.txt
# Processing:  n_glycan_biosynthesi_train_2873.txt
# Processing:  n_glycan_biosynthesi_train_3427.txt
# Processing:  n_glycan_biosynthesi_train_4637.txt
# Processing:  n_glycan_biosynthesi_train_4870.txt
# Processing:  n_glycan_biosynthesi_train_4978.txt
# Processing:  n_glycan_biosynthesi_train_5411.txt
# Processing:  n_glycan_biosynthesi_train_8163.txt
# Processing:  n_glycan_biosynthesi_train_9661.txt
# Processing:  other_types_of_o_gly_train_1299.txt
# Processing:  nicotinate_and_nicot_train_1497.txt
# Processing:  nicotinate_and_nicot_train_1758.txt
# Processing:  nicotinate_and_nicot_train_3074.txt
# Processing:  nicotinate_and_nicot_train_3087.txt
# Processing:  nicotinate_and_nicot_train_4621.txt
# Processing:  nicotinate_and_nicot_train_4753.txt
# Processing:  nicotinate_and_nicot_train_5849.txt
# Processing:  nicotinate_and_nicot_train_6359.txt
# Processing:  nicotinate_and_nicot_train_6943.txt
# Processing:  nicotinate_and_nicot_train_9363.txt
# Processing:  nitrogen_metabolism_train_3442.txt
# Processing:  nitrogen_metabolism_train_4157.txt
# Processing:  nitrogen_metabolism_train_4204.txt
# Processing:  nitrogen_metabolism_train_6141.txt
# Processing:  nitrogen_metabolism_train_7075.txt
# Processing:  nitrogen_metabolism_train_7440.txt
# Processing:  nitrogen_metabolism_train_8986.txt
# Processing:  nitrogen_metabolism_train_9395.txt
# Processing:  nitrogen_metabolism_train_9476.txt
# Processing:  nitrogen_metabolism_train_9511.txt
# Processing:  one_carbon_pool_by_f_train_1293.txt
# Processing:  one_carbon_pool_by_f_train_1466.txt
# Processing:  one_carbon_pool_by_f_train_1656.txt
# Processing:  one_carbon_pool_by_f_train_1671.txt
# Processing:  one_carbon_pool_by_f_train_3035.txt
# Processing:  one_carbon_pool_by_f_train_3699.txt
# Processing:  one_carbon_pool_by_f_train_4046.txt
# Processing:  one_carbon_pool_by_f_train_4656.txt
# Processing:  one_carbon_pool_by_f_train_5988.txt
# Processing:  one_carbon_pool_by_f_train_9250.txt
# Processing:  other_types_of_o_gly_train_2394.txt
# Processing:  other_types_of_o_gly_train_2494.txt
# Processing:  other_types_of_o_gly_train_2893.txt
# Processing:  other_types_of_o_gly_train_5221.txt
# Processing:  other_types_of_o_gly_train_6244.txt
# Processing:  other_types_of_o_gly_train_6246.txt
# Processing:  other_types_of_o_gly_train_6804.txt
# Processing:  other_types_of_o_gly_train_8552.txt
# Processing:  other_types_of_o_gly_train_9407.txt
# Processing:  phenylalanine__tyros_train_1487.txt
# Processing:  pantothenate_and_coa_train_2787.txt
# Processing:  pantothenate_and_coa_train_3035.txt
# Processing:  pantothenate_and_coa_train_7239.txt
# Processing:  pantothenate_and_coa_train_7317.txt
# Processing:  pantothenate_and_coa_train_7783.txt
# Processing:  pantothenate_and_coa_train_8164.txt
# Processing:  pantothenate_and_coa_train_8176.txt
# Processing:  pantothenate_and_coa_train_8645.txt
# Processing:  pantothenate_and_coa_train_8812.txt
# Processing:  pantothenate_and_coa_train_9992.txt
# Processing:  pentose_and_glucuron_train_1585.txt
# Processing:  pentose_and_glucuron_train_3424.txt
# Processing:  pentose_and_glucuron_train_5502.txt
# Processing:  pentose_and_glucuron_train_5923.txt
# Processing:  pentose_and_glucuron_train_6395.txt
# Processing:  pentose_and_glucuron_train_6832.txt
# Processing:  pentose_and_glucuron_train_6872.txt
# Processing:  pentose_and_glucuron_train_7254.txt
# Processing:  pentose_and_glucuron_train_7711.txt
# Processing:  pentose_and_glucuron_train_8480.txt
# Processing:  pentose_phosphate_pa_train_1208.txt
# Processing:  pentose_phosphate_pa_train_1506.txt
# Processing:  pentose_phosphate_pa_train_1855.txt
# Processing:  pentose_phosphate_pa_train_2673.txt
# Processing:  pentose_phosphate_pa_train_3930.txt
# Processing:  pentose_phosphate_pa_train_4578.txt
# Processing:  pentose_phosphate_pa_train_5518.txt
# Processing:  pentose_phosphate_pa_train_6584.txt
# Processing:  pentose_phosphate_pa_train_8739.txt
# Processing:  pentose_phosphate_pa_train_9496.txt
# Processing:  phenylalanine__tyros_train_2296.txt
# Processing:  phenylalanine__tyros_train_2425.txt
# Processing:  phenylalanine__tyros_train_2724.txt
# Processing:  phenylalanine__tyros_train_3774.txt
# Processing:  phenylalanine__tyros_train_4121.txt
# Processing:  phenylalanine__tyros_train_4519.txt
# Processing:  phenylalanine__tyros_train_9302.txt
# Processing:  phenylalanine__tyros_train_9535.txt
# Processing:  phenylalanine__tyros_train_9660.txt
# Processing:  phenylalanine_metabo_train_1899.txt
# Processing:  phenylalanine_metabo_train_2067.txt
# Processing:  phenylalanine_metabo_train_2940.txt
# Processing:  phenylalanine_metabo_train_3213.txt
# Processing:  phenylalanine_metabo_train_5357.txt
# Processing:  phenylalanine_metabo_train_7746.txt
# Processing:  phenylalanine_metabo_train_7866.txt
# Processing:  phenylalanine_metabo_train_7995.txt
# Processing:  phenylalanine_metabo_train_8640.txt
# Processing:  phenylalanine_metabo_train_9455.txt
# Processing:  porphyrin_and_chloro_train_1972.txt
# Processing:  porphyrin_and_chloro_train_4809.txt
# Processing:  porphyrin_and_chloro_train_4873.txt
# Processing:  porphyrin_and_chloro_train_4997.txt
# Processing:  porphyrin_and_chloro_train_5886.txt
# Processing:  porphyrin_and_chloro_train_6811.txt
# Processing:  porphyrin_and_chloro_train_6817.txt
# Processing:  porphyrin_and_chloro_train_7647.txt
# Processing:  porphyrin_and_chloro_train_8022.txt
# Processing:  porphyrin_and_chloro_train_8247.txt
# Processing:  primary_bile_acid_bi_train_2793.txt
# Processing:  primary_bile_acid_bi_train_3795.txt
# Processing:  primary_bile_acid_bi_train_4552.txt
# Processing:  primary_bile_acid_bi_train_4704.txt
# Processing:  primary_bile_acid_bi_train_7460.txt
# Processing:  primary_bile_acid_bi_train_7793.txt
# Processing:  primary_bile_acid_bi_train_8404.txt
# Processing:  primary_bile_acid_bi_train_8799.txt
# Processing:  primary_bile_acid_bi_train_9453.txt
# Processing:  primary_bile_acid_bi_train_9990.txt
# Processing:  propanoate_metabolis_train_1641.txt
# Processing:  propanoate_metabolis_train_2104.txt
# Processing:  propanoate_metabolis_train_2520.txt
# Processing:  propanoate_metabolis_train_4916.txt
# Processing:  propanoate_metabolis_train_5106.txt
# Processing:  propanoate_metabolis_train_6366.txt
# Processing:  propanoate_metabolis_train_6395.txt
# Processing:  propanoate_metabolis_train_7079.txt
# Processing:  propanoate_metabolis_train_8432.txt
# Processing:  propanoate_metabolis_train_9228.txt
# Processing:  purine_metabolism_train_1035.txt
# Processing:  purine_metabolism_train_1409.txt
# Processing:  purine_metabolism_train_1425.txt
# Processing:  purine_metabolism_train_2263.txt
# Processing:  purine_metabolism_train_3580.txt
# Processing:  purine_metabolism_train_3657.txt
# Processing:  purine_metabolism_train_5896.txt
# Processing:  purine_metabolism_train_7936.txt
# Processing:  purine_metabolism_train_9503.txt
# Processing:  purine_metabolism_train_9583.txt
# Processing:  pyrimidine_metabolis_train_1423.txt
# Processing:  pyrimidine_metabolis_train_1615.txt
# Processing:  pyrimidine_metabolis_train_1990.txt
# Processing:  pyrimidine_metabolis_train_3799.txt
# Processing:  pyrimidine_metabolis_train_5325.txt
# Processing:  pyrimidine_metabolis_train_5903.txt
# Processing:  pyrimidine_metabolis_train_7160.txt
# Processing:  pyrimidine_metabolis_train_7241.txt
# Processing:  pyrimidine_metabolis_train_8850.txt
# Processing:  pyrimidine_metabolis_train_9011.txt
# Processing:  pyruvate_metabolism_train_2459.txt
# Processing:  pyruvate_metabolism_train_2623.txt
# Processing:  pyruvate_metabolism_train_2916.txt
# Processing:  pyruvate_metabolism_train_3848.txt
# Processing:  pyruvate_metabolism_train_3867.txt
# Processing:  pyruvate_metabolism_train_4916.txt
# Processing:  pyruvate_metabolism_train_6622.txt
# Processing:  pyruvate_metabolism_train_7292.txt
# Processing:  pyruvate_metabolism_train_7605.txt
# Processing:  pyruvate_metabolism_train_9622.txt
# Processing:  retinol_metabolism_train_1453.txt
# Processing:  retinol_metabolism_train_3755.txt
# Processing:  sulfur_metabolism_train_1891.txt
# Processing:  retinol_metabolism_train_3941.txt
# Processing:  retinol_metabolism_train_4089.txt
# Processing:  retinol_metabolism_train_5470.txt
# Processing:  retinol_metabolism_train_6244.txt
# Processing:  retinol_metabolism_train_8393.txt
# Processing:  retinol_metabolism_train_8948.txt
# Processing:  retinol_metabolism_train_9167.txt
# Processing:  retinol_metabolism_train_9664.txt
# Processing:  riboflavin_metabolis_train_1552.txt
# Processing:  riboflavin_metabolis_train_2807.txt
# Processing:  riboflavin_metabolis_train_4802.txt
# Processing:  riboflavin_metabolis_train_4823.txt
# Processing:  riboflavin_metabolis_train_5743.txt
# Processing:  riboflavin_metabolis_train_5826.txt
# Processing:  riboflavin_metabolis_train_5918.txt
# Processing:  riboflavin_metabolis_train_6043.txt
# Processing:  riboflavin_metabolis_train_6750.txt
# Processing:  riboflavin_metabolis_train_9684.txt
# Processing:  selenocompound_metab_train_1652.txt
# Processing:  selenocompound_metab_train_2780.txt
# Processing:  selenocompound_metab_train_5417.txt
# Processing:  selenocompound_metab_train_5508.txt
# Processing:  selenocompound_metab_train_5553.txt
# Processing:  selenocompound_metab_train_7080.txt
# Processing:  selenocompound_metab_train_8078.txt
# Processing:  selenocompound_metab_train_8196.txt
# Processing:  selenocompound_metab_train_8403.txt
# Processing:  selenocompound_metab_train_9397.txt
# Processing:  sphingolipid_metabol_train_1064.txt
# Processing:  sphingolipid_metabol_train_2299.txt
# Processing:  sphingolipid_metabol_train_3883.txt
# Processing:  sphingolipid_metabol_train_5576.txt
# Processing:  sphingolipid_metabol_train_6402.txt
# Processing:  sphingolipid_metabol_train_7075.txt
# Processing:  sphingolipid_metabol_train_7417.txt
# Processing:  sphingolipid_metabol_train_7532.txt
# Processing:  sphingolipid_metabol_train_7670.txt
# Processing:  sphingolipid_metabol_train_8777.txt
# Processing:  starch_and_sucrose_m_train_1473.txt
# Processing:  starch_and_sucrose_m_train_2356.txt
# Processing:  starch_and_sucrose_m_train_3953.txt
# Processing:  starch_and_sucrose_m_train_4604.txt
# Processing:  starch_and_sucrose_m_train_5326.txt
# Processing:  starch_and_sucrose_m_train_5329.txt
# Processing:  starch_and_sucrose_m_train_5671.txt
# Processing:  starch_and_sucrose_m_train_5869.txt
# Processing:  starch_and_sucrose_m_train_5925.txt
# Processing:  starch_and_sucrose_m_train_8147.txt
# Processing:  steroid_biosynthesis_train_1126.txt
# Processing:  steroid_biosynthesis_train_3268.txt
# Processing:  steroid_biosynthesis_train_4516.txt
# Processing:  steroid_biosynthesis_train_5084.txt
# Processing:  steroid_biosynthesis_train_5609.txt
# Processing:  steroid_biosynthesis_train_7878.txt
# Processing:  steroid_biosynthesis_train_8131.txt
# Processing:  steroid_biosynthesis_train_8821.txt
# Processing:  steroid_biosynthesis_train_9054.txt
# Processing:  steroid_biosynthesis_train_9585.txt
# Processing:  steroid_hormone_bios_train_2497.txt
# Processing:  steroid_hormone_bios_train_2798.txt
# Processing:  steroid_hormone_bios_train_4468.txt
# Processing:  steroid_hormone_bios_train_5673.txt
# Processing:  steroid_hormone_bios_train_6668.txt
# Processing:  steroid_hormone_bios_train_7125.txt
# Processing:  steroid_hormone_bios_train_7327.txt
# Processing:  steroid_hormone_bios_train_8148.txt
# Processing:  steroid_hormone_bios_train_8704.txt
# Processing:  steroid_hormone_bios_train_8921.txt
# Processing:  sulfur_metabolism_train_3820.txt
# Processing:  sulfur_metabolism_train_4762.txt
# Processing:  sulfur_metabolism_train_4864.txt
# Processing:  sulfur_metabolism_train_5728.txt
# Processing:  sulfur_metabolism_train_5877.txt
# Processing:  sulfur_metabolism_train_6064.txt
# Processing:  sulfur_metabolism_train_8644.txt
# Processing:  sulfur_metabolism_train_9149.txt
# Processing:  sulfur_metabolism_train_9748.txt
# Processing:  synthesis_and_degrad_train_2073.txt
# Processing:  synthesis_and_degrad_train_2698.txt
# Processing:  synthesis_and_degrad_train_2802.txt
# Processing:  synthesis_and_degrad_train_2915.txt
# Processing:  synthesis_and_degrad_train_3187.txt
# Processing:  synthesis_and_degrad_train_3351.txt
# Processing:  synthesis_and_degrad_train_3972.txt
# Processing:  synthesis_and_degrad_train_5068.txt
# Processing:  synthesis_and_degrad_train_6205.txt
# Processing:  synthesis_and_degrad_train_6376.txt
# Processing:  taurine_and_hypotaur_train_1079.txt
# Processing:  taurine_and_hypotaur_train_1875.txt
# Processing:  taurine_and_hypotaur_train_2474.txt
# Processing:  taurine_and_hypotaur_train_2505.txt
# Processing:  taurine_and_hypotaur_train_3065.txt
# Processing:  taurine_and_hypotaur_train_3206.txt
# Processing:  taurine_and_hypotaur_train_4985.txt
# Processing:  taurine_and_hypotaur_train_5698.txt
# Processing:  taurine_and_hypotaur_train_6366.txt
# Processing:  taurine_and_hypotaur_train_9891.txt
# Processing:  terpenoid_backbone_b_train_1198.txt
# Processing:  terpenoid_backbone_b_train_2152.txt
# Processing:  terpenoid_backbone_b_train_3241.txt
# Processing:  terpenoid_backbone_b_train_4588.txt
# Processing:  terpenoid_backbone_b_train_6459.txt
# Processing:  terpenoid_backbone_b_train_6621.txt
# Processing:  terpenoid_backbone_b_train_8657.txt
# Processing:  terpenoid_backbone_b_train_8661.txt
# Processing:  terpenoid_backbone_b_train_8942.txt
# Processing:  terpenoid_backbone_b_train_9404.txt
# Processing:  thiamine_metabolism_train_1501.txt
# Processing:  thiamine_metabolism_train_2100.txt
# Processing:  thiamine_metabolism_train_3773.txt
# Processing:  thiamine_metabolism_train_3962.txt
# Processing:  thiamine_metabolism_train_4084.txt
# Processing:  thiamine_metabolism_train_5258.txt
# Processing:  thiamine_metabolism_train_5980.txt
# Processing:  thiamine_metabolism_train_6802.txt
# Processing:  thiamine_metabolism_train_8748.txt
# Processing:  thiamine_metabolism_train_9623.txt
# Processing:  tryptophan_metabolis_train_1628.txt
# Processing:  tryptophan_metabolis_train_2110.txt
# Processing:  tryptophan_metabolis_train_3266.txt
# Processing:  tryptophan_metabolis_train_5522.txt
# Processing:  tryptophan_metabolis_train_6237.txt
# Processing:  tryptophan_metabolis_train_6412.txt
# Processing:  tryptophan_metabolis_train_6753.txt
# Processing:  tryptophan_metabolis_train_8942.txt
# Processing:  tryptophan_metabolis_train_9256.txt
# Processing:  tryptophan_metabolis_train_9385.txt
# Processing:  tyrosine_metabolism_train_1290.txt
# Processing:  tyrosine_metabolism_train_1681.txt
# Processing:  tyrosine_metabolism_train_2226.txt
# Processing:  tyrosine_metabolism_train_4111.txt
# Processing:  tyrosine_metabolism_train_5403.txt
# Processing:  tyrosine_metabolism_train_6010.txt
# Processing:  tyrosine_metabolism_train_7101.txt
# Processing:  tyrosine_metabolism_train_7807.txt
# Processing:  tyrosine_metabolism_train_8180.txt
# Processing:  tyrosine_metabolism_train_8918.txt
# Processing:  ubiquinone_and_other_train_2366.txt
# Processing:  ubiquinone_and_other_train_2517.txt
# Processing:  ubiquinone_and_other_train_2997.txt
# Processing:  ubiquinone_and_other_train_4287.txt
# Processing:  ubiquinone_and_other_train_5477.txt
# Processing:  ubiquinone_and_other_train_5916.txt
# Processing:  ubiquinone_and_other_train_6291.txt
# Processing:  ubiquinone_and_other_train_7233.txt
# Processing:  ubiquinone_and_other_train_7545.txt
# Processing:  ubiquinone_and_other_train_9396.txt
# Processing:  valine__leucine_and___1_train_3551.txt
# Processing:  valine__leucine_and___1_train_4437.txt
# Processing:  valine__leucine_and___1_train_5467.txt
# Processing:  valine__leucine_and___1_train_6589.txt
# Processing:  valine__leucine_and___1_train_7923.txt
# Processing:  valine__leucine_and___1_train_8676.txt
# Processing:  valine__leucine_and___1_train_9079.txt
# Processing:  valine__leucine_and___1_train_9534.txt
# Processing:  valine__leucine_and___1_train_9761.txt
# Processing:  valine__leucine_and_train_1385.txt
# Processing:  valine__leucine_and_train_1863.txt
# Processing:  valine__leucine_and_train_1950.txt
# Processing:  valine__leucine_and_train_3704.txt
# Processing:  valine__leucine_and_train_4369.txt
# Processing:  valine__leucine_and_train_6172.txt
# Processing:  valine__leucine_and_train_7204.txt
# Processing:  valine__leucine_and_train_7368.txt
# Processing:  valine__leucine_and_train_7495.txt
# Processing:  valine__leucine_and_train_7776.txt
# Processing:  vitamin_b6_metabolis_train_1175.txt
# Processing:  vitamin_b6_metabolis_train_1544.txt
# Processing:  vitamin_b6_metabolis_train_2567.txt
# Processing:  vitamin_b6_metabolis_train_3756.txt
# Processing:  vitamin_b6_metabolis_train_3761.txt
# Processing:  vitamin_b6_metabolis_train_6075.txt
# Processing:  vitamin_b6_metabolis_train_6815.txt
# Processing:  vitamin_b6_metabolis_train_6881.txt
# Processing:  vitamin_b6_metabolis_train_7405.txt
# Processing:  vitamin_b6_metabolis_train_7692.txt
# Processing:  alanine__aspartate_a_train_1510.txt
# Processing:  valine__leucine_and___1_train_1008.txt

# %%
# Save the dataset to disk
torch.save(data_list, 'dataset.pt')
